# %% [markdown]
# # JDE ETL Source Design
# ## Goal:  Generate source SQL with friendly names and built-in data Conversion
# 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals
# 2. Pull *Specific* Table fields
# 3. Create SQL mapiing pull with data-conversion

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import os, sys
import warnings

warnings.filterwarnings('ignore')

# %%
from decouple import config
config.search_path = '/home/jovyan/work'

# %% [markdown]
# ### Connect to SQL DB

# %%
engine = create_engine(config('DATABASE_URL'))

# %% [markdown]
# ### 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals

# %%
sql_field_meta_server = 'ESYS_PROD'
sql_field_meta_lib = 'ARCPCOM71'

# %%
sql_field_meta = '''
SELECT 
	RTRIM("FRDTAI")				AS data_item
	,"FRDTAT"					AS data_item_type
	,"FROWTP"					AS data_type
	,"FRDTAS"					AS data_item_size
	,ISNULL("FRCDEC", 0)		AS display_decimals
	,ISNULL("FRDSCR", 'zNA')	AS row_description 
    
FROM 

    OPENQUERY ({}, '

	SELECT
		t.FRDTAI
		,FRDTAT
		,FROWTP
		,FRDTAS
		,FRCDEC
		,FRDSCR
	FROM
		{}.F9210 t
		LEFT JOIN {}.F9202 d
		ON t.FRDTAI = d.FRDTAI AND
			d.FRLNGP = '' '' AND
			d.FRSYR = '' ''  
')

'''.format(sql_field_meta_server, sql_field_meta_lib, sql_field_meta_lib)

# %%
print(sql_field_meta)
# Out:
# SELECT
# 	RTRIM("FRDTAI")				AS data_item
# 	,"FRDTAT"					AS data_item_type
# 	,"FROWTP"					AS data_type
# 	,"FRDTAS"					AS data_item_size
# 	,ISNULL("FRCDEC", 0)		AS display_decimals
# 	,ISNULL("FRDSCR", 'zNA')	AS row_description
#
# FROM
#
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		t.FRDTAI
# 		,FRDTAT
# 		,FROWTP
# 		,FRDTAS
# 		,FRCDEC
# 		,FRDSCR
# 	FROM
# 		ARCPCOM71.F9210 t
# 		LEFT JOIN ARCPCOM71.F9202 d
# 		ON t.FRDTAI = d.FRDTAI AND
# 			d.FRLNGP = '' '' AND
# 			d.FRSYR = '' ''
# ')

# %%
df_field_meta = pd.read_sql_query(sql_field_meta, engine);

# %%
df_field_meta.iloc[:,[2,3,4]] = df_field_meta.iloc[:,[2,3,4]].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_field_meta.fillna(value=0,inplace=True)

# %% [markdown]
# ### 2. Pull *Specific* Table fields

# %% [markdown]
# #  Set Table Name HERE

# %%
sql_table = 'F554509'
#sql_table = 'F060116'
#sql_table = 'RPTRULES'

sql_link_server = 'ESYS_PROD'
#sql_lib = 'ARCPTEL'
sql_lib = 'ARCPDTA71'
#sql_lib = 'ESEND'
#sql_lib = 'HSIPDTA71'


stage_db_schema = 'Integration.'
convert_julian_date = True

# [ARC | HSI] [P | D] [DTA | CDC] [ 71 | 94]

# %%
sql_table_fields = '''

SELECT * from OPENQUERY ({}, '
	SELECT
		*
	FROM
		QSYS2.SYSCOLUMNS
	WHERE
        TABLE_SCHEMA = ''{}'' AND
		TABLE_NAME in( ''{}'')
    ORDER BY 
        ORDINAL_POSITION
')

''' .format(sql_link_server, sql_lib, sql_table)

# %%
#print (sql_table_fields)

# %%
df_table_fields = pd.read_sql_query(sql_table_fields, engine);

# %% [markdown]
# #### Join table fields with data dictionary meta-data

# %%
#df_table_fields

# %%
df_table_fields = df_table_fields[['ORDINAL_POSITION', 'COLUMN_NAME', 'COLUMN_TEXT', 'DATA_TYPE','LENGTH', 'NUMERIC_PRECISION']]

# %%
df_table_fields['data_item'] = df_table_fields.COLUMN_NAME.str[2:]

# %%
df_table_fields.head()
# Out:
#    ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                 1      QXLITM  2nd Item Number. . . . . . . . . . . . .
# 1                 2      QXCYLN  Cylinder # . . . . . . . . . . . . . . .
# 2                 3      QXURRF  User Reserved Reference  . . . . . . . .
# 3                 4      QX$BID  Bid Number . . . . . . . . . . . . . . .
# 4                 5       QXREF  Reference. . . . . . . . . . . . . . . .
#
#   DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item
# 0      CHAR      25                NaN      LITM
# 1      CHAR      10                NaN      CYLN
# 2      CHAR      15                NaN      URRF
# 3      CHAR      10                NaN      $BID
# 4      CHAR      15                NaN       REF

# %%
df_table_fields.data_item.unique()
# Out:
# array(['LITM', 'CYLN', 'URRF', '$BID', 'REF', 'AST', 'AC10', '$FSI',
#        'NADR', 'UOM1', 'CRCD', 'VBT', 'REF1', 'URCD', 'URDT', 'URAT',
#        'URAB', 'USER'], dtype=object)

# %%
dff = pd.merge(df_table_fields,df_field_meta,on='data_item', how='left')

# %% [markdown]
# #### Cleanup final field name
# remove trailing dots, special characters, and converto to lower_case

# %%
dff['row_description_final'] = dff.row_description.str.rstrip('. ').str.replace(r'%','pct').str.replace(r'$','amt').str.replace(r'[^0-9|a-z|" "]','', case=False).str.replace('  ',' ').str.lower().str.replace(' ','_')

# %% [markdown]
# #### Override with Defaults

# %%
dff['row_description_final'][dff['data_item']=='LITM'] = 'item_number'
dff['row_description_final'][dff['data_item']=='AN8'] = 'billto'
dff['row_description_final'][dff['data_item']=='SHAN'] = 'shipto'
dff['row_description_final'][dff['data_item']=='DOCO'] = 'salesorder_number'

# %% [markdown]
# ### 3. Create SQL mapping pull with data-conversion

# %%
dff.groupby(['DATA_TYPE', 'data_type','display_decimals'])['ORDINAL_POSITION'].count()
# Out:
# DATA_TYPE  data_type  display_decimals
# CHAR       1.0        0.0                  1
#            2.0        0.0                 13
#            9.0        0.0                  1
# DECIMAL    9.0        2.0                  1
# NUMERIC    9.0        0.0                  1
#            11.0       0.0                  1
# Name: ORDINAL_POSITION, dtype: int64

# %%
dff
# Out:
#     ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                  1      QXLITM  2nd Item Number. . . . . . . . . . . . .
# 1                  2      QXCYLN  Cylinder # . . . . . . . . . . . . . . .
# 2                  3      QXURRF  User Reserved Reference  . . . . . . . .
# 3                  4      QX$BID  Bid Number . . . . . . . . . . . . . . .
# 4                  5       QXREF  Reference. . . . . . . . . . . . . . . .
# 5                  6       QXAST  Adjustment Name. . . . . . . . . . . . .
# 6                  7      QXAC10   Division Code . . . . . . . .. . . . ..
# 7                  8      QX$FSI  Family Set Indicator . . . . . . . . . .
# 8                  9      QXNADR  Network Address. . . . . . . . . . . . .
# 9                 10      QXUOM1  Unit of Measure. . . . . . . . . . . . .
# 10                11      QXCRCD  Currency Code. . . . . . . . . . . . . .
# 11                12       QXVBT  Variable Table . . . . . . . . . . . . .
# 12                13      QXREF1  Reference Height . . . . . . . . . . . .
# 13                14      QXURCD  User Reserved Code . . . . . . . . . . .
# 14                15      QXURDT  User Reserved Date . . . . . . . . . . .
# 15                16      QXURAT  User Reserved Amount . . . . . . . . . .
# 16                17      QXURAB  User Reserved Number . . . . . . . . . .
# 17                18      QXUSER  User ID. . . . . . . . . . . . . . . . .
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type  data_type  \
# 0       CHAR      25                NaN      LITM              A        2.0
# 1       CHAR      10                NaN      CYLN              A        2.0
# 2       CHAR      15                NaN      URRF              A        2.0
# 3       CHAR      10                NaN      $BID              A        2.0
# 4       CHAR      15                NaN       REF              A        2.0
# 5       CHAR       8                NaN       AST              A        2.0
# 6       CHAR       3                NaN      AC10              A        2.0
# 7       CHAR       1                NaN      $FSI              A        1.0
# 8       CHAR       8                NaN      NADR              A        2.0
# 9       CHAR       2                NaN      UOM1              A        2.0
# 10      CHAR       3                NaN      CRCD              A        2.0
# 11      CHAR      10                NaN       VBT              A        2.0
# 12      CHAR      15                NaN      REF1              A        9.0
# 13      CHAR       2                NaN      URCD              A        2.0
# 14   NUMERIC       6                6.0      URDT              S       11.0
# 15   DECIMAL      15               15.0      URAT              P        9.0
# 16   NUMERIC       8                8.0      URAB              S        9.0
# 17      CHAR      10                NaN      USER              A        2.0
#
#     data_item_size  display_decimals  \
# 0             25.0               0.0
# 1             10.0               0.0
# 2             15.0               0.0
# 3             10.0               0.0
# 4             15.0               0.0
# 5              8.0               0.0
# 6              3.0               0.0
# 7              1.0               0.0
# 8              8.0               0.0
# 9              2.0               0.0
# 10             3.0               0.0
# 11            10.0               0.0
# 12            15.0               0.0
# 13             2.0               0.0
# 14             6.0               0.0
# 15            15.0               2.0
# 16             8.0               0.0
# 17            10.0               0.0
#
#                              row_description    row_description_final
# 0   2nd Item Number. . . . . . . . . . . . .              item_number
# 1   Cylinder # . . . . . . . . . . . . . . .                cylinder_
# 2   User Reserved Reference  . . . . . . . .  user_reserved_reference
# 3   Bid Number . . . . . . . . . . . . . . .               bid_number
# 4   Reference. . . . . . . . . . . . . . . .                reference
# 5   Adjustment Name. . . . . . . . . . . . .          adjustment_name
# 6   Division Code . . . . . . . . . . . . ..            division_code
# 7   Family Set Indicator . . . . . . . . . .     family_set_indicator
# 8   Network Address. . . . . . . . . . . . .          network_address
# 9   Unit of Measure. . . . . . . . . . . . .          unit_of_measure
# 10  Currency Code. . . . . . . . . . . . . .            currency_code
# 11  Variable Table . . . . . . . . . . . . .           variable_table
# 12  Reference Height . . . . . . . . . . . .         reference_height
# 13  User Reserved Code . . . . . . . . . . .       user_reserved_code
# 14  User Reserved Date . . . . . . . . . . .       user_reserved_date
# 15  User Reserved Amount . . . . . . . . . .     user_reserved_amount
# 16  User Reserved Number . . . . . . . . . .     user_reserved_number
# 17  User ID. . . . . . . . . . . . . . . . .                  user_id

# %%
def field_format_sel(col_name, col_type, col_dec):
    val =''

    if col_type == 9 :
        if col_dec > 0 :
            val = 'CAST(({})/{} AS DEC({},{})) AS {}'.format(col_name,10**col_dec,15,np.int(col_dec),col_name)
        else :
            val = col_name
    elif  col_type == 11 : 
        if convert_julian_date :
            val = 'CASE WHEN {} IS NOT NULL THEN DATE(DIGITS(DEC({}+ 1900000,7,0))) ELSE NULL END AS {}'.format(col_name, col_name, col_name)
        else :
            val = '{} as {}'.format(col_name,col_name)
    else : 
        val = col_name
    return val;

def field_format_map(col_name, col_descr, is_etl = False):
    val =''

    col_name_format = '{message:{fill}{align}{width}}'.format(message=col_name, fill='_', align='<', width=6)
    
    col_descr_format = col_descr
    if str.isdigit(col_descr_format[0]) :
        col_descr_format = "_" + col_descr_format
        
    if is_etl :
        val = '{}_{} AS {}'.format(col_name_format, col_descr_format, col_descr_format)
    else :
        val = '"{}" AS {}_{}'.format(col_name, col_name_format, col_descr_format)

    return val;



sql_field_map = ', '.join([field_format_map(x,y)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])

sql_field_etl = ', '.join([field_format_map(x,y,is_etl=True)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])
#
# ok
sql_field_sel = ', '.join([ field_format_sel(col_name, col_type, col_dec) \
                           for col_name, col_type, col_dec in zip(dff['COLUMN_NAME'], dff['data_type'], dff['display_decimals'])])

# %%
sql_field_sel
# Out:
# 'QXLITM, QXCYLN, QXURRF, QX$BID, QXREF, QXAST, QXAC10, QX$FSI, QXNADR, QXUOM1, QXCRCD, QXVBT, QXREF1, QXURCD, CASE WHEN QXURDT IS NOT NULL THEN DATE(DIGITS(DEC(QXURDT+ 1900000,7,0))) ELSE NULL END AS QXURDT, CAST((QXURAT)/100.0 AS DEC(15,2)) AS QXURAT, QXURAB, QXUSER'

# %%
sql_table_map = '''

--------------------------------------------------------------------------------
-- DROP TABLE Integration.{}_{}_<instert_friendly_name_here>
--------------------------------------------------------------------------------

SELECT 

    {} 
    {} 

-- INTO {}{}_{}_<instert_friendly_name_here>

FROM 
    OPENQUERY ({}, '

	SELECT
		{}

	FROM
		{}.{}
--    WHERE
--        <insert custom code here>
--    ORDER BY
--        <insert custom code here>
')

--------------------------------------------------------------------------------

'''.format(sql_lib, sql_table, 'Top 5', sql_field_map, stage_db_schema, sql_lib, sql_table, sql_link_server, sql_field_sel, sql_lib, sql_table)

# %% [markdown]
# ### Output Table
# 1. Use to create STAGE via SQL link table
# 1. Note that some Julian _JDT conversion will need to be converted Post

# %%
print(sql_table_map)
# Out:
# --------------------------------------------------------------------------------
# -- DROP TABLE Integration.ARCPDTA71_F554509_<instert_friendly_name_here>
# --------------------------------------------------------------------------------
#
# SELECT
#
#     Top 5
#     "QXLITM" AS QXLITM_item_number, "QXCYLN" AS QXCYLN_cylinder_, "QXURRF" AS QXURRF_user_reserved_reference, "QX$BID" AS QX$BID_bid_number, "QXREF" AS QXREF__reference, "QXAST" AS QXAST__adjustment_name, "QXAC10" AS QXAC10_division_code, "QX$FSI" AS QX$FSI_family_set_indicator, "QXNADR" AS QXNADR_network_address, "QXUOM1" AS QXUOM1_unit_of_measure, "QXCRCD" AS QXCRCD_currency_code, "QXVBT" AS QXVBT__variable_table, "QXREF1" AS QXREF1_reference_height, "QXURCD" AS QXURCD_user_reserved_code, "QXURDT" AS QXURDT_user_reserved_date, "QXURAT" AS QXURAT_user_reserved_amount, "QXURAB" AS QXURAB_user_reserved_number, "QXUSER" AS QXUSER_user_id
#
# -- INTO Integration.ARCPDTA71_F554509_<instert_friendly_name_here>
#
# FROM
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		QXLITM, QXCYLN, QXURRF, QX$BID, QXREF, QXAST, QXAC10, QX$FSI, QXNADR, QXUOM1, QXCRCD, QXVBT, QXREF1, QXURCD, CASE WHEN QXURDT IS NOT NULL THEN DATE(DIGITS(DEC(QXURDT+ 1900000,7,0))) ELSE NULL END AS QXURDT, CAST((QXURAT)/100.0 AS DEC(15,2)) AS QXURAT, QXURAB, QXUSER
#
# 	FROM
# 		ARCPDTA71.F554509
# --    WHERE
# --        <insert custom code here>
# --    ORDER BY
# --        <insert custom code here>
# ')
#
# --------------------------------------------------------------------------------

# %%
dff
# Out:
#     ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                  1      QXLITM  2nd Item Number. . . . . . . . . . . . .
# 1                  2      QXCYLN  Cylinder # . . . . . . . . . . . . . . .
# 2                  3      QXURRF  User Reserved Reference  . . . . . . . .
# 3                  4      QX$BID  Bid Number . . . . . . . . . . . . . . .
# 4                  5       QXREF  Reference. . . . . . . . . . . . . . . .
# 5                  6       QXAST  Adjustment Name. . . . . . . . . . . . .
# 6                  7      QXAC10   Division Code . . . . . . . .. . . . ..
# 7                  8      QX$FSI  Family Set Indicator . . . . . . . . . .
# 8                  9      QXNADR  Network Address. . . . . . . . . . . . .
# 9                 10      QXUOM1  Unit of Measure. . . . . . . . . . . . .
# 10                11      QXCRCD  Currency Code. . . . . . . . . . . . . .
# 11                12       QXVBT  Variable Table . . . . . . . . . . . . .
# 12                13      QXREF1  Reference Height . . . . . . . . . . . .
# 13                14      QXURCD  User Reserved Code . . . . . . . . . . .
# 14                15      QXURDT  User Reserved Date . . . . . . . . . . .
# 15                16      QXURAT  User Reserved Amount . . . . . . . . . .
# 16                17      QXURAB  User Reserved Number . . . . . . . . . .
# 17                18      QXUSER  User ID. . . . . . . . . . . . . . . . .
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type  data_type  \
# 0       CHAR      25                NaN      LITM              A        2.0
# 1       CHAR      10                NaN      CYLN              A        2.0
# 2       CHAR      15                NaN      URRF              A        2.0
# 3       CHAR      10                NaN      $BID              A        2.0
# 4       CHAR      15                NaN       REF              A        2.0
# 5       CHAR       8                NaN       AST              A        2.0
# 6       CHAR       3                NaN      AC10              A        2.0
# 7       CHAR       1                NaN      $FSI              A        1.0
# 8       CHAR       8                NaN      NADR              A        2.0
# 9       CHAR       2                NaN      UOM1              A        2.0
# 10      CHAR       3                NaN      CRCD              A        2.0
# 11      CHAR      10                NaN       VBT              A        2.0
# 12      CHAR      15                NaN      REF1              A        9.0
# 13      CHAR       2                NaN      URCD              A        2.0
# 14   NUMERIC       6                6.0      URDT              S       11.0
# 15   DECIMAL      15               15.0      URAT              P        9.0
# 16   NUMERIC       8                8.0      URAB              S        9.0
# 17      CHAR      10                NaN      USER              A        2.0
#
#     data_item_size  display_decimals  \
# 0             25.0               0.0
# 1             10.0               0.0
# 2             15.0               0.0
# 3             10.0               0.0
# 4             15.0               0.0
# 5              8.0               0.0
# 6              3.0               0.0
# 7              1.0               0.0
# 8              8.0               0.0
# 9              2.0               0.0
# 10             3.0               0.0
# 11            10.0               0.0
# 12            15.0               0.0
# 13             2.0               0.0
# 14             6.0               0.0
# 15            15.0               2.0
# 16             8.0               0.0
# 17            10.0               0.0
#
#                              row_description    row_description_final
# 0   2nd Item Number. . . . . . . . . . . . .              item_number
# 1   Cylinder # . . . . . . . . . . . . . . .                cylinder_
# 2   User Reserved Reference  . . . . . . . .  user_reserved_reference
# 3   Bid Number . . . . . . . . . . . . . . .               bid_number
# 4   Reference. . . . . . . . . . . . . . . .                reference
# 5   Adjustment Name. . . . . . . . . . . . .          adjustment_name
# 6   Division Code . . . . . . . . . . . . ..            division_code
# 7   Family Set Indicator . . . . . . . . . .     family_set_indicator
# 8   Network Address. . . . . . . . . . . . .          network_address
# 9   Unit of Measure. . . . . . . . . . . . .          unit_of_measure
# 10  Currency Code. . . . . . . . . . . . . .            currency_code
# 11  Variable Table . . . . . . . . . . . . .           variable_table
# 12  Reference Height . . . . . . . . . . . .         reference_height
# 13  User Reserved Code . . . . . . . . . . .       user_reserved_code
# 14  User Reserved Date . . . . . . . . . . .       user_reserved_date
# 15  User Reserved Amount . . . . . . . . . .     user_reserved_amount
# 16  User Reserved Number . . . . . . . . . .     user_reserved_number
# 17  User ID. . . . . . . . . . . . . . . . .                  user_id

# %%
# %time df_table_map = pd.read_sql_query(sql_table_map, engine);
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# pymssql.pyx in pymssql.Cursor.execute()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_query()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_query()
#
# _mssql.pyx in _mssql.MSSQLConnection.get_result()
#
# _mssql.pyx in _mssql.check_cancel_and_raise()
#
# _mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (7342, b'An unexpected NULL value was returned for column "[MSDASQL].QXURAT" from OLE DB provider "MSDASQL" for linked server "ESYS_PROD". This column cannot be NULL.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     507     def do_execute(self, cursor, statement, parameters, context=None):
# --> 508         cursor.execute(statement, parameters)
#     509
#
# pymssql.pyx in pymssql.Cursor.execute()
#
# OperationalError: (7342, b'An unexpected NULL value was returned for column "[MSDASQL].QXURAT" from OLE DB provider "MSDASQL" for linked server "ESYS_PROD". This column cannot be NULL.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <timed exec> in <module>()
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     312     return pandas_sql.read_query(
#     313         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 314         parse_dates=parse_dates, chunksize=chunksize)
#     315
#     316
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1061         args = _convert_params(sql, params)
#    1062
# -> 1063         result = self.execute(*args)
#    1064         columns = result.keys()
#    1065
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     952     def execute(self, *args, **kwargs):
#     953         """Simple passthrough to SQLAlchemy connectable"""
# --> 954         return self.connectable.execute(*args, **kwargs)
#     955
#     956     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2073
#    2074         connection = self.contextual_connect(close_with_result=True)
# -> 2075         return connection.execute(statement, *multiparams, **params)
#    2076
#    2077     def scalar(self, statement, *multiparams, **params):
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     506
#     507     def do_execute(self, cursor, statement, parameters, context=None):
# --> 508         cursor.execute(statement, parameters)
#     509
#     510     def do_execute_no_params(self, cursor, statement, context=None):
#
# pymssql.pyx in pymssql.Cursor.execute()
#
# OperationalError: (pymssql.OperationalError) (7342, b'An unexpected NULL value was returned for column "[MSDASQL].QXURAT" from OLE DB provider "MSDASQL" for linked server "ESYS_PROD". This column cannot be NULL.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n') [SQL: '\n\n--------------------------------------------------------------------------------\n-- DROP TABLE Integration.ARCPDTA71_F554509_<instert_friendly_name_here>\n--------------------------------------------------------------------------------\n\nSELECT \n\n    Top 5 \n    "QXLITM" AS QXLITM_item_number, "QXCYLN" AS QXCYLN_cylinder_, "QXURRF" AS QXURRF_user_reserved_reference, "QX$BID" AS QX$BID_bid_number, "QXREF" AS QXREF__reference, "QXAST" AS QXAST__adjustment_name, "QXAC10" AS QXAC10_division_code, "QX$FSI" AS QX$FSI_family_set_indicator, "QXNADR" AS QXNADR_network_address, "QXUOM1" AS QXUOM1_unit_of_measure, "QXCRCD" AS QXCRCD_currency_code, "QXVBT" AS QXVBT__variable_table, "QXREF1" AS QXREF1_reference_height, "QXURCD" AS QXURCD_user_reserved_code, "QXURDT" AS QXURDT_user_reserved_date, "QXURAT" AS QXURAT_user_reserved_amount, "QXURAB" AS QXURAB_user_reserved_number, "QXUSER" AS QXUSER_user_id \n\n-- INTO Integration.ARCPDTA71_F554509_<instert_friendly_name_here>\n\nFROM \n    OPENQUERY (ESYS_PROD, \'\n\n\tSELECT\n\t\tQXLITM, QXCYLN, QXURRF, QX$BID, QXREF, QXAST, QXAC10, QX$FSI, QXNADR, QXUOM1, QXCRCD, QXVBT, QXREF1, QXURCD, CASE WHEN QXURDT IS NOT NULL THEN DATE(DIGITS(DEC(QXURDT+ 1900000,7,0))) ELSE NULL END AS QXURDT, CAST((QXURAT)/100.0 AS DEC(15,2)) AS QXURAT, QXURAB, QXUSER\n\n\tFROM\n\t\tARCPDTA71.F554509\n--    WHERE\n--        <insert custom code here>\n--    ORDER BY\n--        <insert custom code here>\n\')\n\n--------------------------------------------------------------------------------\n\n'] (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# ### Next steps...
# Add SQL to SQL Tools data package

# %%
df_table_map
# Out:
#    QCDOCO_salesorder_number QCDCTO_order_type  \
# 0                    2051.0                SO
# 1                       2.0                CM
# 2                    9022.0                CM
# 3                       1.0                CO
# 4                   90276.0                SO
#
#   QCKCOO_order_number_document_company QC$XRN_cross_reference_number  \
# 0                                02000
# 1                                02000          1220151001
# 2                                02000          1220151001
# 3                                02000          1220151001
# 4                                02000
#
#   QC$AC1_address_code_future_1 QC$OSC_order_source_code  \
# 0                          000                        T
# 1                          000                        T
# 2                          000                        T
# 3                          000                        T
# 4                          000                        T
#
#    QC$FA__total_amount_freight QC$ASC_apply_small_order_charges  \
# 0                          0.0                                Y
# 1                          0.0                                Y
# 2                          0.0                                Y
# 3                          0.0                                Y
# 4                          0.0                                Y
#
#   QC$AHC_apply_hazardous_charges QC$FMC_form_222c        ...          \
# 0                              Y                         ...
# 1                              Y                         ...
# 2                              Y                         ...
# 3                              Y                         ...
# 4                              Y                         ...
#
#   QCAC19_category_code_19 QCAC20_category_code_20 QCAC21_category_code_21  \
# 0                                             EFC
# 1                                             EFC
# 2                                             EFC
# 3                                             EFC
# 4                                             EFC
#
#   QCAC22_category_code_22  QCAC23_category_code_23 QCUSER_user_id  \
# 0                                              DEN     MMORIN
# 1                                              DEN     MMORIN
# 2                                              DEN     BMAR04
# 3                                              DEN     MMORIN
# 4                                              DEN     MMORIN
#
#   QCPID__program_id QCJOBN_work_station_id QCUPMJ_date_updated  \
# 0        P551101                EAGLEHIST           2007-03-13
# 1        XS5713                 EAGLEHIST           2007-03-08
# 2        XS5714                 EAGLEHIST           2007-03-13
# 3        XS5713                 EAGLEHIST           2007-03-08
# 4        P551101                EAGLEHIST           2007-03-06
#
#   QCTDAY_time_of_day
# 0           132436.0
# 1           163852.0
# 2           133259.0
# 3           114821.0
# 4           171557.0
#
# [5 rows x 96 columns]
