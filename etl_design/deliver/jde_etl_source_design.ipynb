# %% [markdown]
# # JDE ETL Source Design
# ## Goal:  Generate source SQL with friendly names and built-in data Conversion
# 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals
# 2. Pull *Specific* Table fields
# 3. Create SQL mapiing pull with data-conversion

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import os, sys
import warnings

warnings.filterwarnings('ignore')

# %%
from decouple import config
config.search_path = '/home/jovyan/work'

# %% [markdown]
# ### Connect to SQL DB

# %%
engine = create_engine(config('DATABASE_URL'))

# %% [markdown]
# ### 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals

# %%
sql_field_meta_server = 'ESYS_PROD'
sql_field_meta_lib = 'ARCPCOM71'

# %%
sql_field_meta = '''
SELECT 
	RTRIM("FRDTAI")				AS data_item
	,"FRDTAT"					AS data_item_type
	,"FROWTP"					AS data_type
	,"FRDTAS"					AS data_item_size
	,ISNULL("FRCDEC", 0)		AS display_decimals
	,ISNULL("FRDSCR", 'zNA')	AS row_description 
    
FROM 

    OPENQUERY ({}, '

	SELECT
		t.FRDTAI
		,FRDTAT
		,FROWTP
		,FRDTAS
		,FRCDEC
		,FRDSCR
	FROM
		{}.F9210 t
		LEFT JOIN {}.F9202 d
		ON t.FRDTAI = d.FRDTAI AND
			d.FRLNGP = '' '' AND
			d.FRSYR = '' ''  
')

'''.format(sql_field_meta_server, sql_field_meta_lib, sql_field_meta_lib)

# %%
print(sql_field_meta)
# Out:
# SELECT
# 	RTRIM("FRDTAI")				AS data_item
# 	,"FRDTAT"					AS data_item_type
# 	,"FROWTP"					AS data_type
# 	,"FRDTAS"					AS data_item_size
# 	,ISNULL("FRCDEC", 0)		AS display_decimals
# 	,ISNULL("FRDSCR", 'zNA')	AS row_description
#
# FROM
#
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		t.FRDTAI
# 		,FRDTAT
# 		,FROWTP
# 		,FRDTAS
# 		,FRCDEC
# 		,FRDSCR
# 	FROM
# 		ARCPCOM71.F9210 t
# 		LEFT JOIN ARCPCOM71.F9202 d
# 		ON t.FRDTAI = d.FRDTAI AND
# 			d.FRLNGP = '' '' AND
# 			d.FRSYR = '' ''
# ')

# %%
df_field_meta = pd.read_sql_query(sql_field_meta, engine);

# %%
df_field_meta.iloc[:,[2,3,4]] = df_field_meta.iloc[:,[2,3,4]].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_field_meta.fillna(value=0,inplace=True)

# %% [markdown]
# ### 2. Pull *Specific* Table fields

# %% [markdown]
# #  Set Table Name HERE

# %%
sql_table = 'F4211'
#sql_table = 'F060116'
#sql_table = 'RPTRULES'

sql_link_server = 'ESYS_PROD'
#sql_lib = 'ARCPTEL'
sql_lib = 'ARCPDTA71'
#sql_lib = 'ESEND'
#sql_lib = 'HSIPDTA71'


stage_db_schema = 'Integration.'
convert_julian_date = True

# [ARC | HSI] [P | D] [DTA | CDC] [ 71 | 94]

# %%
sql_table_fields = '''

SELECT * from OPENQUERY ({}, '
	SELECT
		*
	FROM
		QSYS2.SYSCOLUMNS
	WHERE
        TABLE_SCHEMA = ''{}'' AND
		TABLE_NAME in( ''{}'')
    ORDER BY 
        ORDINAL_POSITION
')

''' .format(sql_link_server, sql_lib, sql_table)

# %%
#print (sql_table_fields)

# %%
df_table_fields = pd.read_sql_query(sql_table_fields, engine);

# %% [markdown]
# #### Join table fields with data dictionary meta-data

# %%
#df_table_fields

# %%
df_table_fields = df_table_fields[['ORDINAL_POSITION', 'COLUMN_NAME', 'COLUMN_TEXT', 'DATA_TYPE','LENGTH', 'NUMERIC_PRECISION']]

# %%
df_table_fields['data_item'] = df_table_fields.COLUMN_NAME.str[2:]

# %%
df_table_fields.head()
# Out:
#    ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                 1      SDKCOO  Order Company. . . . . . . . . . . . . .
# 1                 2      SDDOCO  Order Number . . . . . . . . . . . . . .
# 2                 3      SDDCTO  Order Type . . . . . . . . . . . . . . .
# 3                 4      SDLNID  Line Number. . . . . . . . . . . . . . .
# 4                 5      SDSFXO  Order Suffix . . . . . . . . . . . . . .
#
#   DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item
# 0      CHAR       5                NaN      KCOO
# 1   NUMERIC       8                8.0      DOCO
# 2      CHAR       2                NaN      DCTO
# 3   DECIMAL       6                6.0      LNID
# 4      CHAR       3                NaN      SFXO

# %%
df_table_fields.data_item.unique()
# Out:
# array(['KCOO', 'DOCO', 'DCTO', 'LNID', 'SFXO', 'SFX', 'MCU', 'CO', 'OKCO',
#        'OORN', 'OCTO', 'OGNO', 'RKCO', 'RORN', 'RCTO', 'RLLN', 'DMCT',
#        'DMCS', 'BALU', 'AN8', 'SHAN', 'MKFR', 'BTAN', 'PA8', 'DRQJ',
#        'TRDJ', 'PDDJ', 'OPDJ', 'ADDJ', 'IVD', 'CNDJ', 'DGL', 'RSDJ',
#        'PEFJ', 'PPDJ', 'RQSJ', 'ADLJ', 'DRQT', 'RSDT', 'VR01', 'VR02',
#        'VR03', 'ITM', 'LITM', 'AITM', 'MERL', 'LOCN', 'LOTN', 'FRGD',
#        'THGD', 'ACGD', 'FRMP', 'THRP', 'APOT', 'EXDP', 'DSC1', 'DSC2',
#        'LNTY', 'NXTR', 'LTTR', 'HOLD', 'EMCU', 'HDBU', 'DMBU', 'RLIT',
#        'KTLN', 'CPNT', 'RKIT', 'KTP', 'CSID', 'SRP1', 'SRP2', 'SRP3',
#        'SRP4', 'SRP5', 'PRP1', 'PRP2', 'PRP3', 'PRP4', 'PRP5', 'DMS1',
#        'DMT1', 'UOM', 'UORG', 'SOQS', 'SOBK', 'SOCN', 'SONE', 'UOPN',
#        'QTYT', 'QRLV', 'COMM', 'OTQY', 'BCRC', 'UPRC', 'AEXP', 'AOPN',
#        'PROV', 'TPC', 'APUM', 'LPRC', 'UNCS', 'ECST', 'CSTO', 'TCST',
#        'INMG', 'PTC', 'RYIN', 'DTBS', 'TRDC', 'FUN2', 'ASN', 'OSEQ',
#        'PRGR', 'CLVL', 'DSPR', 'DSFT', 'FAPP', 'CADC', 'KCO', 'DOC', 'DCT',
#        'ODOC', 'ODCT', 'OKC', 'PSN', 'DELN', 'PTSK', 'TAX1', 'TXA1',
#        'EXR1', 'ATXT', 'PRIO', 'RESL', 'BACK', 'SBAL', 'APTS', 'LOB',
#        'EUSE', 'DTYS', 'NTR', 'VEND', 'ANBY', 'CARS', 'MOT', 'COT', 'ROUT',
#        'STOP', 'ZON', 'CNID', 'FRTH', 'AFT', 'FUF1', 'FRTC', 'FRAT',
#        'RATT', 'SHCM', 'SHCN', 'SHPN', 'SERN', 'LDNM', 'SHMT', 'TKNR',
#        'TKTM', 'TKDA', 'UOM1', 'PQOR', 'UOM2', 'SQOR', 'UOM4', 'ITWT',
#        'WTUM', 'ITVL', 'VLUM', 'RPRC', 'ORPR', 'ORP', 'CMGP', 'CMGL',
#        'GLC', 'CTRY', 'FY', 'STTS', 'SO01', 'SO02', 'SO03', 'SO04', 'SO05',
#        'SO06', 'SO07', 'SO08', 'SO09', 'SO10', 'SO11', 'SO12', 'SO13',
#        'SO14', 'SO15', 'SO16', 'SO17', 'SO18', 'SO19', 'SO20', 'SLSM',
#        'SLCM', 'SLM2', 'SLC2', 'ACOM', 'CMCG', 'RCD', 'GRWT', 'GWUM',
#        'ANI', 'AID', 'OMCU', 'OBJ', 'SUB', 'LT', 'SBL', 'SBLT', 'LCOD',
#        'UPC1', 'UPC2', 'UPC3', 'SWMS', 'UNCD', 'CRMD', 'CRCD', 'CRR',
#        'FPRC', 'FUP', 'FEA', 'FUC', 'FEC', 'URCD', 'URDT', 'URAT', 'URAB',
#        'URRF', 'SCPD', 'SCPT', 'SCPS', 'EDCK', 'SBCK', 'BBCK', 'CMDM',
#        'USC1', 'USC2', 'USC3', 'USC4', 'USC5', 'BLNO', 'TMUP', 'S1DJ',
#        'S2DJ', 'WORN', 'WCTO', 'WKCO', 'WGNO', 'WCEJ', 'WFLG', 'WODO',
#        'WOCT', 'MMCU', 'SOQO', 'BOLA', 'SO21', 'SO22', 'SO23', 'SO24',
#        'SO25', 'SO26', 'SO27', 'SO28', 'SO29', 'SO30', 'ABR1', 'ABT1',
#        'ABR2', 'ABT2', 'ABR3', 'ABT3', 'ABR4', 'ABT4', 'TORG', 'USER',
#        'PID', 'JOBN', 'UPMJ', 'TDAY', 'UPAJ', 'TENT'], dtype=object)

# %%
dff = pd.merge(df_table_fields,df_field_meta,on='data_item', how='left')

# %% [markdown]
# #### Cleanup final field name
# remove trailing dots, special characters, and converto to lower_case

# %%
dff['row_description_final'] = dff.row_description.str.rstrip('. ').str.replace(r'%','pct').str.replace(r'$','amt').str.replace(r'[^0-9|a-z|" "]','', case=False).str.replace('  ',' ').str.lower().str.replace(' ','_')

# %% [markdown]
# #### Override with Defaults

# %%
dff['row_description_final'][dff['data_item']=='LITM'] = 'item_number'
dff['row_description_final'][dff['data_item']=='AN8'] = 'billto'
dff['row_description_final'][dff['data_item']=='SHAN'] = 'shipto'
dff['row_description_final'][dff['data_item']=='DOCO'] = 'salesorder_number'

# %% [markdown]
# ### 3. Create SQL mapping pull with data-conversion

# %%
dff.groupby(['DATA_TYPE', 'data_type','display_decimals'])['ORDINAL_POSITION'].count()
# Out:
# DATA_TYPE  data_type  display_decimals
# CHAR       1.0        0.0                  74
#            2.0        0.0                 115
# DECIMAL    9.0        0.0                  17
#                       2.0                   6
#                       3.0                  10
#                       4.0                  12
# NUMERIC    9.0        0.0                  36
#                       1.0                   1
#                       3.0                   1
#            11.0       0.0                  20
# Name: ORDINAL_POSITION, dtype: int64

# %%
dff
# Out:
#      ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                   1      SDKCOO  Order Company. . . . . . . . . . . . . .
# 1                   2      SDDOCO  Order Number . . . . . . . . . . . . . .
# 2                   3      SDDCTO  Order Type . . . . . . . . . . . . . . .
# 3                   4      SDLNID  Line Number. . . . . . . . . . . . . . .
# 4                   5      SDSFXO  Order Suffix . . . . . . . . . . . . . .
# 5                   6       SDSFX  Pay Item . . . . . . . . . . . . . . . .
# 6                   7       SDMCU  Business Unit. . . . . . . . . . . . . .
# 7                   8        SDCO  Company. . . . . . . . . . . . . . . . .
# 8                   9      SDOKCO  Original Order Document Company. . . . .
# 9                  10      SDOORN  Original Order Number. . . . . . . . . .
# 10                 11      SDOCTO  Original Order Type. . . . . . . . . . .
# 11                 12      SDOGNO  Original Line Number . . . . . . . . . .
# 12                 13      SDRKCO  Related Order Key Company. . . . . . . .
# 13                 14      SDRORN  Related Order Number . . . . . . . . . .
# 14                 15      SDRCTO  Related Order Type . . . . . . . . . . .
# 15                 16      SDRLLN  Related PO/SO Line Number. . . . . . . .
# 16                 17      SDDMCT  Agreement Nbr. . . . . . . . . . . . . .
# 17                 18      SDDMCS   Agreement Supplement. . . . .. . . . ..
# 18                 19      SDBALU  Contract Balances Updated Y/N. . . . . .
# 19                 20       SDAN8  Address Number . . . . . . . . . . . . .
# 20                 21      SDSHAN  Ship To. . . . . . . . . . . . . . . . .
# 21                 22      SDMKFR  Mark-for . . . . . . . . . . . . . . . .
# 22                 23      SDBTAN  Bill To Number . . . . . . . . . . . . .
# 23                 24       SDPA8  Parent Number. . . . . . . . . . . . . .
# 24                 25      SDDRQJ  Requested. . . . . . . . . . . . . . . .
# 25                 26      SDTRDJ  Order Date . . . . . . . . . . . . . . .
# 26                 27      SDPDDJ  Scheduled Pick . . . . . . . . . . . . .
# 27                 28      SDOPDJ  Original Promised. . . . . . . . . . . .
# 28                 29      SDADDJ  Actual Ship. . . . . . . . . . . . . . .
# 29                 30       SDIVD  Invoice Date . . . . . . . . . . . . . .
# ..                ...         ...                                       ...
# 262               263      SDWOCT  Order Type . . . . . . . . . . . . . . .
# 263               264      SDMMCU  Branch . . . . . . . . . . . . . . . . .
# 264               265      SDSOQO  Original Quantity. . . . . . . . . . . .
# 265               266      SDBOLA  Bill of Lading Number. . . . . . . . . .
# 266               267      SDSO21   Exchange Rate Date Flag . . .. . . . ..
# 267               268      SDSO22  Future Line Printed. . . . . . . . . . .
# 268               269      SDSO23  Sales Order Status 23. . . . . . . . . .
# 269               270      SDSO24  Sales Order Status 24. . . . . . . . . .
# 270               271      SDSO25  Sales Order Status 25. . . . . . . . . .
# 271               272      SDSO26  Sales Order Status 26. . . . . . . . . .
# 272               273      SDSO27  Sales Order Status 27. . . . . . . . . .
# 273               274      SDSO28  Sales Order Status 28. . . . . . . . . .
# 274               275      SDSO29  Sales Order Status 29. . . . . . . . . .
# 275               276      SDSO30  Sales Order Status 30. . . . . . . . . .
# 276               277      SDABR1  Enh Subledger Code 1 . . . . . . . . . .
# 277               278      SDABT1   Enh Subledger Type 1. . . . .. . .. . .
# 278               279      SDABR2  Enh Subledger Code 2 . . . . . . . . . .
# 279               280      SDABT2   Enh Subledger Type 2. . . . .. . .. . .
# 280               281      SDABR3  Enh Subledger Code 3 . . . . . . . . . .
# 281               282      SDABT3   Enh Subledger Type 3. . . . .. . .. . .
# 282               283      SDABR4   Enh Subledger Code 4. . . . .. . .. . .
# 283               284      SDABT4   Enh Subledger Type 4. . . . .. . .. . .
# 284               285      SDTORG  Transaction Originator . . . . . . . . .
# 285               286      SDUSER  User ID. . . . . . . . . . . . . . . . .
# 286               287       SDPID  Program ID . . . . . . . . . . . . . . .
# 287               288      SDJOBN  Work Station ID. . . . . . . . . . . . .
# 288               289      SDUPMJ  Date Updated . . . . . . . . . . . . . .
# 289               290      SDTDAY  Time of Day. . . . . . . . . . . . . . .
# 290               291      SDUPAJ  Date Added . . . . . . . . . . . . . . .
# 291               292      SDTENT  Time Entered . . . . . . . . . . . . . .
#
#     DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type  data_type  \
# 0        CHAR       5                NaN      KCOO              A        2.0
# 1     NUMERIC       8                8.0      DOCO              S        9.0
# 2        CHAR       2                NaN      DCTO              A        2.0
# 3     DECIMAL       6                6.0      LNID              P        9.0
# 4        CHAR       3                NaN      SFXO              A        2.0
# 5        CHAR       3                NaN       SFX              A        2.0
# 6        CHAR      12                NaN       MCU              A        2.0
# 7        CHAR       5                NaN        CO              A        2.0
# 8        CHAR       5                NaN      OKCO              A        2.0
# 9        CHAR       8                NaN      OORN              A        2.0
# 10       CHAR       2                NaN      OCTO              A        2.0
# 11    DECIMAL       7                7.0      OGNO              P        9.0
# 12       CHAR       5                NaN      RKCO              A        2.0
# 13       CHAR       8                NaN      RORN              A        2.0
# 14       CHAR       2                NaN      RCTO              A        2.0
# 15    DECIMAL       7                7.0      RLLN              P        9.0
# 16       CHAR      12                NaN      DMCT              A        2.0
# 17    NUMERIC       3                3.0      DMCS              S        9.0
# 18       CHAR       1                NaN      BALU              A        1.0
# 19    NUMERIC       8                8.0       AN8              S        9.0
# 20    NUMERIC       8                8.0      SHAN              S        9.0
# 21    NUMERIC       8                8.0      MKFR              S        9.0
# 22    NUMERIC       8                8.0      BTAN              S        9.0
# 23    NUMERIC       8                8.0       PA8              S        9.0
# 24    NUMERIC       6                6.0      DRQJ              S       11.0
# 25    NUMERIC       6                6.0      TRDJ              S       11.0
# 26    NUMERIC       6                6.0      PDDJ              S       11.0
# 27    NUMERIC       6                6.0      OPDJ              S       11.0
# 28    NUMERIC       6                6.0      ADDJ              S       11.0
# 29    NUMERIC       6                6.0       IVD              S       11.0
# ..        ...     ...                ...       ...            ...        ...
# 262      CHAR       2                NaN      WOCT              A        2.0
# 263      CHAR      12                NaN      MMCU              A        2.0
# 264   DECIMAL      15               15.0      SOQO              P        9.0
# 265   NUMERIC      17               17.0      BOLA              S        9.0
# 266      CHAR       1                NaN      SO21              A        1.0
# 267      CHAR       1                NaN      SO22              A        1.0
# 268      CHAR       1                NaN      SO23              A        1.0
# 269      CHAR       1                NaN      SO24              A        1.0
# 270      CHAR       1                NaN      SO25              A        1.0
# 271      CHAR       1                NaN      SO26              A        1.0
# 272      CHAR       1                NaN      SO27              A        1.0
# 273      CHAR       1                NaN      SO28              A        1.0
# 274      CHAR       1                NaN      SO29              A        1.0
# 275      CHAR       1                NaN      SO30              A        1.0
# 276      CHAR      12                NaN      ABR1              A        2.0
# 277      CHAR       1                NaN      ABT1              A        1.0
# 278      CHAR      12                NaN      ABR2              A        2.0
# 279      CHAR       1                NaN      ABT2              A        1.0
# 280      CHAR      34                NaN      ABR3              A        2.0
# 281      CHAR       1                NaN      ABT3              A        1.0
# 282      CHAR      34                NaN      ABR4              A        2.0
# 283      CHAR       1                NaN      ABT4              A        1.0
# 284      CHAR      10                NaN      TORG              A        2.0
# 285      CHAR      10                NaN      USER              A        2.0
# 286      CHAR      10                NaN       PID              A        2.0
# 287      CHAR      10                NaN      JOBN              A        2.0
# 288   NUMERIC       6                6.0      UPMJ              S       11.0
# 289   DECIMAL       6                6.0      TDAY              P        9.0
# 290   NUMERIC       6                6.0      UPAJ              S       11.0
# 291   NUMERIC       6                6.0      TENT              S        9.0
#
#      data_item_size  display_decimals  \
# 0               5.0               0.0
# 1               8.0               0.0
# 2               2.0               0.0
# 3               6.0               3.0
# 4               3.0               0.0
# 5               3.0               0.0
# 6              12.0               0.0
# 7               5.0               0.0
# 8               5.0               0.0
# 9               8.0               0.0
# 10              2.0               0.0
# 11              7.0               3.0
# 12              5.0               0.0
# 13              8.0               0.0
# 14              2.0               0.0
# 15              7.0               3.0
# 16             12.0               0.0
# 17              3.0               0.0
# 18              1.0               0.0
# 19              8.0               0.0
# 20              8.0               0.0
# 21              8.0               0.0
# 22              8.0               0.0
# 23              8.0               0.0
# 24              6.0               0.0
# 25              6.0               0.0
# 26              6.0               0.0
# 27              6.0               0.0
# 28              6.0               0.0
# 29              6.0               0.0
# ..              ...               ...
# 262             2.0               0.0
# 263            12.0               0.0
# 264            15.0               0.0
# 265            17.0               0.0
# 266             1.0               0.0
# 267             1.0               0.0
# 268             1.0               0.0
# 269             1.0               0.0
# 270             1.0               0.0
# 271             1.0               0.0
# 272             1.0               0.0
# 273             1.0               0.0
# 274             1.0               0.0
# 275             1.0               0.0
# 276            12.0               0.0
# 277             1.0               0.0
# 278            12.0               0.0
# 279             1.0               0.0
# 280            34.0               0.0
# 281             1.0               0.0
# 282            34.0               0.0
# 283             1.0               0.0
# 284            10.0               0.0
# 285            10.0               0.0
# 286            10.0               0.0
# 287            10.0               0.0
# 288             6.0               0.0
# 289             6.0               0.0
# 290             6.0               0.0
# 291             6.0               0.0
#
#                               row_description            row_description_final
# 0    Order Number Document Company. . . . . .    order_number_document_company
# 1    Order Number . . . . . . . . . . . . . .                salesorder_number
# 2    Order Type . . . . . . . . . . . . . . .                       order_type
# 3    Line Number. . . . . . . . . . . . . . .                      line_number
# 4    Order Suffix . . . . . . . . . . . . . .                     order_suffix
# 5    Pay Item . . . . . . . . . . . . . . . .                         pay_item
# 6    Business Unit. . . . . . . . . . . . . .                    business_unit
# 7    Company. . . . . . . . . . . . . . . . .                          company
# 8    Original Order Document Company. . . . .  original_order_document_company
# 9    Original Order Number. . . . . . . . . .            original_order_number
# 10   Original Order Type. . . . . . . . . . .              original_order_type
# 11   Original Line Number . . . . . . . . . .             original_line_number
# 12   Related Order Key Company. . . . . . . .        related_order_key_company
# 13   Related Order Number . . . . . . . . . .             related_order_number
# 14   Related Order Type . . . . . . . . . . .               related_order_type
# 15   Related PO/SO Line Number. . . . . . . .         related_poso_line_number
# 16   Contract Number. . . . . . . . . . . . .                  contract_number
# 17   Contract Supplement. . . . . . . . . . .              contract_supplement
# 18   Contract Balances Updated Y/N. . . . . .     contract_balances_updated_yn
# 19   Address Number . . . . . . . . . . . . .                           billto
# 20   Ship To. . . . . . . . . . . . . . . . .                           shipto
# 21   Mark-for . . . . . . . . . . . . . . . .                          markfor
# 22   Bill To Number . . . . . . . . . . . . .                   bill_to_number
# 23   Parent Number. . . . . . . . . . . . . .                    parent_number
# 24   Requested. . . . . . . . . . . . . . . .                        requested
# 25   Order Date . . . . . . . . . . . . . . .                       order_date
# 26   Scheduled Pick . . . . . . . . . . . . .                   scheduled_pick
# 27   Original Promised. . . . . . . . . . . .                original_promised
# 28   Actual Ship. . . . . . . . . . . . . . .                      actual_ship
# 29   Invoice Date . . . . . . . . . . . . . .                     invoice_date
# ..                                        ...                              ...
# 262  Order Type . . . . . . . . . . . . . . .                       order_type
# 263  Branch . . . . . . . . . . . . . . . . .                           branch
# 264  Original Quantity. . . . . . . . . . . .                original_quantity
# 265  Bill of Lading Number. . . . . . . . . .            bill_of_lading_number
# 266  Exchange Rate Date Flag . . . . . . . ..          exchange_rate_date_flag
# 267  Future Line Printed. . . . . . . . . . .              future_line_printed
# 268  Sales Order Status 23. . . . . . . . . .            sales_order_status_23
# 269  Sales Order Status 24. . . . . . . . . .            sales_order_status_24
# 270  Sales Order Status 25. . . . . . . . . .            sales_order_status_25
# 271  Sales Order Status 26. . . . . . . . . .            sales_order_status_26
# 272  Sales Order Status 27. . . . . . . . . .            sales_order_status_27
# 273  Sales Order Status 28. . . . . . . . . .            sales_order_status_28
# 274  Sales Order Status 29. . . . . . . . . .            sales_order_status_29
# 275  Sales Order Status 30. . . . . . . . . .            sales_order_status_30
# 276  Enh Subledger Code 1 . . . . . . . . . .             enh_subledger_code_1
# 277  Enh Subledger Type 1. . . . . . . .. . .             enh_subledger_type_1
# 278  Enh Subledger Code 2 . . . . . . . . . .             enh_subledger_code_2
# 279  Enh Subledger Type 2. . . . . . . .. . .             enh_subledger_type_2
# 280  Enh Subledger Code 3 . . . . . . . . . .             enh_subledger_code_3
# 281  Enh Subledger Type 3. . . . . . . .. . .             enh_subledger_type_3
# 282  Enh Subledger Code 4. . . . . . . .. . .             enh_subledger_code_4
# 283  Enh Subledger Type 4. . . . . . . .. . .             enh_subledger_type_4
# 284  Transaction Originator . . . . . . . . .           transaction_originator
# 285  User ID. . . . . . . . . . . . . . . . .                          user_id
# 286  Program ID . . . . . . . . . . . . . . .                       program_id
# 287  Work Station ID. . . . . . . . . . . . .                  work_station_id
# 288  Date Updated . . . . . . . . . . . . . .                     date_updated
# 289  Time of Day. . . . . . . . . . . . . . .                      time_of_day
# 290  Date Added . . . . . . . . . . . . . . .                       date_added
# 291  Time Entered . . . . . . . . . . . . . .                     time_entered
#
# [292 rows x 13 columns]

# %%
def field_format_sel(col_name, col_type, col_dec):
    val =''

    if col_type == 9 :
        if col_dec > 0 :
            val = 'CAST(({})/{} AS DEC({},{})) AS {}'.format(col_name,10**col_dec,15,np.int(col_dec),col_name)
        else :
            val = col_name
    elif  col_type == 11 : 
        if convert_julian_date :
            val = 'CASE WHEN {} IS NOT NULL THEN DATE(DIGITS(DEC({}+ 1900000,7,0))) ELSE NULL END AS {}'.format(col_name, col_name, col_name)
        else :
            val = '{} as {}'.format(col_name,col_name)
    else : 
        val = col_name
    return val;

def field_format_map(col_name, col_descr, is_etl = False):
    val =''

    col_name_format = '{message:{fill}{align}{width}}'.format(message=col_name, fill='_', align='<', width=6)
    
    col_descr_format = col_descr
    if str.isdigit(col_descr_format[0]) :
        col_descr_format = "_" + col_descr_format
        
    if is_etl :
        val = '{}_{} AS {}'.format(col_name_format, col_descr_format, col_descr_format)
    else :
        val = '"{}" AS {}_{}'.format(col_name, col_name_format, col_descr_format)

    return val;



sql_field_map = ', '.join([field_format_map(x,y)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])

sql_field_etl = ', '.join([field_format_map(x,y,is_etl=True)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])
#
# ok
sql_field_sel = ', '.join([ field_format_sel(col_name, col_type, col_dec) \
                           for col_name, col_type, col_dec in zip(dff['COLUMN_NAME'], dff['data_type'], dff['display_decimals'])])

# %%
sql_field_sel
# Out:
# 'SDKCOO, SDDOCO, SDDCTO, CAST((SDLNID)/1000.0 AS DEC(15,3)) AS SDLNID, SDSFXO, SDSFX, SDMCU, SDCO, SDOKCO, SDOORN, SDOCTO, CAST((SDOGNO)/1000.0 AS DEC(15,3)) AS SDOGNO, SDRKCO, SDRORN, SDRCTO, CAST((SDRLLN)/1000.0 AS DEC(15,3)) AS SDRLLN, SDDMCT, SDDMCS, SDBALU, SDAN8, SDSHAN, SDMKFR, SDBTAN, SDPA8, CASE WHEN SDDRQJ IS NOT NULL THEN DATE(DIGITS(DEC(SDDRQJ+ 1900000,7,0))) ELSE NULL END AS SDDRQJ, CASE WHEN SDTRDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDTRDJ+ 1900000,7,0))) ELSE NULL END AS SDTRDJ, CASE WHEN SDPDDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDPDDJ+ 1900000,7,0))) ELSE NULL END AS SDPDDJ, CASE WHEN SDOPDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDOPDJ+ 1900000,7,0))) ELSE NULL END AS SDOPDJ, CASE WHEN SDADDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDADDJ+ 1900000,7,0))) ELSE NULL END AS SDADDJ, CASE WHEN SDIVD IS NOT NULL THEN DATE(DIGITS(DEC(SDIVD+ 1900000,7,0))) ELSE NULL END AS SDIVD, CASE WHEN SDCNDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDCNDJ+ 1900000,7,0))) ELSE NULL END AS SDCNDJ, CASE WHEN SDDGL IS NOT NULL THEN DATE(DIGITS(DEC(SDDGL+ 1900000,7,0))) ELSE NULL END AS SDDGL, CASE WHEN SDRSDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDRSDJ+ 1900000,7,0))) ELSE NULL END AS SDRSDJ, CASE WHEN SDPEFJ IS NOT NULL THEN DATE(DIGITS(DEC(SDPEFJ+ 1900000,7,0))) ELSE NULL END AS SDPEFJ, CASE WHEN SDPPDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDPPDJ+ 1900000,7,0))) ELSE NULL END AS SDPPDJ, CASE WHEN SDRQSJ IS NOT NULL THEN DATE(DIGITS(DEC(SDRQSJ+ 1900000,7,0))) ELSE NULL END AS SDRQSJ, CASE WHEN SDADLJ IS NOT NULL THEN DATE(DIGITS(DEC(SDADLJ+ 1900000,7,0))) ELSE NULL END AS SDADLJ, SDDRQT, SDRSDT, SDVR01, SDVR02, SDVR03, SDITM, SDLITM, SDAITM, SDMERL, SDLOCN, SDLOTN, SDFRGD, SDTHGD, SDACGD, CAST((SDFRMP)/1000.0 AS DEC(15,3)) AS SDFRMP, CAST((SDTHRP)/1000.0 AS DEC(15,3)) AS SDTHRP, CAST((SDAPOT)/1000.0 AS DEC(15,3)) AS SDAPOT, SDEXDP, SDDSC1, SDDSC2, SDLNTY, SDNXTR, SDLTTR, SDHOLD, SDEMCU, SDHDBU, SDDMBU, SDRLIT, CAST((SDKTLN)/1000.0 AS DEC(15,3)) AS SDKTLN, CAST((SDCPNT)/10.0 AS DEC(15,1)) AS SDCPNT, SDRKIT, SDKTP, SDCSID, SDSRP1, SDSRP2, SDSRP3, SDSRP4, SDSRP5, SDPRP1, SDPRP2, SDPRP3, SDPRP4, SDPRP5, SDDMS1, SDDMT1, SDUOM, SDUORG, SDSOQS, SDSOBK, SDSOCN, SDSONE, SDUOPN, SDQTYT, SDQRLV, SDCOMM, SDOTQY, SDBCRC, CAST((SDUPRC)/10000.0 AS DEC(15,4)) AS SDUPRC, CAST((SDAEXP)/100.0 AS DEC(15,2)) AS SDAEXP, CAST((SDAOPN)/100.0 AS DEC(15,2)) AS SDAOPN, SDPROV, SDTPC, SDAPUM, CAST((SDLPRC)/10000.0 AS DEC(15,4)) AS SDLPRC, CAST((SDUNCS)/10000.0 AS DEC(15,4)) AS SDUNCS, CAST((SDECST)/100.0 AS DEC(15,2)) AS SDECST, SDCSTO, CAST((SDTCST)/10000.0 AS DEC(15,4)) AS SDTCST, SDINMG, SDPTC, SDRYIN, SDDTBS, CAST((SDTRDC)/1000.0 AS DEC(15,3)) AS SDTRDC, CAST((SDFUN2)/10000.0 AS DEC(15,4)) AS SDFUN2, SDASN, SDOSEQ, SDPRGR, SDCLVL, CAST((SDDSPR)/10000.0 AS DEC(15,4)) AS SDDSPR, SDDSFT, SDFAPP, CAST((SDCADC)/1000.0 AS DEC(15,3)) AS SDCADC, SDKCO, SDDOC, SDDCT, SDODOC, SDODCT, SDOKC, SDPSN, SDDELN, SDPTSK, SDTAX1, SDTXA1, SDEXR1, SDATXT, SDPRIO, SDRESL, SDBACK, SDSBAL, SDAPTS, SDLOB, SDEUSE, SDDTYS, SDNTR, SDVEND, SDANBY, SDCARS, SDMOT, SDCOT, SDROUT, SDSTOP, SDZON, SDCNID, SDFRTH, SDAFT, SDFUF1, SDFRTC, SDFRAT, SDRATT, SDSHCM, SDSHCN, SDSHPN, SDSERN, SDLDNM, SDSHMT, SDTKNR, SDTKTM, CASE WHEN SDTKDA IS NOT NULL THEN DATE(DIGITS(DEC(SDTKDA+ 1900000,7,0))) ELSE NULL END AS SDTKDA, SDUOM1, SDPQOR, SDUOM2, SDSQOR, SDUOM4, CAST((SDITWT)/10000.0 AS DEC(15,4)) AS SDITWT, SDWTUM, CAST((SDITVL)/10000.0 AS DEC(15,4)) AS SDITVL, SDVLUM, SDRPRC, SDORPR, SDORP, SDCMGP, SDCMGL, SDGLC, SDCTRY, SDFY, SDSTTS, SDSO01, SDSO02, SDSO03, SDSO04, SDSO05, SDSO06, SDSO07, SDSO08, SDSO09, SDSO10, SDSO11, SDSO12, SDSO13, SDSO14, SDSO15, SDSO16, SDSO17, SDSO18, SDSO19, SDSO20, SDSLSM, CAST((SDSLCM)/1000.0 AS DEC(15,3)) AS SDSLCM, SDSLM2, CAST((SDSLC2)/1000.0 AS DEC(15,3)) AS SDSLC2, SDACOM, SDCMCG, SDRCD, CAST((SDGRWT)/10000.0 AS DEC(15,4)) AS SDGRWT, SDGWUM, SDANI, SDAID, SDOMCU, SDOBJ, SDSUB, SDLT, SDSBL, SDSBLT, SDLCOD, SDUPC1, SDUPC2, SDUPC3, SDSWMS, SDUNCD, SDCRMD, SDCRCD, SDCRR, CAST((SDFPRC)/10000.0 AS DEC(15,4 ...

# %%
sql_table_map = '''

--------------------------------------------------------------------------------
-- DROP TABLE Integration.{}_{}_<instert_friendly_name_here>
--------------------------------------------------------------------------------

SELECT 

    {} 
    {} 

-- INTO {}{}_{}_<instert_friendly_name_here>

FROM 
    OPENQUERY ({}, '

	SELECT
		{}

	FROM
		{}.{}
--    WHERE
--        <insert custom code here>
--    ORDER BY
--        <insert custom code here>
')

--------------------------------------------------------------------------------

'''.format(sql_lib, sql_table, 'Top 5', sql_field_map, stage_db_schema, sql_lib, sql_table, sql_link_server, sql_field_sel, sql_lib, sql_table)

# %% [markdown]
# ### Output Table
# 1. Use to create STAGE via SQL link table
# 1. Note that some Julian _JDT conversion will need to be converted Post

# %%
print(sql_table_map)
# Out:
# --------------------------------------------------------------------------------
# -- DROP TABLE Integration.ARCPDTA71_F4211_<instert_friendly_name_here>
# --------------------------------------------------------------------------------
#
# SELECT
#
#     Top 5
#     "SDKCOO" AS SDKCOO_order_number_document_company, "SDDOCO" AS SDDOCO_salesorder_number, "SDDCTO" AS SDDCTO_order_type, "SDLNID" AS SDLNID_line_number, "SDSFXO" AS SDSFXO_order_suffix, "SDSFX" AS SDSFX__pay_item, "SDMCU" AS SDMCU__business_unit, "SDCO" AS SDCO___company, "SDOKCO" AS SDOKCO_original_order_document_company, "SDOORN" AS SDOORN_original_order_number, "SDOCTO" AS SDOCTO_original_order_type, "SDOGNO" AS SDOGNO_original_line_number, "SDRKCO" AS SDRKCO_related_order_key_company, "SDRORN" AS SDRORN_related_order_number, "SDRCTO" AS SDRCTO_related_order_type, "SDRLLN" AS SDRLLN_related_poso_line_number, "SDDMCT" AS SDDMCT_contract_number, "SDDMCS" AS SDDMCS_contract_supplement, "SDBALU" AS SDBALU_contract_balances_updated_yn, "SDAN8" AS SDAN8__billto, "SDSHAN" AS SDSHAN_shipto, "SDMKFR" AS SDMKFR_markfor, "SDBTAN" AS SDBTAN_bill_to_number, "SDPA8" AS SDPA8__parent_number, "SDDRQJ" AS SDDRQJ_requested, "SDTRDJ" AS SDTRDJ_order_date, "SDPDDJ" AS SDPDDJ_scheduled_pick, "SDOPDJ" AS SDOPDJ_original_promised, "SDADDJ" AS SDADDJ_actual_ship, "SDIVD" AS SDIVD__invoice_date, "SDCNDJ" AS SDCNDJ_cancel_date, "SDDGL" AS SDDGL__gl_date, "SDRSDJ" AS SDRSDJ_promised_delivery, "SDPEFJ" AS SDPEFJ_price_effective, "SDPPDJ" AS SDPPDJ_future_use_1, "SDRQSJ" AS SDRQSJ_requested, "SDADLJ" AS SDADLJ_actual_delivery, "SDDRQT" AS SDDRQT_requested_delivery_time, "SDRSDT" AS SDRSDT_promised_delivery_time, "SDVR01" AS SDVR01_reference, "SDVR02" AS SDVR02_reference_2, "SDVR03" AS SDVR03_markfor_reference, "SDITM" AS SDITM__item_number_short, "SDLITM" AS SDLITM_item_number, "SDAITM" AS SDAITM__3rd_item_number, "SDMERL" AS SDMERL_item_revision_level, "SDLOCN" AS SDLOCN_location, "SDLOTN" AS SDLOTN_lot, "SDFRGD" AS SDFRGD_from_grade, "SDTHGD" AS SDTHGD_thru_grade, "SDACGD" AS SDACGD_actual_grade, "SDFRMP" AS SDFRMP_from_potency, "SDTHRP" AS SDTHRP_thru_potency, "SDAPOT" AS SDAPOT_actual_potency, "SDEXDP" AS SDEXDP_days_before_expiration, "SDDSC1" AS SDDSC1_description, "SDDSC2" AS SDDSC2_description_2, "SDLNTY" AS SDLNTY_line_type, "SDNXTR" AS SDNXTR_status_code_next, "SDLTTR" AS SDLTTR_status_code_last, "SDHOLD" AS SDHOLD_hold_orders_code, "SDEMCU" AS SDEMCU_header_business_unit, "SDHDBU" AS SDHDBU_header_business_unit, "SDDMBU" AS SDDMBU_demand_business_unit, "SDRLIT" AS SDRLIT_related_item_number_kit, "SDKTLN" AS SDKTLN_kit_master_line_number, "SDCPNT" AS SDCPNT_component_line_number, "SDRKIT" AS SDRKIT_related_kit_component, "SDKTP" AS SDKTP__number_of_component_per_parent, "SDCSID" AS SDCSID_configured_string_id, "SDSRP1" AS SDSRP1_major_product_class, "SDSRP2" AS SDSRP2_sub_major_product_class, "SDSRP3" AS SDSRP3_minor_product_class, "SDSRP4" AS SDSRP4_sub_minor_product_class, "SDSRP5" AS SDSRP5_hazardous_class, "SDPRP1" AS SDPRP1_commodity_class, "SDPRP2" AS SDPRP2_commodity_sub_class, "SDPRP3" AS SDPRP3_supplier_rebate_code, "SDPRP4" AS SDPRP4_tax_classification, "SDPRP5" AS SDPRP5_landed_cost_rule, "SDDMS1" AS SDDMS1_agreement_supplement, "SDDMT1" AS SDDMT1_borrow_agreement, "SDUOM" AS SDUOM__um, "SDUORG" AS SDUORG_quantity, "SDSOQS" AS SDSOQS_quantity_shipped, "SDSOBK" AS SDSOBK_quantity_backordered, "SDSOCN" AS SDSOCN_quantity_canceled, "SDSONE" AS SDSONE_future_quantity_committed, "SDUOPN" AS SDUOPN_quantity_open, "SDQTYT" AS SDQTYT_quantity_shipped_to_date, "SDQRLV" AS SDQRLV_quantity_relieved, "SDCOMM" AS SDCOMM_committed_hs, "SDOTQY" AS SDOTQY_other_quantity_12, "SDBCRC" AS SDBCRC_base_currency, "SDUPRC" AS SDUPRC_unit_price, "SDAEXP" AS SDAEXP_extended_price, "SDAOPN" AS SDAOPN_amount_open, "SDPROV" AS SDPROV_price_override_code, "SDTPC" AS SDTPC__temporary_price_yn, "SDAPUM" AS SDAPUM_entered_unit_of_measure_for_unit_price, "SDLPRC" AS SDLPRC_unit_list_price, "SDUNCS" AS SDUNCS_unit_cost, "SDECST" AS SDECST_extended_cost, "SDCSTO" AS SDCSTO_cost_override_code, "SDTCST" AS SDTCST_transfer_cost, "SDINMG" AS SDINMG_print_message, "SDPTC" AS SDPTC__payment_terms, "SDRYIN" AS SDRYIN_payment_instrument, "SDDTBS" AS SDDTBS_based_on_date,  ...
#
# -- INTO Integration.ARCPDTA71_F4211_<instert_friendly_name_here>
#
# FROM
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		SDKCOO, SDDOCO, SDDCTO, CAST((SDLNID)/1000.0 AS DEC(15,3)) AS SDLNID, SDSFXO, SDSFX, SDMCU, SDCO, SDOKCO, SDOORN, SDOCTO, CAST((SDOGNO)/1000.0 AS DEC(15,3)) AS SDOGNO, SDRKCO, SDRORN, SDRCTO, CAST((SDRLLN)/1000.0 AS DEC(15,3)) AS SDRLLN, SDDMCT, SDDMCS, SDBALU, SDAN8, SDSHAN, SDMKFR, SDBTAN, SDPA8, CASE WHEN SDDRQJ IS NOT NULL THEN DATE(DIGITS(DEC(SDDRQJ+ 1900000,7,0))) ELSE NULL END AS SDDRQJ, CASE WHEN SDTRDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDTRDJ+ 1900000,7,0))) ELSE NULL END AS SDTRDJ, CASE WHEN SDPDDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDPDDJ+ 1900000,7,0))) ELSE NULL END AS SDPDDJ, CASE WHEN SDOPDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDOPDJ+ 1900000,7,0))) ELSE NULL END AS SDOPDJ, CASE WHEN SDADDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDADDJ+ 1900000,7,0))) ELSE NULL END AS SDADDJ, CASE WHEN SDIVD IS NOT NULL THEN DATE(DIGITS(DEC(SDIVD+ 1900000,7,0))) ELSE NULL END AS SDIVD, CASE WHEN SDCNDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDCNDJ+ 1900000,7,0))) ELSE NULL END AS SDCNDJ, CASE WHEN SDDGL IS NOT NULL THEN DATE(DIGITS(DEC(SDDGL+ 1900000,7,0))) ELSE NULL END AS SDDGL, CASE WHEN SDRSDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDRSDJ+ 1900000,7,0))) ELSE NULL END AS SDRSDJ, CASE WHEN SDPEFJ IS NOT NULL THEN DATE(DIGITS(DEC(SDPEFJ+ 1900000,7,0))) ELSE NULL END AS SDPEFJ, CASE WHEN SDPPDJ IS NOT NULL THEN DATE(DIGITS(DEC(SDPPDJ+ 1900000,7,0))) ELSE NULL END AS SDPPDJ, CASE WHEN SDRQSJ IS NOT NULL THEN DATE(DIGITS(DEC(SDRQSJ+ 1900000,7,0))) ELSE NULL END AS SDRQSJ, CASE WHEN SDADLJ IS NOT NULL THEN DATE(DIGITS(DEC(SDADLJ+ 1900000,7,0))) ELSE NULL END AS SDADLJ, SDDRQT, SDRSDT, SDVR01, SDVR02, SDVR03, SDITM, SDLITM, SDAITM, SDMERL, SDLOCN, SDLOTN, SDFRGD, SDTHGD, SDACGD, CAST((SDFRMP)/1000.0 AS DEC(15,3)) AS SDFRMP, CAST((SDTHRP)/1000.0 AS DEC(15,3)) AS SDTHRP, CAST((SDAPOT)/1000.0 AS DEC(15,3)) AS SDAPOT, SDEXDP, SDDSC1, SDDSC2, SDLNTY, SDNXTR, SDLTTR, SDHOLD, SDEMCU, SDHDBU, SDDMBU, SDRLIT, CAST((SDKTLN)/1000.0 AS DEC(15,3)) AS SDKTLN, CAST((SDCPNT)/10.0 AS DEC(15,1)) AS SDCPNT, SDRKIT, SDKTP, SDCSID, SDSRP1, SDSRP2, SDSRP3, SDSRP4, SDSRP5, SDPRP1, SDPRP2, SDPRP3, SDPRP4, SDPRP5, SDDMS1, SDDMT1, SDUOM, SDUORG, SDSOQS, SDSOBK, SDSOCN, SDSONE, SDUOPN, SDQTYT, SDQRLV, SDCOMM, SDOTQY, SDBCRC, CAST((SDUPRC)/10000.0 AS DEC(15,4)) AS SDUPRC, CAST((SDAEXP)/100.0 AS DEC(15,2)) AS SDAEXP, CAST((SDAOPN)/100.0 AS DEC(15,2)) AS SDAOPN, SDPROV, SDTPC, SDAPUM, CAST((SDLPRC)/10000.0 AS DEC(15,4)) AS SDLPRC, CAST((SDUNCS)/10000.0 AS DEC(15,4)) AS SDUNCS, CAST((SDECST)/100.0 AS DEC(15,2)) AS SDECST, SDCSTO, CAST((SDTCST)/10000.0 AS DEC(15,4)) AS SDTCST, SDINMG, SDPTC, SDRYIN, SDDTBS, CAST((SDTRDC)/1000.0 AS DEC(15,3)) AS SDTRDC, CAST((SDFUN2)/10000.0 AS DEC(15,4)) AS SDFUN2, SDASN, SDOSEQ, SDPRGR, SDCLVL, CAST((SDDSPR)/10000.0 AS DEC(15,4)) AS SDDSPR, SDDSFT, SDFAPP, CAST((SDCADC)/1000.0 AS DEC(15,3)) AS SDCADC, SDKCO, SDDOC, SDDCT, SDODOC, SDODCT, SDOKC, SDPSN, SDDELN, SDPTSK, SDTAX1, SDTXA1, SDEXR1, SDATXT, SDPRIO, SDRESL, SDBACK, SDSBAL, SDAPTS, SDLOB, SDEUSE, SDDTYS, SDNTR, SDVEND, SDANBY, SDCARS, SDMOT, SDCOT, SDROUT, SDSTOP, SDZON, SDCNID, SDFRTH, SDAFT, SDFUF1, SDFRTC, SDFRAT, SDRATT, SDSHCM, SDSHCN, SDSHPN, SDSERN, SDLDNM, SDSHMT, SDTKNR, SDTKTM, CASE WHEN SDTKDA IS NOT NULL THEN DATE(DIGITS(DEC(SDTKDA+ 1900000,7,0))) ELSE NULL END AS SDTKDA, SDUOM1, SDPQOR, SDUOM2, SDSQOR, SDUOM4, CAST((SDITWT)/10000.0 AS DEC(15,4)) AS SDITWT, SDWTUM, CAST((SDITVL)/10000.0 AS DEC(15,4)) AS SDITVL, SDVLUM, SDRPRC, SDORPR, SDORP, SDCMGP, SDCMGL, SDGLC, SDCTRY, SDFY, SDSTTS, SDSO01, SDSO02, SDSO03, SDSO04, SDSO05, SDSO06, SDSO07, SDSO08, SDSO09, SDSO10, SDSO11, SDSO12, SDSO13, SDSO14, SDSO15, SDSO16, SDSO17, SDSO18, SDSO19, SDSO20, SDSLSM, CAST((SDSLCM)/1000.0 AS DEC(15,3)) AS SDSLCM, SDSLM2, CAST((SDSLC2)/1000.0 AS DEC(15,3)) AS SDSLC2, SDACOM, SDCMCG, SDRCD, CAST((SDGRWT)/10000.0 AS DEC(15,4)) AS SDGRWT, SDGWUM, SDANI, SDAID, SDOMCU, SDOBJ, SDSUB, SDLT, SDSBL, SDSBLT, SDLCOD, SDUPC1, SDUPC2, SDUPC3, SDSWMS, SDUNCD, SDCRMD, SDCRCD, SDCRR, CAST((SDFPRC)/10000.0 AS DEC(15, ...
#
# 	FROM
# 		ARCPDTA71.F4211
# --    WHERE
# --        <insert custom code here>
# --    ORDER BY
# --        <insert custom code here>
# ')
#
# --------------------------------------------------------------------------------

# %%
dff
# Out:
#      ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                   1      SDKCOO  Order Company. . . . . . . . . . . . . .
# 1                   2      SDDOCO  Order Number . . . . . . . . . . . . . .
# 2                   3      SDDCTO  Order Type . . . . . . . . . . . . . . .
# 3                   4      SDLNID  Line Number. . . . . . . . . . . . . . .
# 4                   5      SDSFXO  Order Suffix . . . . . . . . . . . . . .
# 5                   6       SDSFX  Pay Item . . . . . . . . . . . . . . . .
# 6                   7       SDMCU  Business Unit. . . . . . . . . . . . . .
# 7                   8        SDCO  Company. . . . . . . . . . . . . . . . .
# 8                   9      SDOKCO  Original Order Document Company. . . . .
# 9                  10      SDOORN  Original Order Number. . . . . . . . . .
# 10                 11      SDOCTO  Original Order Type. . . . . . . . . . .
# 11                 12      SDOGNO  Original Line Number . . . . . . . . . .
# 12                 13      SDRKCO  Related Order Key Company. . . . . . . .
# 13                 14      SDRORN  Related Order Number . . . . . . . . . .
# 14                 15      SDRCTO  Related Order Type . . . . . . . . . . .
# 15                 16      SDRLLN  Related PO/SO Line Number. . . . . . . .
# 16                 17      SDDMCT  Agreement Nbr. . . . . . . . . . . . . .
# 17                 18      SDDMCS   Agreement Supplement. . . . .. . . . ..
# 18                 19      SDBALU  Contract Balances Updated Y/N. . . . . .
# 19                 20       SDAN8  Address Number . . . . . . . . . . . . .
# 20                 21      SDSHAN  Ship To. . . . . . . . . . . . . . . . .
# 21                 22      SDMKFR  Mark-for . . . . . . . . . . . . . . . .
# 22                 23      SDBTAN  Bill To Number . . . . . . . . . . . . .
# 23                 24       SDPA8  Parent Number. . . . . . . . . . . . . .
# 24                 25      SDDRQJ  Requested. . . . . . . . . . . . . . . .
# 25                 26      SDTRDJ  Order Date . . . . . . . . . . . . . . .
# 26                 27      SDPDDJ  Scheduled Pick . . . . . . . . . . . . .
# 27                 28      SDOPDJ  Original Promised. . . . . . . . . . . .
# 28                 29      SDADDJ  Actual Ship. . . . . . . . . . . . . . .
# 29                 30       SDIVD  Invoice Date . . . . . . . . . . . . . .
# ..                ...         ...                                       ...
# 262               263      SDWOCT  Order Type . . . . . . . . . . . . . . .
# 263               264      SDMMCU  Branch . . . . . . . . . . . . . . . . .
# 264               265      SDSOQO  Original Quantity. . . . . . . . . . . .
# 265               266      SDBOLA  Bill of Lading Number. . . . . . . . . .
# 266               267      SDSO21   Exchange Rate Date Flag . . .. . . . ..
# 267               268      SDSO22  Future Line Printed. . . . . . . . . . .
# 268               269      SDSO23  Sales Order Status 23. . . . . . . . . .
# 269               270      SDSO24  Sales Order Status 24. . . . . . . . . .
# 270               271      SDSO25  Sales Order Status 25. . . . . . . . . .
# 271               272      SDSO26  Sales Order Status 26. . . . . . . . . .
# 272               273      SDSO27  Sales Order Status 27. . . . . . . . . .
# 273               274      SDSO28  Sales Order Status 28. . . . . . . . . .
# 274               275      SDSO29  Sales Order Status 29. . . . . . . . . .
# 275               276      SDSO30  Sales Order Status 30. . . . . . . . . .
# 276               277      SDABR1  Enh Subledger Code 1 . . . . . . . . . .
# 277               278      SDABT1   Enh Subledger Type 1. . . . .. . .. . .
# 278               279      SDABR2  Enh Subledger Code 2 . . . . . . . . . .
# 279               280      SDABT2   Enh Subledger Type 2. . . . .. . .. . .
# 280               281      SDABR3  Enh Subledger Code 3 . . . . . . . . . .
# 281               282      SDABT3   Enh Subledger Type 3. . . . .. . .. . .
# 282               283      SDABR4   Enh Subledger Code 4. . . . .. . .. . .
# 283               284      SDABT4   Enh Subledger Type 4. . . . .. . .. . .
# 284               285      SDTORG  Transaction Originator . . . . . . . . .
# 285               286      SDUSER  User ID. . . . . . . . . . . . . . . . .
# 286               287       SDPID  Program ID . . . . . . . . . . . . . . .
# 287               288      SDJOBN  Work Station ID. . . . . . . . . . . . .
# 288               289      SDUPMJ  Date Updated . . . . . . . . . . . . . .
# 289               290      SDTDAY  Time of Day. . . . . . . . . . . . . . .
# 290               291      SDUPAJ  Date Added . . . . . . . . . . . . . . .
# 291               292      SDTENT  Time Entered . . . . . . . . . . . . . .
#
#     DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type  data_type  \
# 0        CHAR       5                NaN      KCOO              A        2.0
# 1     NUMERIC       8                8.0      DOCO              S        9.0
# 2        CHAR       2                NaN      DCTO              A        2.0
# 3     DECIMAL       6                6.0      LNID              P        9.0
# 4        CHAR       3                NaN      SFXO              A        2.0
# 5        CHAR       3                NaN       SFX              A        2.0
# 6        CHAR      12                NaN       MCU              A        2.0
# 7        CHAR       5                NaN        CO              A        2.0
# 8        CHAR       5                NaN      OKCO              A        2.0
# 9        CHAR       8                NaN      OORN              A        2.0
# 10       CHAR       2                NaN      OCTO              A        2.0
# 11    DECIMAL       7                7.0      OGNO              P        9.0
# 12       CHAR       5                NaN      RKCO              A        2.0
# 13       CHAR       8                NaN      RORN              A        2.0
# 14       CHAR       2                NaN      RCTO              A        2.0
# 15    DECIMAL       7                7.0      RLLN              P        9.0
# 16       CHAR      12                NaN      DMCT              A        2.0
# 17    NUMERIC       3                3.0      DMCS              S        9.0
# 18       CHAR       1                NaN      BALU              A        1.0
# 19    NUMERIC       8                8.0       AN8              S        9.0
# 20    NUMERIC       8                8.0      SHAN              S        9.0
# 21    NUMERIC       8                8.0      MKFR              S        9.0
# 22    NUMERIC       8                8.0      BTAN              S        9.0
# 23    NUMERIC       8                8.0       PA8              S        9.0
# 24    NUMERIC       6                6.0      DRQJ              S       11.0
# 25    NUMERIC       6                6.0      TRDJ              S       11.0
# 26    NUMERIC       6                6.0      PDDJ              S       11.0
# 27    NUMERIC       6                6.0      OPDJ              S       11.0
# 28    NUMERIC       6                6.0      ADDJ              S       11.0
# 29    NUMERIC       6                6.0       IVD              S       11.0
# ..        ...     ...                ...       ...            ...        ...
# 262      CHAR       2                NaN      WOCT              A        2.0
# 263      CHAR      12                NaN      MMCU              A        2.0
# 264   DECIMAL      15               15.0      SOQO              P        9.0
# 265   NUMERIC      17               17.0      BOLA              S        9.0
# 266      CHAR       1                NaN      SO21              A        1.0
# 267      CHAR       1                NaN      SO22              A        1.0
# 268      CHAR       1                NaN      SO23              A        1.0
# 269      CHAR       1                NaN      SO24              A        1.0
# 270      CHAR       1                NaN      SO25              A        1.0
# 271      CHAR       1                NaN      SO26              A        1.0
# 272      CHAR       1                NaN      SO27              A        1.0
# 273      CHAR       1                NaN      SO28              A        1.0
# 274      CHAR       1                NaN      SO29              A        1.0
# 275      CHAR       1                NaN      SO30              A        1.0
# 276      CHAR      12                NaN      ABR1              A        2.0
# 277      CHAR       1                NaN      ABT1              A        1.0
# 278      CHAR      12                NaN      ABR2              A        2.0
# 279      CHAR       1                NaN      ABT2              A        1.0
# 280      CHAR      34                NaN      ABR3              A        2.0
# 281      CHAR       1                NaN      ABT3              A        1.0
# 282      CHAR      34                NaN      ABR4              A        2.0
# 283      CHAR       1                NaN      ABT4              A        1.0
# 284      CHAR      10                NaN      TORG              A        2.0
# 285      CHAR      10                NaN      USER              A        2.0
# 286      CHAR      10                NaN       PID              A        2.0
# 287      CHAR      10                NaN      JOBN              A        2.0
# 288   NUMERIC       6                6.0      UPMJ              S       11.0
# 289   DECIMAL       6                6.0      TDAY              P        9.0
# 290   NUMERIC       6                6.0      UPAJ              S       11.0
# 291   NUMERIC       6                6.0      TENT              S        9.0
#
#      data_item_size  display_decimals  \
# 0               5.0               0.0
# 1               8.0               0.0
# 2               2.0               0.0
# 3               6.0               3.0
# 4               3.0               0.0
# 5               3.0               0.0
# 6              12.0               0.0
# 7               5.0               0.0
# 8               5.0               0.0
# 9               8.0               0.0
# 10              2.0               0.0
# 11              7.0               3.0
# 12              5.0               0.0
# 13              8.0               0.0
# 14              2.0               0.0
# 15              7.0               3.0
# 16             12.0               0.0
# 17              3.0               0.0
# 18              1.0               0.0
# 19              8.0               0.0
# 20              8.0               0.0
# 21              8.0               0.0
# 22              8.0               0.0
# 23              8.0               0.0
# 24              6.0               0.0
# 25              6.0               0.0
# 26              6.0               0.0
# 27              6.0               0.0
# 28              6.0               0.0
# 29              6.0               0.0
# ..              ...               ...
# 262             2.0               0.0
# 263            12.0               0.0
# 264            15.0               0.0
# 265            17.0               0.0
# 266             1.0               0.0
# 267             1.0               0.0
# 268             1.0               0.0
# 269             1.0               0.0
# 270             1.0               0.0
# 271             1.0               0.0
# 272             1.0               0.0
# 273             1.0               0.0
# 274             1.0               0.0
# 275             1.0               0.0
# 276            12.0               0.0
# 277             1.0               0.0
# 278            12.0               0.0
# 279             1.0               0.0
# 280            34.0               0.0
# 281             1.0               0.0
# 282            34.0               0.0
# 283             1.0               0.0
# 284            10.0               0.0
# 285            10.0               0.0
# 286            10.0               0.0
# 287            10.0               0.0
# 288             6.0               0.0
# 289             6.0               0.0
# 290             6.0               0.0
# 291             6.0               0.0
#
#                               row_description            row_description_final
# 0    Order Number Document Company. . . . . .    order_number_document_company
# 1    Order Number . . . . . . . . . . . . . .                salesorder_number
# 2    Order Type . . . . . . . . . . . . . . .                       order_type
# 3    Line Number. . . . . . . . . . . . . . .                      line_number
# 4    Order Suffix . . . . . . . . . . . . . .                     order_suffix
# 5    Pay Item . . . . . . . . . . . . . . . .                         pay_item
# 6    Business Unit. . . . . . . . . . . . . .                    business_unit
# 7    Company. . . . . . . . . . . . . . . . .                          company
# 8    Original Order Document Company. . . . .  original_order_document_company
# 9    Original Order Number. . . . . . . . . .            original_order_number
# 10   Original Order Type. . . . . . . . . . .              original_order_type
# 11   Original Line Number . . . . . . . . . .             original_line_number
# 12   Related Order Key Company. . . . . . . .        related_order_key_company
# 13   Related Order Number . . . . . . . . . .             related_order_number
# 14   Related Order Type . . . . . . . . . . .               related_order_type
# 15   Related PO/SO Line Number. . . . . . . .         related_poso_line_number
# 16   Contract Number. . . . . . . . . . . . .                  contract_number
# 17   Contract Supplement. . . . . . . . . . .              contract_supplement
# 18   Contract Balances Updated Y/N. . . . . .     contract_balances_updated_yn
# 19   Address Number . . . . . . . . . . . . .                           billto
# 20   Ship To. . . . . . . . . . . . . . . . .                           shipto
# 21   Mark-for . . . . . . . . . . . . . . . .                          markfor
# 22   Bill To Number . . . . . . . . . . . . .                   bill_to_number
# 23   Parent Number. . . . . . . . . . . . . .                    parent_number
# 24   Requested. . . . . . . . . . . . . . . .                        requested
# 25   Order Date . . . . . . . . . . . . . . .                       order_date
# 26   Scheduled Pick . . . . . . . . . . . . .                   scheduled_pick
# 27   Original Promised. . . . . . . . . . . .                original_promised
# 28   Actual Ship. . . . . . . . . . . . . . .                      actual_ship
# 29   Invoice Date . . . . . . . . . . . . . .                     invoice_date
# ..                                        ...                              ...
# 262  Order Type . . . . . . . . . . . . . . .                       order_type
# 263  Branch . . . . . . . . . . . . . . . . .                           branch
# 264  Original Quantity. . . . . . . . . . . .                original_quantity
# 265  Bill of Lading Number. . . . . . . . . .            bill_of_lading_number
# 266  Exchange Rate Date Flag . . . . . . . ..          exchange_rate_date_flag
# 267  Future Line Printed. . . . . . . . . . .              future_line_printed
# 268  Sales Order Status 23. . . . . . . . . .            sales_order_status_23
# 269  Sales Order Status 24. . . . . . . . . .            sales_order_status_24
# 270  Sales Order Status 25. . . . . . . . . .            sales_order_status_25
# 271  Sales Order Status 26. . . . . . . . . .            sales_order_status_26
# 272  Sales Order Status 27. . . . . . . . . .            sales_order_status_27
# 273  Sales Order Status 28. . . . . . . . . .            sales_order_status_28
# 274  Sales Order Status 29. . . . . . . . . .            sales_order_status_29
# 275  Sales Order Status 30. . . . . . . . . .            sales_order_status_30
# 276  Enh Subledger Code 1 . . . . . . . . . .             enh_subledger_code_1
# 277  Enh Subledger Type 1. . . . . . . .. . .             enh_subledger_type_1
# 278  Enh Subledger Code 2 . . . . . . . . . .             enh_subledger_code_2
# 279  Enh Subledger Type 2. . . . . . . .. . .             enh_subledger_type_2
# 280  Enh Subledger Code 3 . . . . . . . . . .             enh_subledger_code_3
# 281  Enh Subledger Type 3. . . . . . . .. . .             enh_subledger_type_3
# 282  Enh Subledger Code 4. . . . . . . .. . .             enh_subledger_code_4
# 283  Enh Subledger Type 4. . . . . . . .. . .             enh_subledger_type_4
# 284  Transaction Originator . . . . . . . . .           transaction_originator
# 285  User ID. . . . . . . . . . . . . . . . .                          user_id
# 286  Program ID . . . . . . . . . . . . . . .                       program_id
# 287  Work Station ID. . . . . . . . . . . . .                  work_station_id
# 288  Date Updated . . . . . . . . . . . . . .                     date_updated
# 289  Time of Day. . . . . . . . . . . . . . .                      time_of_day
# 290  Date Added . . . . . . . . . . . . . . .                       date_added
# 291  Time Entered . . . . . . . . . . . . . .                     time_entered
#
# [292 rows x 13 columns]

# %%
# %time df_table_map = pd.read_sql_query(sql_table_map, engine);
# Out:
# CPU times: user 86.9 ms, sys: 412 µs, total: 87.3 ms
# Wall time: 4.16 s

# %% [markdown]
# ### Next steps...
# Add SQL to SQL Tools data package

# %%
df_table_map
# Out:
#   SDKCOO_order_number_document_company  SDDOCO_salesorder_number  \
# 0                                02000                 1056020.0
# 1                                02000                 1056026.0
# 2                                02000                 1056028.0
# 3                                02000                 1056035.0
# 4                                02000                 1056057.0
#
#   SDDCTO_order_type  SDLNID_line_number SDSFXO_order_suffix SDSFX__pay_item  \
# 0                CA                 3.0                 000
# 1                CA                 2.0                 000
# 2                CA                 2.0                 000
# 3                CA                 2.0                 000
# 4                CA                 2.0                 000
#
#   SDMCU__business_unit SDCO___company SDOKCO_original_order_document_company  \
# 0         020099990011          02000
# 1         020099990012          02000
# 2         020099990016          02000
# 3         020099990011          02000
# 4         020001000000          02000
#
#   SDOORN_original_order_number         ...           \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#           SDABR4_enh_subledger_code_4  SDABT4_enh_subledger_type_4  \
# 0
# 1
# 2
# 3
# 4
#
#   SDTORG_transaction_originator SDUSER_user_id SDPID__program_id  \
# 0                    SCHART         ARCONA            X5723
# 1                    SMAT05         ARCONA            X5723
# 2                    VPENNE         ARCONA            X5723
# 3                    NROY           ARCONA            X5723
# 4                    PCON01         ARCONA            X5723
#
#    SDJOBN_work_station_id SDUPMJ_date_updated  SDTDAY_time_of_day  \
# 0              ECS_PNDSRV          2018-03-16            144439.0
# 1              ECS_PNDSRV          2018-03-16            150701.0
# 2              ECS_PNDSRV          2018-03-16            151050.0
# 3              ECS_PNDSRV          2018-03-16            152742.0
# 4              ECS_PNDSRV          2018-03-16            155711.0
#
#   SDUPAJ_date_added  SDTENT_time_entered
# 0              None                  0.0
# 1              None                  0.0
# 2              None                  0.0
# 3              None                  0.0
# 4              None                  0.0
#
# [5 rows x 292 columns]
