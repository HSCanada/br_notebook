# %% [markdown]
# # JDE ETL Source Design
# ## Goal:  Generate source SQL with friendly names and built-in data Conversion
# 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals
# 2. Pull *Specific* Table fields
# 3. Create SQL mapiing pull with data-conversion

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import os, sys
import warnings

warnings.filterwarnings('ignore')

# %%
from decouple import config
config.search_path = '/home/jovyan/work'

# %% [markdown]
# ### Connect to SQL DB

# %%
engine = create_engine(config('DATABASE_URL'))

# %% [markdown]
# ### 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals

# %%
sql_field_meta_server = 'ESYS_PROD'
sql_field_meta_lib = 'ARCPCOM71'

# %%
sql_field_meta = '''
SELECT 
	RTRIM("FRDTAI")				AS data_item
	,"FRDTAT"					AS data_item_type
	,"FROWTP"					AS data_type
	,"FRDTAS"					AS data_item_size
	,ISNULL("FRCDEC", 0)		AS display_decimals
	,ISNULL("FRDSCR", 'zNA')	AS row_description 
    
FROM 

    OPENQUERY ({}, '

	SELECT
		t.FRDTAI
		,FRDTAT
		,FROWTP
		,FRDTAS
		,FRCDEC
		,FRDSCR
	FROM
		{}.F9210 t
		LEFT JOIN {}.F9202 d
		ON t.FRDTAI = d.FRDTAI AND
			d.FRLNGP = '' '' AND
			d.FRSYR = '' ''  
')

'''.format(sql_field_meta_server, sql_field_meta_lib, sql_field_meta_lib)

# %%
print(sql_field_meta)
# Out:
# SELECT
# 	RTRIM("FRDTAI")				AS data_item
# 	,"FRDTAT"					AS data_item_type
# 	,"FROWTP"					AS data_type
# 	,"FRDTAS"					AS data_item_size
# 	,ISNULL("FRCDEC", 0)		AS display_decimals
# 	,ISNULL("FRDSCR", 'zNA')	AS row_description
#
# FROM
#
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		t.FRDTAI
# 		,FRDTAT
# 		,FROWTP
# 		,FRDTAS
# 		,FRCDEC
# 		,FRDSCR
# 	FROM
# 		ARCPCOM71.F9210 t
# 		LEFT JOIN ARCPCOM71.F9202 d
# 		ON t.FRDTAI = d.FRDTAI AND
# 			d.FRLNGP = '' '' AND
# 			d.FRSYR = '' ''
# ')

# %%
df_field_meta = pd.read_sql_query(sql_field_meta, engine);

# %%
df_field_meta.iloc[:,[2,3,4]] = df_field_meta.iloc[:,[2,3,4]].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_field_meta.fillna(value=0,inplace=True)

# %% [markdown]
# ### 2. Pull *Specific* Table fields

# %% [markdown]
# #  Set Table Name HERE

# %%
sql_table = 'F5698'
#sql_table = 'F060116'
#sql_table = 'RPTRULES'

sql_link_server = 'ESYS_PROD'
#sql_lib = 'ARCPTEL'
sql_lib = 'ARCPDTA71'
#sql_lib = 'ESEND'
#sql_lib = 'HSIPDTA71'


stage_db_schema = 'Integration.'
convert_julian_date = True

# [ARC | HSI] [P | D] [DTA | CDC] [ 71 | 94]

# %%
sql_table_fields = '''

SELECT * from OPENQUERY ({}, '
	SELECT
		*
	FROM
		QSYS2.SYSCOLUMNS
	WHERE
        TABLE_SCHEMA = ''{}'' AND
		TABLE_NAME in( ''{}'')
    ORDER BY 
        ORDINAL_POSITION
')

''' .format(sql_link_server, sql_lib, sql_table)

# %%
#print (sql_table_fields)

# %%
df_table_fields = pd.read_sql_query(sql_table_fields, engine);

# %% [markdown]
# #### Join table fields with data dictionary meta-data

# %%
#df_table_fields

# %%
df_table_fields = df_table_fields[['ORDINAL_POSITION', 'COLUMN_NAME', 'COLUMN_TEXT', 'DATA_TYPE','LENGTH', 'NUMERIC_PRECISION']]

# %%
df_table_fields['data_item'] = df_table_fields.COLUMN_NAME.str[2:]

# %%
df_table_fields.head()
# Out:
#    ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                 1      QT$RTP  Record Type. . . . . . . . . . . . . . .
# 1                 2       QTITM  Item Number (Short). . . . . . . . . . .
# 2                 3      QTLITM  2nd Item Number. . . . . . . . . . . . .
# 3                 4      QT$AJP  Adjustment Percent . . . . . . . . . . .
# 4                 5      QT$AJD  Adjustment Dollar. . . . . . . . . . . .
#
#   DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item
# 0      CHAR       2                NaN      $RTP
# 1   NUMERIC       8                8.0       ITM
# 2      CHAR      25                NaN      LITM
# 3   DECIMAL       5                5.0      $AJP
# 4   NUMERIC      15               15.0      $AJD

# %%
df_table_fields.data_item.unique()
# Out:
# array(['$RTP', 'ITM', 'LITM', '$AJP', '$AJD', '$USG', 'EFFF', 'EXDE',
#        '$FLD', 'AC10', '$SEQ', 'SIC', 'AC01', 'AC02', 'AC03', 'AC04',
#        'AC05', 'AC06', '$FT1', '$FT2', '$FT3', '$FT4', '$FT5', '$FT6',
#        '$FT7', '$FT8', '$FT9', '$FT0', 'CRTU', 'PGM', 'CRDJ', 'CRTM',
#        'USER', 'PID', 'JOBN', 'UPMJ', 'TDAY'], dtype=object)

# %%
dff = pd.merge(df_table_fields,df_field_meta,on='data_item', how='left')

# %% [markdown]
# #### Cleanup final field name
# remove trailing dots, special characters, and converto to lower_case

# %%
dff['row_description_final'] = dff.row_description.str.rstrip('. ').str.replace(r'%','pct').str.replace(r'$','amt').str.replace(r'[^0-9|a-z|" "]','', case=False).str.replace('  ',' ').str.lower().str.replace(' ','_')

# %% [markdown]
# #### Override with Defaults

# %%
dff['row_description_final'][dff['data_item']=='LITM'] = 'item_number'
dff['row_description_final'][dff['data_item']=='AN8'] = 'billto'
dff['row_description_final'][dff['data_item']=='SHAN'] = 'shipto'
dff['row_description_final'][dff['data_item']=='DOCO'] = 'salesorder_number'

# %% [markdown]
# ### 3. Create SQL mapping pull with data-conversion

# %%
dff.groupby(['DATA_TYPE', 'data_type','display_decimals'])['ORDINAL_POSITION'].count()
# Out:
# DATA_TYPE  data_type  display_decimals
# CHAR       1.0        0.0                  1
#            2.0        0.0                 21
# DECIMAL    9.0        0.0                  1
#                       4.0                  1
# NUMERIC    9.0        0.0                  9
#            11.0       0.0                  4
# Name: ORDINAL_POSITION, dtype: int64

# %%
dff
# Out:
#     ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                  1      QT$RTP  Record Type. . . . . . . . . . . . . . .
# 1                  2       QTITM  Item Number (Short). . . . . . . . . . .
# 2                  3      QTLITM  2nd Item Number. . . . . . . . . . . . .
# 3                  4      QT$AJP  Adjustment Percent . . . . . . . . . . .
# 4                  5      QT$AJD  Adjustment Dollar. . . . . . . . . . . .
# 5                  6      QT$USG  Adjustment Usage . . . . . . . . . . . .
# 6                  7      QTEFFF  Effective From Date  . . . . . . . . . .
# 7                  8      QTEXDE  Expiration Date. . . . . . . . . . . . .
# 8                  9      QT$FLD  Data Field Name. . . . . . . . . . . . .
# 9                 10      QTAC10   Division Code . . . . . . . .. . . . ..
# 10                11      QT$SEQ   Sequence / ID#. . . . . . . .. . . .. .
# 11                12       QTSIC  Speciality . . . . . . . . . . . . . . .
# 12                13      QTAC01  Customer Profession. . . . . . . . . . .
# 13                14      QTAC02  Customer Sub Profession. . . . . . . . .
# 14                15      QTAC03  Type of Paying Customer. . . . . . . . .
# 15                16      QTAC04  Practice Type. . . . . . . . . . . . . .
# 16                17      QTAC05  A/P Check Routing Code . . . . . . . . .
# 17                18      QTAC06  Category Code - Address 06 . . . . . . .
# 18                19      QT$FT1  Future Use 1 . . . . . . . . . . . . . .
# 19                20      QT$FT2  Future Use 2 . . . . . . . . . . . . . .
# 20                21      QT$FT3  Future Use 3 . . . . . . . . . . . . . .
# 21                22      QT$FT4  Future Use 4 . . . . . . . . . . . . . .
# 22                23      QT$FT5  Future Use 5 . . . . . . . . . . . . . .
# 23                24      QT$FT6  Future Use 6 . . . . . . . . . . . . . .
# 24                25      QT$FT7  Future Use 7 . . . . . . . . . . . . . .
# 25                26      QT$FT8  Future Use 8 . . . . . . . . . . . . . .
# 26                27      QT$FT9  Future Use 9 . . . . . . . . . . . . . .
# 27                28      QT$FT0  Future Use 0 . . . . . . . . . . . . . .
# 28                29      QTCRTU  Created by User. . . . . . . . . . . . .
# 29                30       QTPGM  Program Name . . . . . . . . . . . . . .
# 30                31      QTCRDJ  Creation Date. . . . . . . . . . . . . .
# 31                32      QTCRTM  Creation Time. . . . . . . . . . . . . .
# 32                33      QTUSER  User ID. . . . . . . . . . . . . . . . .
# 33                34       QTPID  Program ID . . . . . . . . . . . . . . .
# 34                35      QTJOBN  Work Station ID. . . . . . . . . . . . .
# 35                36      QTUPMJ  Date Updated . . . . . . . . . . . . . .
# 36                37      QTTDAY  Time of Day. . . . . . . . . . . . . . .
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type  data_type  \
# 0       CHAR       2                NaN      $RTP              A        2.0
# 1    NUMERIC       8                8.0       ITM              S        9.0
# 2       CHAR      25                NaN      LITM              A        2.0
# 3    DECIMAL       5                5.0      $AJP              P        9.0
# 4    NUMERIC      15               15.0      $AJD              S        9.0
# 5       CHAR       1                NaN      $USG              A        1.0
# 6    NUMERIC       6                6.0      EFFF              S       11.0
# 7    NUMERIC       6                6.0      EXDE              S       11.0
# 8       CHAR       6                NaN      $FLD              A        2.0
# 9       CHAR       3                NaN      AC10              A        2.0
# 10   NUMERIC       8                8.0      $SEQ              S        9.0
# 11      CHAR      10                NaN       SIC              A        2.0
# 12      CHAR       3                NaN      AC01              A        2.0
# 13      CHAR       3                NaN      AC02              A        2.0
# 14      CHAR       3                NaN      AC03              A        2.0
# 15      CHAR       3                NaN      AC04              A        2.0
# 16      CHAR       3                NaN      AC05              A        2.0
# 17      CHAR       3                NaN      AC06              A        2.0
# 18   NUMERIC      15               15.0      $FT1              S        9.0
# 19   NUMERIC      15               15.0      $FT2              S        9.0
# 20   NUMERIC      15               15.0      $FT3              S        9.0
# 21   NUMERIC      15               15.0      $FT4              S        9.0
# 22   NUMERIC      15               15.0      $FT5              S        9.0
# 23      CHAR      15                NaN      $FT6              A        2.0
# 24      CHAR      15                NaN      $FT7              A        2.0
# 25      CHAR      15                NaN      $FT8              A        2.0
# 26      CHAR      15                NaN      $FT9              A        2.0
# 27      CHAR      15                NaN      $FT0              A        2.0
# 28      CHAR      10                NaN      CRTU              A        2.0
# 29      CHAR      10                NaN       PGM              A        2.0
# 30   NUMERIC       6                6.0      CRDJ              S       11.0
# 31   NUMERIC       6                6.0      CRTM              S        9.0
# 32      CHAR      10                NaN      USER              A        2.0
# 33      CHAR      10                NaN       PID              A        2.0
# 34      CHAR      10                NaN      JOBN              A        2.0
# 35   NUMERIC       6                6.0      UPMJ              S       11.0
# 36   DECIMAL       6                6.0      TDAY              P        9.0
#
#     data_item_size  display_decimals  \
# 0              2.0               0.0
# 1              8.0               0.0
# 2             25.0               0.0
# 3              5.0               4.0
# 4             15.0               0.0
# 5              1.0               0.0
# 6              6.0               0.0
# 7              6.0               0.0
# 8              6.0               0.0
# 9              3.0               0.0
# 10             8.0               0.0
# 11            10.0               0.0
# 12             3.0               0.0
# 13             3.0               0.0
# 14             3.0               0.0
# 15             3.0               0.0
# 16             3.0               0.0
# 17             3.0               0.0
# 18            15.0               0.0
# 19            15.0               0.0
# 20            15.0               0.0
# 21            15.0               0.0
# 22            15.0               0.0
# 23            15.0               0.0
# 24            15.0               0.0
# 25            15.0               0.0
# 26            15.0               0.0
# 27            15.0               0.0
# 28            10.0               0.0
# 29            10.0               0.0
# 30             6.0               0.0
# 31             6.0               0.0
# 32            10.0               0.0
# 33            10.0               0.0
# 34            10.0               0.0
# 35             6.0               0.0
# 36             6.0               0.0
#
#                              row_description     row_description_final
# 0   Record Type. . . . . . . . . . . . . . .               record_type
# 1   Item Number (Short). . . . . . . . . . .         item_number_short
# 2   2nd Item Number. . . . . . . . . . . . .               item_number
# 3   Adjustment Percent . . . . . . . . . . .        adjustment_percent
# 4   Adjustment Dollar. . . . . . . . . . . .         adjustment_dollar
# 5   Adjustment Usage . . . . . . . . . . . .          adjustment_usage
# 6   Effective From Date  . . . . . . . . . .       effective_from_date
# 7   Expiration Date. . . . . . . . . . . . .           expiration_date
# 8   Data Field Name. . . . . . . . . . . . .           data_field_name
# 9   Division Code . . . . . . . . . . . . ..             division_code
# 10  Sequence / ID#. . . . . . . . . . . .. .               sequence_id
# 11  Speciality . . . . . . . . . . . . . . .                speciality
# 12  Customer Profession. . . . . . . . . . .       customer_profession
# 13  Customer Sub Profession. . . . . . . . .   customer_sub_profession
# 14  Type of Paying Customer. . . . . . . . .   type_of_paying_customer
# 15  Practice Type. . . . . . . . . . . . . .             practice_type
# 16  A/P Check Routing Code . . . . . . . . .     ap_check_routing_code
# 17  Category Code - Address 06 . . . . . . .  category_code_address_06
# 18  Future Use 1 . . . . . . . . . . . . . .              future_use_1
# 19  Future Use 2 . . . . . . . . . . . . . .              future_use_2
# 20  Future Use 3 . . . . . . . . . . . . . .              future_use_3
# 21  Future Use 4 . . . . . . . . . . . . . .              future_use_4
# 22  Future Use 5 . . . . . . . . . . . . . .              future_use_5
# 23  Future Use 6 . . . . . . . . . . . . . .              future_use_6
# 24  Future Use 7 . . . . . . . . . . . . . .              future_use_7
# 25  Future Use 8 . . . . . . . . . . . . . .              future_use_8
# 26  Future Use 9 . . . . . . . . . . . . . .              future_use_9
# 27  Future Use 0 . . . . . . . . . . . . . .              future_use_0
# 28  Created by User. . . . . . . . . . . . .           created_by_user
# 29  Program Name . . . . . . . . . . . . . .              program_name
# 30  Creation Date. . . . . . . . . . . . . .             creation_date
# 31  Creation Time. . . . . . . . . . . . . .             creation_time
# 32  User ID. . . . . . . . . . . . . . . . .                   user_id
# 33  Program ID . . . . . . . . . . . . . . .                program_id
# 34  Work Station ID. . . . . . . . . . . . .           work_station_id
# 35  Date Updated . . . . . . . . . . . . . .              date_updated
# 36  Time of Day. . . . . . . . . . . . . . .               time_of_day

# %%
def field_format_sel(col_name, col_type, col_dec):
    val =''

    if col_type == 9 :
        if col_dec > 0 :
            val = 'CAST(({})/{} AS DEC({},{})) AS {}'.format(col_name,10**col_dec,15,np.int(col_dec),col_name)
        else :
            val = col_name
    elif  col_type == 11 : 
        if convert_julian_date :
            val = 'CASE WHEN {} IS NOT NULL THEN DATE(DIGITS(DEC({}+ 1900000,7,0))) ELSE NULL END AS {}'.format(col_name, col_name, col_name)
        else :
            val = '{} as {}'.format(col_name,col_name)
    else : 
        val = col_name
    return val;

def field_format_map(col_name, col_descr, is_etl = False):
    val =''

    col_name_format = '{message:{fill}{align}{width}}'.format(message=col_name, fill='_', align='<', width=6)
    
    col_descr_format = col_descr
    if str.isdigit(col_descr_format[0]) :
        col_descr_format = "_" + col_descr_format
        
    if is_etl :
        val = '{}_{} AS {}'.format(col_name_format, col_descr_format, col_descr_format)
    else :
        val = '"{}" AS {}_{}'.format(col_name, col_name_format, col_descr_format)

    return val;



sql_field_map = ', '.join([field_format_map(x,y)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])

sql_field_etl = ', '.join([field_format_map(x,y,is_etl=True)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])
#
# ok
sql_field_sel = ', '.join([ field_format_sel(col_name, col_type, col_dec) \
                           for col_name, col_type, col_dec in zip(dff['COLUMN_NAME'], dff['data_type'], dff['display_decimals'])])

# %%
sql_field_sel
# Out:
# 'QT$RTP, QTITM, QTLITM, CAST((QT$AJP)/10000.0 AS DEC(15,4)) AS QT$AJP, QT$AJD, QT$USG, CASE WHEN QTEFFF IS NOT NULL THEN DATE(DIGITS(DEC(QTEFFF+ 1900000,7,0))) ELSE NULL END AS QTEFFF, CASE WHEN QTEXDE IS NOT NULL THEN DATE(DIGITS(DEC(QTEXDE+ 1900000,7,0))) ELSE NULL END AS QTEXDE, QT$FLD, QTAC10, QT$SEQ, QTSIC, QTAC01, QTAC02, QTAC03, QTAC04, QTAC05, QTAC06, QT$FT1, QT$FT2, QT$FT3, QT$FT4, QT$FT5, QT$FT6, QT$FT7, QT$FT8, QT$FT9, QT$FT0, QTCRTU, QTPGM, CASE WHEN QTCRDJ IS NOT NULL THEN DATE(DIGITS(DEC(QTCRDJ+ 1900000,7,0))) ELSE NULL END AS QTCRDJ, QTCRTM, QTUSER, QTPID, QTJOBN, CASE WHEN QTUPMJ IS NOT NULL THEN DATE(DIGITS(DEC(QTUPMJ+ 1900000,7,0))) ELSE NULL END AS QTUPMJ, QTTDAY'

# %%
sql_table_map = '''

--------------------------------------------------------------------------------
-- DROP TABLE Integration.{}_{}_<instert_friendly_name_here>
--------------------------------------------------------------------------------

SELECT 

    {} 
    {} 

-- INTO {}{}_{}_<instert_friendly_name_here>

FROM 
    OPENQUERY ({}, '

	SELECT
		{}

	FROM
		{}.{}
--    WHERE
--        <insert custom code here>
--    ORDER BY
--        <insert custom code here>
')

--------------------------------------------------------------------------------

'''.format(sql_lib, sql_table, 'Top 5', sql_field_map, stage_db_schema, sql_lib, sql_table, sql_link_server, sql_field_sel, sql_lib, sql_table)

# %% [markdown]
# ### Output Table
# 1. Use to create STAGE via SQL link table
# 1. Note that some Julian _JDT conversion will need to be converted Post

# %%
print(sql_table_map)
# Out:
# --------------------------------------------------------------------------------
# -- DROP TABLE Integration.ARCPDTA71_F5698_<instert_friendly_name_here>
# --------------------------------------------------------------------------------
#
# SELECT
#
#     Top 5
#     "QT$RTP" AS QT$RTP_record_type, "QTITM" AS QTITM__item_number_short, "QTLITM" AS QTLITM_item_number, "QT$AJP" AS QT$AJP_adjustment_percent, "QT$AJD" AS QT$AJD_adjustment_dollar, "QT$USG" AS QT$USG_adjustment_usage, "QTEFFF" AS QTEFFF_effective_from_date, "QTEXDE" AS QTEXDE_expiration_date, "QT$FLD" AS QT$FLD_data_field_name, "QTAC10" AS QTAC10_division_code, "QT$SEQ" AS QT$SEQ_sequence_id, "QTSIC" AS QTSIC__speciality, "QTAC01" AS QTAC01_customer_profession, "QTAC02" AS QTAC02_customer_sub_profession, "QTAC03" AS QTAC03_type_of_paying_customer, "QTAC04" AS QTAC04_practice_type, "QTAC05" AS QTAC05_ap_check_routing_code, "QTAC06" AS QTAC06_category_code_address_06, "QT$FT1" AS QT$FT1_future_use_1, "QT$FT2" AS QT$FT2_future_use_2, "QT$FT3" AS QT$FT3_future_use_3, "QT$FT4" AS QT$FT4_future_use_4, "QT$FT5" AS QT$FT5_future_use_5, "QT$FT6" AS QT$FT6_future_use_6, "QT$FT7" AS QT$FT7_future_use_7, "QT$FT8" AS QT$FT8_future_use_8, "QT$FT9" AS QT$FT9_future_use_9, "QT$FT0" AS QT$FT0_future_use_0, "QTCRTU" AS QTCRTU_created_by_user, "QTPGM" AS QTPGM__program_name, "QTCRDJ" AS QTCRDJ_creation_date, "QTCRTM" AS QTCRTM_creation_time, "QTUSER" AS QTUSER_user_id, "QTPID" AS QTPID__program_id, "QTJOBN" AS QTJOBN_work_station_id, "QTUPMJ" AS QTUPMJ_date_updated, "QTTDAY" AS QTTDAY_time_of_day
#
# -- INTO Integration.ARCPDTA71_F5698_<instert_friendly_name_here>
#
# FROM
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		QT$RTP, QTITM, QTLITM, CAST((QT$AJP)/10000.0 AS DEC(15,4)) AS QT$AJP, QT$AJD, QT$USG, CASE WHEN QTEFFF IS NOT NULL THEN DATE(DIGITS(DEC(QTEFFF+ 1900000,7,0))) ELSE NULL END AS QTEFFF, CASE WHEN QTEXDE IS NOT NULL THEN DATE(DIGITS(DEC(QTEXDE+ 1900000,7,0))) ELSE NULL END AS QTEXDE, QT$FLD, QTAC10, QT$SEQ, QTSIC, QTAC01, QTAC02, QTAC03, QTAC04, QTAC05, QTAC06, QT$FT1, QT$FT2, QT$FT3, QT$FT4, QT$FT5, QT$FT6, QT$FT7, QT$FT8, QT$FT9, QT$FT0, QTCRTU, QTPGM, CASE WHEN QTCRDJ IS NOT NULL THEN DATE(DIGITS(DEC(QTCRDJ+ 1900000,7,0))) ELSE NULL END AS QTCRDJ, QTCRTM, QTUSER, QTPID, QTJOBN, CASE WHEN QTUPMJ IS NOT NULL THEN DATE(DIGITS(DEC(QTUPMJ+ 1900000,7,0))) ELSE NULL END AS QTUPMJ, QTTDAY
#
# 	FROM
# 		ARCPDTA71.F5698
# --    WHERE
# --        <insert custom code here>
# --    ORDER BY
# --        <insert custom code here>
# ')
#
# --------------------------------------------------------------------------------

# %%
dff
# Out:
#     ORDINAL_POSITION COLUMN_NAME                               COLUMN_TEXT  \
# 0                  1      QT$RTP  Record Type. . . . . . . . . . . . . . .
# 1                  2       QTITM  Item Number (Short). . . . . . . . . . .
# 2                  3      QTLITM  2nd Item Number. . . . . . . . . . . . .
# 3                  4      QT$AJP  Adjustment Percent . . . . . . . . . . .
# 4                  5      QT$AJD  Adjustment Dollar. . . . . . . . . . . .
# 5                  6      QT$USG  Adjustment Usage . . . . . . . . . . . .
# 6                  7      QTEFFF  Effective From Date  . . . . . . . . . .
# 7                  8      QTEXDE  Expiration Date. . . . . . . . . . . . .
# 8                  9      QT$FLD  Data Field Name. . . . . . . . . . . . .
# 9                 10      QTAC10   Division Code . . . . . . . .. . . . ..
# 10                11      QT$SEQ   Sequence / ID#. . . . . . . .. . . .. .
# 11                12       QTSIC  Speciality . . . . . . . . . . . . . . .
# 12                13      QTAC01  Customer Profession. . . . . . . . . . .
# 13                14      QTAC02  Customer Sub Profession. . . . . . . . .
# 14                15      QTAC03  Type of Paying Customer. . . . . . . . .
# 15                16      QTAC04  Practice Type. . . . . . . . . . . . . .
# 16                17      QTAC05  A/P Check Routing Code . . . . . . . . .
# 17                18      QTAC06  Category Code - Address 06 . . . . . . .
# 18                19      QT$FT1  Future Use 1 . . . . . . . . . . . . . .
# 19                20      QT$FT2  Future Use 2 . . . . . . . . . . . . . .
# 20                21      QT$FT3  Future Use 3 . . . . . . . . . . . . . .
# 21                22      QT$FT4  Future Use 4 . . . . . . . . . . . . . .
# 22                23      QT$FT5  Future Use 5 . . . . . . . . . . . . . .
# 23                24      QT$FT6  Future Use 6 . . . . . . . . . . . . . .
# 24                25      QT$FT7  Future Use 7 . . . . . . . . . . . . . .
# 25                26      QT$FT8  Future Use 8 . . . . . . . . . . . . . .
# 26                27      QT$FT9  Future Use 9 . . . . . . . . . . . . . .
# 27                28      QT$FT0  Future Use 0 . . . . . . . . . . . . . .
# 28                29      QTCRTU  Created by User. . . . . . . . . . . . .
# 29                30       QTPGM  Program Name . . . . . . . . . . . . . .
# 30                31      QTCRDJ  Creation Date. . . . . . . . . . . . . .
# 31                32      QTCRTM  Creation Time. . . . . . . . . . . . . .
# 32                33      QTUSER  User ID. . . . . . . . . . . . . . . . .
# 33                34       QTPID  Program ID . . . . . . . . . . . . . . .
# 34                35      QTJOBN  Work Station ID. . . . . . . . . . . . .
# 35                36      QTUPMJ  Date Updated . . . . . . . . . . . . . .
# 36                37      QTTDAY  Time of Day. . . . . . . . . . . . . . .
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type  data_type  \
# 0       CHAR       2                NaN      $RTP              A        2.0
# 1    NUMERIC       8                8.0       ITM              S        9.0
# 2       CHAR      25                NaN      LITM              A        2.0
# 3    DECIMAL       5                5.0      $AJP              P        9.0
# 4    NUMERIC      15               15.0      $AJD              S        9.0
# 5       CHAR       1                NaN      $USG              A        1.0
# 6    NUMERIC       6                6.0      EFFF              S       11.0
# 7    NUMERIC       6                6.0      EXDE              S       11.0
# 8       CHAR       6                NaN      $FLD              A        2.0
# 9       CHAR       3                NaN      AC10              A        2.0
# 10   NUMERIC       8                8.0      $SEQ              S        9.0
# 11      CHAR      10                NaN       SIC              A        2.0
# 12      CHAR       3                NaN      AC01              A        2.0
# 13      CHAR       3                NaN      AC02              A        2.0
# 14      CHAR       3                NaN      AC03              A        2.0
# 15      CHAR       3                NaN      AC04              A        2.0
# 16      CHAR       3                NaN      AC05              A        2.0
# 17      CHAR       3                NaN      AC06              A        2.0
# 18   NUMERIC      15               15.0      $FT1              S        9.0
# 19   NUMERIC      15               15.0      $FT2              S        9.0
# 20   NUMERIC      15               15.0      $FT3              S        9.0
# 21   NUMERIC      15               15.0      $FT4              S        9.0
# 22   NUMERIC      15               15.0      $FT5              S        9.0
# 23      CHAR      15                NaN      $FT6              A        2.0
# 24      CHAR      15                NaN      $FT7              A        2.0
# 25      CHAR      15                NaN      $FT8              A        2.0
# 26      CHAR      15                NaN      $FT9              A        2.0
# 27      CHAR      15                NaN      $FT0              A        2.0
# 28      CHAR      10                NaN      CRTU              A        2.0
# 29      CHAR      10                NaN       PGM              A        2.0
# 30   NUMERIC       6                6.0      CRDJ              S       11.0
# 31   NUMERIC       6                6.0      CRTM              S        9.0
# 32      CHAR      10                NaN      USER              A        2.0
# 33      CHAR      10                NaN       PID              A        2.0
# 34      CHAR      10                NaN      JOBN              A        2.0
# 35   NUMERIC       6                6.0      UPMJ              S       11.0
# 36   DECIMAL       6                6.0      TDAY              P        9.0
#
#     data_item_size  display_decimals  \
# 0              2.0               0.0
# 1              8.0               0.0
# 2             25.0               0.0
# 3              5.0               4.0
# 4             15.0               0.0
# 5              1.0               0.0
# 6              6.0               0.0
# 7              6.0               0.0
# 8              6.0               0.0
# 9              3.0               0.0
# 10             8.0               0.0
# 11            10.0               0.0
# 12             3.0               0.0
# 13             3.0               0.0
# 14             3.0               0.0
# 15             3.0               0.0
# 16             3.0               0.0
# 17             3.0               0.0
# 18            15.0               0.0
# 19            15.0               0.0
# 20            15.0               0.0
# 21            15.0               0.0
# 22            15.0               0.0
# 23            15.0               0.0
# 24            15.0               0.0
# 25            15.0               0.0
# 26            15.0               0.0
# 27            15.0               0.0
# 28            10.0               0.0
# 29            10.0               0.0
# 30             6.0               0.0
# 31             6.0               0.0
# 32            10.0               0.0
# 33            10.0               0.0
# 34            10.0               0.0
# 35             6.0               0.0
# 36             6.0               0.0
#
#                              row_description     row_description_final
# 0   Record Type. . . . . . . . . . . . . . .               record_type
# 1   Item Number (Short). . . . . . . . . . .         item_number_short
# 2   2nd Item Number. . . . . . . . . . . . .               item_number
# 3   Adjustment Percent . . . . . . . . . . .        adjustment_percent
# 4   Adjustment Dollar. . . . . . . . . . . .         adjustment_dollar
# 5   Adjustment Usage . . . . . . . . . . . .          adjustment_usage
# 6   Effective From Date  . . . . . . . . . .       effective_from_date
# 7   Expiration Date. . . . . . . . . . . . .           expiration_date
# 8   Data Field Name. . . . . . . . . . . . .           data_field_name
# 9   Division Code . . . . . . . . . . . . ..             division_code
# 10  Sequence / ID#. . . . . . . . . . . .. .               sequence_id
# 11  Speciality . . . . . . . . . . . . . . .                speciality
# 12  Customer Profession. . . . . . . . . . .       customer_profession
# 13  Customer Sub Profession. . . . . . . . .   customer_sub_profession
# 14  Type of Paying Customer. . . . . . . . .   type_of_paying_customer
# 15  Practice Type. . . . . . . . . . . . . .             practice_type
# 16  A/P Check Routing Code . . . . . . . . .     ap_check_routing_code
# 17  Category Code - Address 06 . . . . . . .  category_code_address_06
# 18  Future Use 1 . . . . . . . . . . . . . .              future_use_1
# 19  Future Use 2 . . . . . . . . . . . . . .              future_use_2
# 20  Future Use 3 . . . . . . . . . . . . . .              future_use_3
# 21  Future Use 4 . . . . . . . . . . . . . .              future_use_4
# 22  Future Use 5 . . . . . . . . . . . . . .              future_use_5
# 23  Future Use 6 . . . . . . . . . . . . . .              future_use_6
# 24  Future Use 7 . . . . . . . . . . . . . .              future_use_7
# 25  Future Use 8 . . . . . . . . . . . . . .              future_use_8
# 26  Future Use 9 . . . . . . . . . . . . . .              future_use_9
# 27  Future Use 0 . . . . . . . . . . . . . .              future_use_0
# 28  Created by User. . . . . . . . . . . . .           created_by_user
# 29  Program Name . . . . . . . . . . . . . .              program_name
# 30  Creation Date. . . . . . . . . . . . . .             creation_date
# 31  Creation Time. . . . . . . . . . . . . .             creation_time
# 32  User ID. . . . . . . . . . . . . . . . .                   user_id
# 33  Program ID . . . . . . . . . . . . . . .                program_id
# 34  Work Station ID. . . . . . . . . . . . .           work_station_id
# 35  Date Updated . . . . . . . . . . . . . .              date_updated
# 36  Time of Day. . . . . . . . . . . . . . .               time_of_day

# %%
# %time df_table_map = pd.read_sql_query(sql_table_map, engine);
# Out:
# CPU times: user 16.4 ms, sys: 0 ns, total: 16.4 ms
# Wall time: 7.46 s

# %% [markdown]
# ### Next steps...
# Add SQL to SQL Tools data package

# %%
df_table_map
# Out:
#   QT$RTP_record_type  QTITM__item_number_short         QTLITM_item_number  \
# 0                 S1                  768589.0  1044648
# 1                 S1                  768589.0  1044648
# 2                 S1                  768589.0  1044648
# 3                 S1                  769078.0  1081158
# 4                 S1                  769078.0  1081158
#
#    QT$AJP_adjustment_percent  QT$AJD_adjustment_dollar  \
# 0                      1.075                       0.0
# 1                      1.070                       0.0
# 2                      1.070                       0.0
# 3                      1.000                       0.0
# 4                      1.000                       0.0
#
#   QT$USG_adjustment_usage QTEFFF_effective_from_date QTEXDE_expiration_date  \
# 0                       P                 2018-01-16             2040-12-31
# 1                       P                 2010-01-18             2018-01-15
# 2                       P                 2009-12-17             2010-01-17
# 3                       P                 2020-03-26             2020-12-31
# 4                       P                 2014-12-20             2040-12-31
#
#   QT$FLD_data_field_name QTAC10_division_code         ...          \
# 0                 AC10                    ALL         ...
# 1                 AC10                    ALL         ...
# 2                 AC10                    ALL         ...
# 3                 AC10                    ALL         ...
# 4                 AC10                    ALL         ...
#
#    QT$FT0_future_use_0 QTCRTU_created_by_user QTPGM__program_name  \
# 0                                  LJAGGA              P5698001
# 1                                  LJAGGA              P5698001
# 2                                  LJAGGA              P5698001
# 3                                  LJAGGA              P5698001
# 4                                  LJAGGA              P5698001
#
#   QTCRDJ_creation_date QTCRTM_creation_time QTUSER_user_id QTPID__program_id  \
# 0           2018-01-15             130232.0     LJAGGA            P5698001
# 1           2010-01-18             160159.0     LJAGGA            P5698001
# 2           2009-12-17             165436.0     LJAGGA            P5698001
# 3           2014-12-19             172613.0     LJAGGA            P5698001
# 4           2014-12-19             172613.0     LJAGGA            P5698001
#
#   QTJOBN_work_station_id  QTUPMJ_date_updated  QTTDAY_time_of_day
# 0             J569800002           2018-01-15            130232.0
# 1             J569800002           2010-01-18            160159.0
# 2             J569800002           2009-12-17            165436.0
# 3             J569800002           2014-12-19            172613.0
# 4             J569800002           2014-12-19            172613.0
#
# [5 rows x 37 columns]
