# %% [markdown]
# # JDE ETL Source Design
# ## Goal:  Generate source SQL with friendly names and built-in data Conversion
# 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals
# 2. Pull *Specific* Table fields
# 3. Create SQL mapiing pull with data-conversion

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import os, sys
import warnings

warnings.filterwarnings('ignore')

# %%
from decouple import config
config.search_path = '/home/jovyan/work'

# %% [markdown]
# ### Connect to SQL DB

# %%
engine = create_engine(config('DATABASE_URL'))

# %% [markdown]
# ### 1. Pull *ALL* Field metadata based on QA 9.3:  Name, Datatype, Decimals

# %%
sql_field_meta_server = 'ESYS_PROD'
sql_field_meta_lib = 'ARCPCOM71'
#sql_field_meta_lib = 'ARCPCOM71'
#sql_field_meta_lib = 'HSIPCOM93Q'

# %%
sql_field_meta = '''
SELECT 
	RTRIM("FRDTAI")				AS data_item
	,"FRDTAT"					AS data_item_type
	,"FROWTP"					AS data_type
	,"FRDTAS"					AS data_item_size
	,ISNULL("FRCDEC", 0)		AS display_decimals
	,ISNULL("FRDSCR", 'zNA')	AS row_description 
    
FROM 

    OPENQUERY ({}, '

	SELECT
		t.FRDTAI
		,FRDTAT
		,FROWTP
		,FRDTAS
		,FRCDEC
		,FRDSCR
	FROM
		{}.F9210 t
		LEFT JOIN {}.F9202 d
		ON t.FRDTAI = d.FRDTAI AND
			d.FRLNGP = '' '' AND
			d.FRSYR = '' ''  
')

'''.format(sql_field_meta_server, sql_field_meta_lib, sql_field_meta_lib)

# %%
print(sql_field_meta)
# Out:
# SELECT
# 	RTRIM("FRDTAI")				AS data_item
# 	,"FRDTAT"					AS data_item_type
# 	,"FROWTP"					AS data_type
# 	,"FRDTAS"					AS data_item_size
# 	,ISNULL("FRCDEC", 0)		AS display_decimals
# 	,ISNULL("FRDSCR", 'zNA')	AS row_description
#
# FROM
#
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		t.FRDTAI
# 		,FRDTAT
# 		,FROWTP
# 		,FRDTAS
# 		,FRCDEC
# 		,FRDSCR
# 	FROM
# 		ARCPCOM71.F9210 t
# 		LEFT JOIN ARCPCOM71.F9202 d
# 		ON t.FRDTAI = d.FRDTAI AND
# 			d.FRLNGP = '' '' AND
# 			d.FRSYR = '' ''
# ')

# %%
df_field_meta = pd.read_sql_query(sql_field_meta, engine);

# %%
df_field_meta.iloc[:,[2,3,4]] = df_field_meta.iloc[:,[2,3,4]].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_field_meta.fillna(value=0,inplace=True)

# %% [markdown]
# ### 2. Pull *Specific* Table fields

# %% [markdown]
# #  Set Table Name HERE

# %%
sql_table = 'NPFIMS'

sql_link_server = 'ESYS_PROD'
sql_lib = 'ARCPTEL'
#sql_lib = 'ARCPDTA71'
#sql_lib = 'HSIPDTA71'


stage_db_schema = 'etl.'
convert_julian_date = True

# [ARC | HSI] [P | D] [DTA | CDC] [ 71 | 94]

# %%
sql_table_fields = '''

SELECT * from OPENQUERY ({}, '
	SELECT
		*
	FROM
		QSYS2.SYSCOLUMNS
	WHERE
        TABLE_SCHEMA = ''{}'' AND
		TABLE_NAME in( ''{}'')
    ORDER BY 
        ORDINAL_POSITION
')

''' .format(sql_link_server, sql_lib, sql_table)

# %%
#print (sql_table_fields)

# %%
df_table_fields = pd.read_sql_query(sql_table_fields, engine);

# %% [markdown]
# #### Join table fields with data dictionary meta-data

# %%
#df_table_fields

# %%
df_table_fields = df_table_fields[['ORDINAL_POSITION', 'COLUMN_NAME', 'COLUMN_TEXT', 'DATA_TYPE','LENGTH', 'NUMERIC_PRECISION']]

# %%
df_table_fields['data_item'] = df_table_fields.COLUMN_NAME.str[2:]

# %%
df_table_fields.head()
# Out:
#    ORDINAL_POSITION COLUMN_NAME                  COLUMN_TEXT DATA_TYPE  \
# 0                 1      IMACDE                ACTIVITY CODE      CHAR
# 1                 2      IMACST            Item Average Cost   DECIMAL
# 2                 3      IMACHF     AVAILABILITY CHANGE FLAG      CHAR
# 3                 4      IMAVLC  AVAILABILITY CODE CORPORATE      CHAR
# 4                 5      IMADTE            AVAILABILITY DATE   DECIMAL
#
#    LENGTH  NUMERIC_PRECISION data_item
# 0       1                NaN      ACDE
# 1       9                9.0      ACST
# 2       1                NaN      ACHF
# 3       1                NaN      AVLC
# 4       6                6.0      ADTE

# %%
df_table_fields
# Out:
#     ORDINAL_POSITION COLUMN_NAME                                COLUMN_TEXT  \
# 0                  1      IMACDE                              ACTIVITY CODE
# 1                  2      IMACST                          Item Average Cost
# 2                  3      IMACHF                   AVAILABILITY CHANGE FLAG
# 3                  4      IMAVLC                AVAILABILITY CODE CORPORATE
# 4                  5      IMADTE                          AVAILABILITY DATE
# 5                  6      IMRQTY                        RESTRICTED QUANTITY
# 6                  7      IMBODT                            BACK-ORDER DATE
# 7                  8      IMCLSC                                 CLASS CODE
# 8                  9      IMCQTC                         CASE QUANTITY CODE
# 9                 10      IMCLQT                          CASE LOT QUANTITY
# 10                11      IMDESC                                DESCRIPTION
# 11                12      IMDKYA                          DESCRIPTION KEY A
# 12                13      IMDKYB                          DESCRIPTION KEY B
# 13                14      IMHEIG                                     HEIGHT
# 14                15      IMCSET                       ITEM FAMILY COST SET
# 15                16      IMITEM                                  ITEM CODE
# 16                17      IMRSET                     ITEM FAMILY RESALE SET
# 17                18      IMITAX                              ITEM TAX CODE
# 18                19      IMKITC  'M' = MIX/MATCH,'N' = MIX/MATCH GROUP RCD
# 19                20      IMLENG                                     LENGTH
# 20                21      IMNDC#               N.D.C. CODE-PRIMARY SUPPLIER
# 21                22      IMPINF                        PRICING INFORMATION
# 22                23      IMPCL1         PRODUCT CLASSIFICATION CODE, MAJOR
# 23                24      IMWGTC                  ITEM SHIPPING METHOD CODE
# 24                25      IMSIZE                               PRODUCT SIZE
# 25                26      IMSTRN                              ITEM STRENGTH
# 26                27      IMSCDE                          SUBSTITUTION CODE
# 27                28      IMVEND                                VENDOR CODE
# 28                29      IMVITM                 PRIMARY SUPPLIER ITEM CODE
# 29                30      IMWEIG                                     WEIGHT
# ..               ...         ...                                        ...
# 70                71      IMSLBT                 ITEM E-SHIPPING LABEL TYPE
# 71                72      IMNDC1                       NDC# 10 Digit Edited
# 72                73      IMNDC2                              NDC# 10 Digit
# 73                74      IMNDC3                              NDC# 11 Digit
# 74                75      IMMLNK                            Item Image Link
# 75                76      IMELEN                             Item Ea Length
# 76                77      IMEWID                              Item Ea Width
# 77                78      IMEHEI                             Item Ea Heigth
# 78                79      IMGIN#                                   GET IN #
# 79                80      IMEDES                  Item Extended Description
# 80                81      IMIDES                        Invoice Description
# 81                82      IMPSPD                      Packing Slip Prt Desc
# 82                83      IMJSTN                          JDE Item Strength
# 83                84      IMWTYP                              Warranty Type
# 84                85      IMSIDS                             Supplier Item#
# 85                86      IMUS01                            Future Use - 01
# 86                87      IMUS02                            Future Use - 02
# 87                88      IMUS03                            Future Use - 03
# 88                89      IMUS04                            Future Use - 04
# 89                90      IMUS05                            Future Use - 05
# 90                91      IMUS06                            Future Use - 06
# 91                92      IMUS07                            Future Use - 07
# 92                93      IMUS08                            Future Use - 08
# 93                94      IMUS09                            Future Use - 09
# 94                95      IMUS10                            Future Use - 10
# 95                96      IMUS11                            Future Use - 11
# 96                97      IMUS12                            Future Use - 12
# 97                98      IMUS13                            Future Use - 13
# 98                99      IMUS14                            Future Use - 14
# 99               100      IMUS15                            Future Use - 15
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item
# 0       CHAR       1                NaN      ACDE
# 1    DECIMAL       9                9.0      ACST
# 2       CHAR       1                NaN      ACHF
# 3       CHAR       1                NaN      AVLC
# 4    DECIMAL       6                6.0      ADTE
# 5    DECIMAL       5                5.0      RQTY
# 6    DECIMAL       6                6.0      BODT
# 7       CHAR       2                NaN      CLSC
# 8       CHAR       1                NaN      CQTC
# 9    DECIMAL       4                4.0      CLQT
# 10      CHAR      25                NaN      DESC
# 11      CHAR      25                NaN      DKYA
# 12      CHAR      25                NaN      DKYB
# 13   DECIMAL       5                5.0      HEIG
# 14      CHAR       7                NaN      CSET
# 15      CHAR       7                NaN      ITEM
# 16      CHAR       7                NaN      RSET
# 17      CHAR       1                NaN      ITAX
# 18      CHAR       1                NaN      KITC
# 19   DECIMAL       5                5.0      LENG
# 20   DECIMAL      11               11.0      NDC#
# 21      CHAR      20                NaN      PINF
# 22      CHAR       3                NaN      PCL1
# 23      CHAR       3                NaN      WGTC
# 24      CHAR       8                NaN      SIZE
# 25      CHAR       7                NaN      STRN
# 26      CHAR       1                NaN      SCDE
# 27      CHAR       6                NaN      VEND
# 28      CHAR      12                NaN      VITM
# 29   DECIMAL       5                5.0      WEIG
# ..       ...     ...                ...       ...
# 70      CHAR       2                NaN      SLBT
# 71   DECIMAL      10               10.0      NDC1
# 72      CHAR      12                NaN      NDC2
# 73      CHAR      13                NaN      NDC3
# 74      CHAR      60                NaN      MLNK
# 75   DECIMAL       6                6.0      ELEN
# 76   DECIMAL       6                6.0      EWID
# 77   DECIMAL       6                6.0      EHEI
# 78      CHAR      14                NaN      GIN#
# 79      CHAR      65                NaN      EDES
# 80      CHAR      65                NaN      IDES
# 81      CHAR      65                NaN      PSPD
# 82      CHAR      12                NaN      JSTN
# 83      CHAR       8                NaN      WTYP
# 84      CHAR      25                NaN      SIDS
# 85      CHAR       2                NaN      US01
# 86      CHAR       2                NaN      US02
# 87      CHAR       2                NaN      US03
# 88      CHAR       2                NaN      US04
# 89      CHAR       2                NaN      US05
# 90      CHAR       5                NaN      US06
# 91      CHAR       5                NaN      US07
# 92      CHAR      10                NaN      US08
# 93      CHAR      10                NaN      US09
# 94      CHAR      10                NaN      US10
# 95      CHAR      20                NaN      US11
# 96      CHAR      20                NaN      US12
# 97      CHAR      40                NaN      US13
# 98   DECIMAL      13               13.0      US14
# 99   DECIMAL      13               13.0      US15
#
# [100 rows x 7 columns]

# %%
df_table_fields.data_item.unique()
# Out:
# array(['ACDE', 'ACST', 'ACHF', 'AVLC', 'ADTE', 'RQTY', 'BODT', 'CLSC',
#        'CQTC', 'CLQT', 'DESC', 'DKYA', 'DKYB', 'HEIG', 'CSET', 'ITEM',
#        'RSET', 'ITAX', 'KITC', 'LENG', 'NDC#', 'PINF', 'PCL1', 'WGTC',
#        'SIZE', 'STRN', 'SCDE', 'VEND', 'VITM', 'WEIG', 'WIDT', 'DTYP',
#        'LOCT', 'CLMJ', 'CLSJ', 'CLMC', 'CLSM', 'BUYR', 'SUPL', 'RPKE',
#        'TXCA', 'UDEF', 'PUCD', 'ENTD', 'FRTC', 'HAZC', 'ADMC', 'CSTP',
#        'PKTP', 'INVU', 'SLEL', 'JNKM', 'STCK', 'SLSC', 'PRCD', 'MSC1',
#        'MSC2', 'MSC3', 'WDSC', 'PDSC', 'DCLS', 'PRLF', 'WCHC', 'NHAZ',
#        'LCTL', 'PSLF', 'JDSC', 'LNTY', 'SNOR', 'STAS', 'SLBT', 'NDC1',
#        'NDC2', 'NDC3', 'MLNK', 'ELEN', 'EWID', 'EHEI', 'GIN#', 'EDES',
#        'IDES', 'PSPD', 'JSTN', 'WTYP', 'SIDS', 'US01', 'US02', 'US03',
#        'US04', 'US05', 'US06', 'US07', 'US08', 'US09', 'US10', 'US11',
#        'US12', 'US13', 'US14', 'US15'], dtype=object)

# %%
dff = pd.merge(df_table_fields,df_field_meta,on='data_item', how='left')
#dff = pd.merge(df_table_fields,df_field_meta,on='data_item', how='inner')

# %%
# hack to set resonable defaults for missing data
dff['display_decimals'].fillna(value='0',inplace=True)
dff['data_type'].fillna(value='0',inplace=True)
dff['row_description'].fillna(value=dff['COLUMN_TEXT'], inplace=True)

# %% [markdown]
# #### Cleanup final field name
# remove trailing dots, special characters, and converto to lower_case

# %%
dff['row_description_final'] = dff.row_description.str.rstrip('. ').str.replace(r'%','pct').str.replace(r'$','amt').str.replace(r'[^0-9|a-z|" "]','', case=False).str.replace('  ',' ').str.lower().str.replace(' ','_')

# %% [markdown]
# #### Override with Defaults

# %%
dff['row_description_final'][dff['data_item']=='LITM'] = 'item_number'
dff['row_description_final'][dff['data_item']=='AN8'] = 'billto'
dff['row_description_final'][dff['data_item']=='SHAN'] = 'shipto'
dff['row_description_final'][dff['data_item']=='DOCO'] = 'salesorder_number'

# %% [markdown]
# ### 3. Create SQL mapping pull with data-conversion

# %%
dff.groupby(['DATA_TYPE', 'data_type','display_decimals'])['ORDINAL_POSITION'].count()
# Out:
# DATA_TYPE  data_type  display_decimals
# CHAR       1.0        0.0                  7
#            2.0        0.0                 10
#            9.0        0.0                 16
#                       4.0                  1
#            11.0       0.0                  1
#            0          0                   44
# DECIMAL    2.0        0.0                  1
#            9.0        0.0                  5
#                       4.0                  1
#            0          0                   14
# Name: ORDINAL_POSITION, dtype: int64

# %%
pd.options.display.max_rows = 99

# %%
dff
# Out:
#     ORDINAL_POSITION COLUMN_NAME                                COLUMN_TEXT  \
# 0                  1      IMACDE                              ACTIVITY CODE
# 1                  2      IMACST                          Item Average Cost
# 2                  3      IMACHF                   AVAILABILITY CHANGE FLAG
# 3                  4      IMAVLC                AVAILABILITY CODE CORPORATE
# 4                  5      IMADTE                          AVAILABILITY DATE
# 5                  6      IMRQTY                        RESTRICTED QUANTITY
# 6                  7      IMBODT                            BACK-ORDER DATE
# 7                  8      IMCLSC                                 CLASS CODE
# 8                  9      IMCQTC                         CASE QUANTITY CODE
# 9                 10      IMCLQT                          CASE LOT QUANTITY
# 10                11      IMDESC                                DESCRIPTION
# 11                12      IMDKYA                          DESCRIPTION KEY A
# 12                13      IMDKYB                          DESCRIPTION KEY B
# 13                14      IMHEIG                                     HEIGHT
# 14                15      IMCSET                       ITEM FAMILY COST SET
# 15                16      IMITEM                                  ITEM CODE
# 16                17      IMRSET                     ITEM FAMILY RESALE SET
# 17                18      IMITAX                              ITEM TAX CODE
# 18                19      IMKITC  'M' = MIX/MATCH,'N' = MIX/MATCH GROUP RCD
# 19                20      IMLENG                                     LENGTH
# 20                21      IMNDC#               N.D.C. CODE-PRIMARY SUPPLIER
# 21                22      IMPINF                        PRICING INFORMATION
# 22                23      IMPCL1         PRODUCT CLASSIFICATION CODE, MAJOR
# 23                24      IMWGTC                  ITEM SHIPPING METHOD CODE
# 24                25      IMSIZE                               PRODUCT SIZE
# 25                26      IMSTRN                              ITEM STRENGTH
# 26                27      IMSCDE                          SUBSTITUTION CODE
# 27                28      IMVEND                                VENDOR CODE
# 28                29      IMVITM                 PRIMARY SUPPLIER ITEM CODE
# 29                30      IMWEIG                                     WEIGHT
# 30                31      IMWIDT                                      WIDTH
# 31                32      IMDTYP                          PRODUCT DATE TYPE
# 32                33      IMLOCT                              LOCATION TYPE
# 33                34      IMCLMJ                        PRODUCT MAJOR CLASS
# 34                35      IMCLSJ                    PRODUCT SUB-MAJOR CLASS
# 35                36      IMCLMC                        PRODUCT MINOR CLASS
# 36                37      IMCLSM                    PRODUCT SUB-MINOR CLASS
# 37                38      IMBUYR                               BUYER NUMBER
# 38                39      IMSUPL                      PRIMARY SUPPLIER CODE
# 39                40      IMRPKE                      Needs Repackaging Y/N
# 40                41      IMTXCA                         Tax Code Array 8 X
# 41                42      IMUDEF                     Undefined Filler Field
# 42                43      IMPUCD                              Purchase Code
# 43                44      IMENTD                               DATE ENTERED
# 44                45      IMFRTC                               FREIGHT CODE
# 45                46      IMHAZC                                HAZARD CODE
# 46                47      IMADMC                         ADMIN. CHARGE CODE
# 47                48      IMCSTP                    % RESALE TO USE AS COST
# 48                49      IMPKTP                       PRINT ON PICK TICKET
# ..               ...         ...                                        ...
# 51                52      IMJNKM                                  JUNK MAIL
# 52                53      IMSTCK                       STOCK,NON-STOCK CODE
# 53                54      IMSLSC                            SALES PLAN CODE
# 54                55      IMPRCD                             PRICE LOT CODE
# 55                56      IMMSC1                               MISC. FLAG 1
# 56                57      IMMSC2                               MISC. FLAG 2
# 57                58      IMMSC3                               MISC. FLAG 3
# 58                59      IMWDSC                      WAREHOUSE DESCRIPTION
# 59                60      IMPDSC                       PHONETIC DESCRIPTION
# 60                61      IMDCLS                        DATE CLASSIFICATION
# 61                62      IMPRLF                        PRODUCT USEFUL LIFE
# 62                63      IMWCHC                            ITEM WATCH CODE
# 63                64      IMNHAZ                                 NON HAZMAT
# 64                65      IMLCTL                           ITEM LOT CONTROL
# 65                66      IMPSLF                         PRODUCT SHELF LIFE
# 66                67      IMJDSC                       JDE ITEM DESCRIPTION
# 67                68      IMLNTY                              JDE LINE TYPE
# 68                69      IMSNOR                      Item Serial# Required
# 69                70      IMSTAS                                ITEM STATUS
# 70                71      IMSLBT                 ITEM E-SHIPPING LABEL TYPE
# 71                72      IMNDC1                       NDC# 10 Digit Edited
# 72                73      IMNDC2                              NDC# 10 Digit
# 73                74      IMNDC3                              NDC# 11 Digit
# 74                75      IMMLNK                            Item Image Link
# 75                76      IMELEN                             Item Ea Length
# 76                77      IMEWID                              Item Ea Width
# 77                78      IMEHEI                             Item Ea Heigth
# 78                79      IMGIN#                                   GET IN #
# 79                80      IMEDES                  Item Extended Description
# 80                81      IMIDES                        Invoice Description
# 81                82      IMPSPD                      Packing Slip Prt Desc
# 82                83      IMJSTN                          JDE Item Strength
# 83                84      IMWTYP                              Warranty Type
# 84                85      IMSIDS                             Supplier Item#
# 85                86      IMUS01                            Future Use - 01
# 86                87      IMUS02                            Future Use - 02
# 87                88      IMUS03                            Future Use - 03
# 88                89      IMUS04                            Future Use - 04
# 89                90      IMUS05                            Future Use - 05
# 90                91      IMUS06                            Future Use - 06
# 91                92      IMUS07                            Future Use - 07
# 92                93      IMUS08                            Future Use - 08
# 93                94      IMUS09                            Future Use - 09
# 94                95      IMUS10                            Future Use - 10
# 95                96      IMUS11                            Future Use - 11
# 96                97      IMUS12                            Future Use - 12
# 97                98      IMUS13                            Future Use - 13
# 98                99      IMUS14                            Future Use - 14
# 99               100      IMUS15                            Future Use - 15
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type data_type  \
# 0       CHAR       1                NaN      ACDE              A         2
# 1    DECIMAL       9                9.0      ACST              P         9
# 2       CHAR       1                NaN      ACHF            NaN         0
# 3       CHAR       1                NaN      AVLC              A         1
# 4    DECIMAL       6                6.0      ADTE            NaN         0
# 5    DECIMAL       5                5.0      RQTY              P         9
# 6    DECIMAL       6                6.0      BODT            NaN         0
# 7       CHAR       2                NaN      CLSC            NaN         0
# 8       CHAR       1                NaN      CQTC            NaN         0
# 9    DECIMAL       4                4.0      CLQT              P         9
# 10      CHAR      25                NaN      DESC              O         2
# 11      CHAR      25                NaN      DKYA            NaN         0
# 12      CHAR      25                NaN      DKYB            NaN         0
# 13   DECIMAL       5                5.0      HEIG            NaN         0
# 14      CHAR       7                NaN      CSET              A         1
# 15      CHAR       7                NaN      ITEM              A         2
# 16      CHAR       7                NaN      RSET              A         9
# 17      CHAR       1                NaN      ITAX            NaN         0
# 18      CHAR       1                NaN      KITC              A         1
# 19   DECIMAL       5                5.0      LENG            NaN         0
# 20   DECIMAL      11               11.0      NDC#            NaN         0
# 21      CHAR      20                NaN      PINF              P         9
# 22      CHAR       3                NaN      PCL1              A         2
# 23      CHAR       3                NaN      WGTC            NaN         0
# 24      CHAR       8                NaN      SIZE            NaN         0
# 25      CHAR       7                NaN      STRN              A         2
# 26      CHAR       1                NaN      SCDE            NaN         0
# 27      CHAR       6                NaN      VEND              S         9
# 28      CHAR      12                NaN      VITM            NaN         0
# 29   DECIMAL       5                5.0      WEIG            NaN         0
# 30   DECIMAL       5                5.0      WIDT            NaN         0
# 31      CHAR       1                NaN      DTYP              A         1
# 32      CHAR       2                NaN      LOCT              A         2
# 33      CHAR       3                NaN      CLMJ            NaN         0
# 34      CHAR       2                NaN      CLSJ            NaN         0
# 35      CHAR       2                NaN      CLMC              P         9
# 36      CHAR       2                NaN      CLSM            NaN         0
# 37   DECIMAL       5                5.0      BUYR              S         9
# 38      CHAR       6                NaN      SUPL              A         2
# 39      CHAR       1                NaN      RPKE            NaN         0
# 40      CHAR       8                NaN      TXCA            NaN         0
# 41      CHAR      20                NaN      UDEF            NaN         0
# 42      CHAR       1                NaN      PUCD              A         2
# 43   DECIMAL       7                7.0      ENTD            NaN         0
# 44      CHAR       1                NaN      FRTC              A         1
# 45      CHAR       2                NaN      HAZC            NaN         0
# 46      CHAR       1                NaN      ADMC            NaN         0
# 47   DECIMAL       4                4.0      CSTP              A         2
# 48      CHAR       1                NaN      PKTP            NaN         0
# ..       ...     ...                ...       ...            ...       ...
# 51      CHAR       1                NaN      JNKM            NaN         0
# 52      CHAR       1                NaN      STCK            NaN         0
# 53      CHAR       1                NaN      SLSC            NaN         0
# 54      CHAR       1                NaN      PRCD              A         1
# 55      CHAR       1                NaN      MSC1            NaN         0
# 56      CHAR       1                NaN      MSC2            NaN         0
# 57      CHAR       1                NaN      MSC3            NaN         0
# 58      CHAR      45                NaN      WDSC            NaN         0
# 59      CHAR      45                NaN      PDSC              O         2
# 60      CHAR       1                NaN      DCLS              S        11
# 61   DECIMAL       5                5.0      PRLF            NaN         0
# 62      CHAR       3                NaN      WCHC            NaN         0
# 63      CHAR       1                NaN      NHAZ            NaN         0
# 64      CHAR       2                NaN      LCTL              A         1
# 65   DECIMAL       2                2.0      PSLF            NaN         0
# 66      CHAR      30                NaN      JDSC            NaN         0
# 67      CHAR       2                NaN      LNTY              A         2
# 68      CHAR       1                NaN      SNOR            NaN         0
# 69      CHAR       2                NaN      STAS            NaN         0
# 70      CHAR       2                NaN      SLBT            NaN         0
# 71   DECIMAL      10               10.0      NDC1            NaN         0
# 72      CHAR      12                NaN      NDC2            NaN         0
# 73      CHAR      13                NaN      NDC3            NaN         0
# 74      CHAR      60                NaN      MLNK            NaN         0
# 75   DECIMAL       6                6.0      ELEN            NaN         0
# 76   DECIMAL       6                6.0      EWID            NaN         0
# 77   DECIMAL       6                6.0      EHEI            NaN         0
# 78      CHAR      14                NaN      GIN#            NaN         0
# 79      CHAR      65                NaN      EDES            NaN         0
# 80      CHAR      65                NaN      IDES            NaN         0
# 81      CHAR      65                NaN      PSPD            NaN         0
# 82      CHAR      12                NaN      JSTN            NaN         0
# 83      CHAR       8                NaN      WTYP            NaN         0
# 84      CHAR      25                NaN      SIDS            NaN         0
# 85      CHAR       2                NaN      US01              S         9
# 86      CHAR       2                NaN      US02              S         9
# 87      CHAR       2                NaN      US03              S         9
# 88      CHAR       2                NaN      US04              S         9
# 89      CHAR       2                NaN      US05              S         9
# 90      CHAR       5                NaN      US06              S         9
# 91      CHAR       5                NaN      US07              S         9
# 92      CHAR      10                NaN      US08              S         9
# 93      CHAR      10                NaN      US09              S         9
# 94      CHAR      10                NaN      US10              S         9
# 95      CHAR      20                NaN      US11              S         9
# 96      CHAR      20                NaN      US12              S         9
# 97      CHAR      40                NaN      US13              S         9
# 98   DECIMAL      13               13.0      US14              S         9
# 99   DECIMAL      13               13.0      US15              S         9
#
#     data_item_size display_decimals                           row_description  \
# 0             12.0                0  Accounting Code. . . . . . . . . . . . .
# 1             15.0                4  Average Unit Cost. . . . . . . . . . . .
# 2              NaN                0                  AVAILABILITY CHANGE FLAG
# 3              1.0                0  Availability Check . . . . . . . . . . .
# 4              NaN                0                         AVAILABILITY DATE
# 5             15.0                0  Reorder Quantity . . . . . . . . . . . .
# 6              NaN                0                           BACK-ORDER DATE
# 7              NaN                0                                CLASS CODE
# 8              NaN                0                        CASE QUANTITY CODE
# 9             15.0                0  Closing Quantity . . . . . . . . . . . .
# 10            30.0                0  Description. . . . . . . . . . . . . . .
# 11             NaN                0                         DESCRIPTION KEY A
# 12             NaN                0                         DESCRIPTION KEY B
# 13             NaN                0                                    HEIGHT
# 14             1.0                0  Cash Settlement (Y/N). . . . . . . . . .
# 15             6.0                0  Item Number. . . . . . . . . . . . . . .
# 16            10.0                0  Rule Set Name. . . . . . . . . . . . . .
# 17             NaN                0                             ITEM TAX CODE
# 18             1.0                0  Kit Component Lines. . . . . . . . . . .
# 19             NaN                0                                    LENGTH
# 20             NaN                0              N.D.C. CODE-PRIMARY SUPPLIER
# 21             9.0                4  Percentage - Budget Change . . . . . . .
# 22             5.0                0  Prob of Close #1 . . . . . . . . . . . .
# 23             NaN                0                 ITEM SHIPPING METHOD CODE
# 24             NaN                0                              PRODUCT SIZE
# 25             3.0                0  Transaction Code . . . . . . . . . . . .
# 26             NaN                0                         SUBSTITUTION CODE
# 27             8.0                0  Primary / Last Supplier Number . . . . .
# 28             NaN                0                PRIMARY SUPPLIER ITEM CODE
# 29             NaN                0                                    WEIGHT
# 30             NaN                0                                     WIDTH
# 31             1.0                0  DOI Entity Type. . . . . . . . . . . . .
# 32             2.0                0  Location Type. . . . . . . . . . . . . .
# 33             NaN                0                       PRODUCT MAJOR CLASS
# 34             NaN                0                   PRODUCT SUB-MAJOR CLASS
# 35             2.0                0  Claim Code . . . . . . . . . . . . . . .
# 36             NaN                0                   PRODUCT SUB-MINOR CLASS
# 37             8.0                0  Buyer Number . . . . . . . . . . . . . .
# 38             6.0                0  Supplier Code  . . . . . . . . . . . . .
# 39             NaN                0                     Needs Repackaging Y/N
# 40             NaN                0                        Tax Code Array 8 X
# 41             NaN                0                    Undefined Filler Field
# 42             3.0                0  Archive File Group Code. . . . . . . . .
# 43             NaN                0                              DATE ENTERED
# 44             1.0                0  Freight Calculated (Y/N) . . . . . . . .
# 45             NaN                0                               HAZARD CODE
# 46             NaN                0                        ADMIN. CHARGE CODE
# 47             8.0                0  Customer Group . . . . . . . . . . . . .
# 48             NaN                0                      PRINT ON PICK TICKET
# ..             ...              ...                                       ...
# 51             NaN                0                                 JUNK MAIL
# 52             NaN                0                      STOCK,NON-STOCK CODE
# 53             NaN                0                           SALES PLAN CODE
# 54             1.0                0  Method Code. . . . . . . . . . . . . . .
# 55             NaN                0                              MISC. FLAG 1
# 56             NaN                0                              MISC. FLAG 2
# 57             NaN                0                              MISC. FLAG 3
# 58             NaN                0                     WAREHOUSE DESCRIPTION
# 59            60.0                0  Primary Description. . . . . . . . . . .
# 60             6.0                0  Date Regular Coverage Lost . . . . . . .
# 61             NaN                0                       PRODUCT USEFUL LIFE
# 62             NaN                0                           ITEM WATCH CODE
# 63             NaN                0                                NON HAZMAT
# 64             1.0                0  Location Control (Y/N) . . . . . . . . .
# 65             NaN                0                        PRODUCT SHELF LIFE
# 66             NaN                0                      JDE ITEM DESCRIPTION
# 67             2.0                0  Line Type. . . . . . . . . . . . . . . .
# 68             NaN                0                     Item Serial# Required
# 69             NaN                0                               ITEM STATUS
# 70             NaN                0                ITEM E-SHIPPING LABEL TYPE
# 71             NaN                0                      NDC# 10 Digit Edited
# 72             NaN                0                             NDC# 10 Digit
# 73             NaN                0                             NDC# 11 Digit
# 74             NaN                0                           Item Image Link
# 75             NaN                0                            Item Ea Length
# 76             NaN                0                             Item Ea Width
# 77             NaN                0                            Item Ea Heigth
# 78             NaN                0                                  GET IN #
# 79             NaN                0                 Item Extended Description
# 80             NaN                0                       Invoice Description
# 81             NaN                0                     Packing Slip Prt Desc
# 82             NaN                0                         JDE Item Strength
# 83             NaN                0                             Warranty Type
# 84             NaN                0                            Supplier Item#
# 85             5.0                0  Users 01 . . . . . . . . . . . . . . . .
# 86             5.0                0  Users 02 . . . . . . . . . . . . . . . .
# 87             5.0                0  Users 03 . . . . . . . . . . . . . . . .
# 88             5.0                0  Users 04 . . . . . . . . . . . . . . . .
# 89             5.0                0  Users 05 . . . . . . . . . . . . . . . .
# 90             5.0                0  Users 06 . . . . . . . . . . . . . . . .
# 91             5.0                0  Users 07 . . . . . . . . . . . . . . . .
# 92             5.0                0  Users 08 . . . . . . . . . . . . . . . .
# 93             5.0                0  Users 09 . . . . . . . . . . . . . . . .
# 94             5.0                0  Users 10 . . . . . . . . . . . . . . . .
# 95             5.0                0  Users 11 . . . . . . . . . . . . . . . .
# 96             5.0                0  Users 12 . . . . . . . . . . . . . . . .
# 97             5.0                0  Users 13 . . . . . . . . . . . . . . . .
# 98             5.0                0  Users 14 . . . . . . . . . . . . . . . .
# 99             5.0                0  Users 15 . . . . . . . . . . . . . . . .
#
#            row_description_final
# 0                accounting_code
# 1              average_unit_cost
# 2       availability_change_flag
# 3             availability_check
# 4              availability_date
# 5               reorder_quantity
# 6                 backorder_date
# 7                     class_code
# 8             case_quantity_code
# 9               closing_quantity
# 10                   description
# 11             description_key_a
# 12             description_key_b
# 13                        height
# 14            cash_settlement_yn
# 15                   item_number
# 16                 rule_set_name
# 17                 item_tax_code
# 18           kit_component_lines
# 19                        length
# 20      ndc_codeprimary_supplier
# 21      percentage_budget_change
# 22               prob_of_close_1
# 23     item_shipping_method_code
# 24                  product_size
# 25              transaction_code
# 26             substitution_code
# 27  primary_last_supplier_number
# 28    primary_supplier_item_code
# 29                        weight
# 30                         width
# 31               doi_entity_type
# 32                 location_type
# 33           product_major_class
# 34        product_submajor_class
# 35                    claim_code
# 36        product_subminor_class
# 37                  buyer_number
# 38                 supplier_code
# 39          needs_repackaging_yn
# 40            tax_code_array_8_x
# 41        undefined_filler_field
# 42       archive_file_group_code
# 43                  date_entered
# 44         freight_calculated_yn
# 45                   hazard_code
# 46             admin_charge_code
# 47                customer_group
# 48          print_on_pick_ticket
# ..                           ...
# 51                     junk_mail
# 52            stocknonstock_code
# 53               sales_plan_code
# 54                   method_code
# 55                   misc_flag_1
# 56                   misc_flag_2
# 57                   misc_flag_3
# 58         warehouse_description
# 59           primary_description
# 60    date_regular_coverage_lost
# 61           product_useful_life
# 62               item_watch_code
# 63                    non_hazmat
# 64           location_control_yn
# 65            product_shelf_life
# 66          jde_item_description
# 67                     line_type
# 68          item_serial_required
# 69                   item_status
# 70     item_eshipping_label_type
# 71           ndc_10_digit_edited
# 72                  ndc_10_digit
# 73                  ndc_11_digit
# 74               item_image_link
# 75                item_ea_length
# 76                 item_ea_width
# 77                item_ea_heigth
# 78                       get_in_
# 79     item_extended_description
# 80           invoice_description
# 81         packing_slip_prt_desc
# 82             jde_item_strength
# 83                 warranty_type
# 84                 supplier_item
# 85                      users_01
# 86                      users_02
# 87                      users_03
# 88                      users_04
# 89                      users_05
# 90                      users_06
# 91                      users_07
# 92                      users_08
# 93                      users_09
# 94                      users_10
# 95                      users_11
# 96                      users_12
# 97                      users_13
# 98                      users_14
# 99                      users_15
#
# [100 rows x 13 columns]

# %%
def field_format_sel(col_name, col_type, col_dec):
    val =''

    if col_type == 9 :
        if col_dec > 0 :
            val = 'CAST(({})/{} AS DEC({},{})) AS {}'.format(col_name,10**col_dec,15,np.int(col_dec),col_name)
        else :
            val = col_name
    elif  col_type == 11 : 
        if convert_julian_date :
            val = 'CASE WHEN {} IS NOT NULL THEN DATE(DIGITS(DEC({}+ 1900000,7,0))) ELSE NULL END AS {}'.format(col_name, col_name, col_name)
        else :
            val = '{} as {}'.format(col_name,col_name)
    else : 
        val = col_name
    return val;

def field_format_map(col_name, col_descr, is_etl = False):
    val =''

    col_name_format = '{message:{fill}{align}{width}}'.format(message=col_name, fill='_', align='<', width=6)
    
    col_descr_format = col_descr
    if str.isdigit(col_descr_format[0]) :
        col_descr_format = "_" + col_descr_format
        
    if is_etl :
        val = '{}_{} AS {}'.format(col_name_format, col_descr_format, col_descr_format)
    else :
        val = '"{}" AS {}_{}'.format(col_name, col_name_format, col_descr_format)

    return val;



sql_field_map = ', '.join([field_format_map(x,y)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])

sql_field_etl = ', '.join([field_format_map(x,y,is_etl=True)  \
                           for x, y in zip(dff['COLUMN_NAME'], dff['row_description_final'])])
#
# ok
sql_field_sel = ', '.join([ field_format_sel(col_name, col_type, col_dec) \
                           for col_name, col_type, col_dec in zip(dff['COLUMN_NAME'], dff['data_type'], dff['display_decimals'])])

# %%
sql_field_sel
# Out:
# 'IMACDE, CAST((IMACST)/10000.0 AS DEC(15,4)) AS IMACST, IMACHF, IMAVLC, IMADTE, IMRQTY, IMBODT, IMCLSC, IMCQTC, IMCLQT, IMDESC, IMDKYA, IMDKYB, IMHEIG, IMCSET, IMITEM, IMRSET, IMITAX, IMKITC, IMLENG, IMNDC#, CAST((IMPINF)/10000.0 AS DEC(15,4)) AS IMPINF, IMPCL1, IMWGTC, IMSIZE, IMSTRN, IMSCDE, IMVEND, IMVITM, IMWEIG, IMWIDT, IMDTYP, IMLOCT, IMCLMJ, IMCLSJ, IMCLMC, IMCLSM, IMBUYR, IMSUPL, IMRPKE, IMTXCA, IMUDEF, IMPUCD, IMENTD, IMFRTC, IMHAZC, IMADMC, IMCSTP, IMPKTP, IMINVU, IMSLEL, IMJNKM, IMSTCK, IMSLSC, IMPRCD, IMMSC1, IMMSC2, IMMSC3, IMWDSC, IMPDSC, CASE WHEN IMDCLS IS NOT NULL THEN DATE(DIGITS(DEC(IMDCLS+ 1900000,7,0))) ELSE NULL END AS IMDCLS, IMPRLF, IMWCHC, IMNHAZ, IMLCTL, IMPSLF, IMJDSC, IMLNTY, IMSNOR, IMSTAS, IMSLBT, IMNDC1, IMNDC2, IMNDC3, IMMLNK, IMELEN, IMEWID, IMEHEI, IMGIN#, IMEDES, IMIDES, IMPSPD, IMJSTN, IMWTYP, IMSIDS, IMUS01, IMUS02, IMUS03, IMUS04, IMUS05, IMUS06, IMUS07, IMUS08, IMUS09, IMUS10, IMUS11, IMUS12, IMUS13, IMUS14, IMUS15'

# %%
sql_table_map = '''

--------------------------------------------------------------------------------
-- DROP TABLE STAGE_JDE_{}_{}_<instert_friendly_name_here>
--------------------------------------------------------------------------------

SELECT 

    {} 
    {} 

-- INTO {}{}_{}_<instert_friendly_name_here>

FROM 
    OPENQUERY ({}, '

	SELECT
		{}

	FROM
		{}.{}
--    WHERE
--        <insert custom code here>
--    ORDER BY
--        <insert custom code here>
')

--------------------------------------------------------------------------------

-- SELECT {} FROM <...>

'''.format(sql_lib, sql_table, 'Top 5', sql_field_map, stage_db_schema, sql_lib, sql_table, sql_link_server, sql_field_sel, sql_lib, sql_table, sql_field_etl)

# %% [markdown]
# ### Output Table
# 1. Use to create STAGE via link and extract via IBM DTF
# 1. Stub out missing fields from 7.1 -> 9.4, where and Autonum ID
# 1. Note that some Julian _JDT conversion will need to be converted Post

# %%
print(sql_table_map)
# Out:
# --------------------------------------------------------------------------------
# -- DROP TABLE STAGE_JDE_ARCPTEL_NPFIMS_<instert_friendly_name_here>
# --------------------------------------------------------------------------------
#
# SELECT
#
#     Top 5
#     "IMACDE" AS IMACDE_accounting_code, "IMACST" AS IMACST_average_unit_cost, "IMACHF" AS IMACHF_availability_change_flag, "IMAVLC" AS IMAVLC_availability_check, "IMADTE" AS IMADTE_availability_date, "IMRQTY" AS IMRQTY_reorder_quantity, "IMBODT" AS IMBODT_backorder_date, "IMCLSC" AS IMCLSC_class_code, "IMCQTC" AS IMCQTC_case_quantity_code, "IMCLQT" AS IMCLQT_closing_quantity, "IMDESC" AS IMDESC_description, "IMDKYA" AS IMDKYA_description_key_a, "IMDKYB" AS IMDKYB_description_key_b, "IMHEIG" AS IMHEIG_height, "IMCSET" AS IMCSET_cash_settlement_yn, "IMITEM" AS IMITEM_item_number, "IMRSET" AS IMRSET_rule_set_name, "IMITAX" AS IMITAX_item_tax_code, "IMKITC" AS IMKITC_kit_component_lines, "IMLENG" AS IMLENG_length, "IMNDC#" AS IMNDC#_ndc_codeprimary_supplier, "IMPINF" AS IMPINF_percentage_budget_change, "IMPCL1" AS IMPCL1_prob_of_close_1, "IMWGTC" AS IMWGTC_item_shipping_method_code, "IMSIZE" AS IMSIZE_product_size, "IMSTRN" AS IMSTRN_transaction_code, "IMSCDE" AS IMSCDE_substitution_code, "IMVEND" AS IMVEND_primary_last_supplier_number, "IMVITM" AS IMVITM_primary_supplier_item_code, "IMWEIG" AS IMWEIG_weight, "IMWIDT" AS IMWIDT_width, "IMDTYP" AS IMDTYP_doi_entity_type, "IMLOCT" AS IMLOCT_location_type, "IMCLMJ" AS IMCLMJ_product_major_class, "IMCLSJ" AS IMCLSJ_product_submajor_class, "IMCLMC" AS IMCLMC_claim_code, "IMCLSM" AS IMCLSM_product_subminor_class, "IMBUYR" AS IMBUYR_buyer_number, "IMSUPL" AS IMSUPL_supplier_code, "IMRPKE" AS IMRPKE_needs_repackaging_yn, "IMTXCA" AS IMTXCA_tax_code_array_8_x, "IMUDEF" AS IMUDEF_undefined_filler_field, "IMPUCD" AS IMPUCD_archive_file_group_code, "IMENTD" AS IMENTD_date_entered, "IMFRTC" AS IMFRTC_freight_calculated_yn, "IMHAZC" AS IMHAZC_hazard_code, "IMADMC" AS IMADMC_admin_charge_code, "IMCSTP" AS IMCSTP_customer_group, "IMPKTP" AS IMPKTP_print_on_pick_ticket, "IMINVU" AS IMINVU_upd_inventoryservice_level, "IMSLEL" AS IMSLEL_count_as_sales_lnegross_prf, "IMJNKM" AS IMJNKM_junk_mail, "IMSTCK" AS IMSTCK_stocknonstock_code, "IMSLSC" AS IMSLSC_sales_plan_code, "IMPRCD" AS IMPRCD_method_code, "IMMSC1" AS IMMSC1_misc_flag_1, "IMMSC2" AS IMMSC2_misc_flag_2, "IMMSC3" AS IMMSC3_misc_flag_3, "IMWDSC" AS IMWDSC_warehouse_description, "IMPDSC" AS IMPDSC_primary_description, "IMDCLS" AS IMDCLS_date_regular_coverage_lost, "IMPRLF" AS IMPRLF_product_useful_life, "IMWCHC" AS IMWCHC_item_watch_code, "IMNHAZ" AS IMNHAZ_non_hazmat, "IMLCTL" AS IMLCTL_location_control_yn, "IMPSLF" AS IMPSLF_product_shelf_life, "IMJDSC" AS IMJDSC_jde_item_description, "IMLNTY" AS IMLNTY_line_type, "IMSNOR" AS IMSNOR_item_serial_required, "IMSTAS" AS IMSTAS_item_status, "IMSLBT" AS IMSLBT_item_eshipping_label_type, "IMNDC1" AS IMNDC1_ndc_10_digit_edited, "IMNDC2" AS IMNDC2_ndc_10_digit, "IMNDC3" AS IMNDC3_ndc_11_digit, "IMMLNK" AS IMMLNK_item_image_link, "IMELEN" AS IMELEN_item_ea_length, "IMEWID" AS IMEWID_item_ea_width, "IMEHEI" AS IMEHEI_item_ea_heigth, "IMGIN#" AS IMGIN#_get_in_, "IMEDES" AS IMEDES_item_extended_description, "IMIDES" AS IMIDES_invoice_description, "IMPSPD" AS IMPSPD_packing_slip_prt_desc, "IMJSTN" AS IMJSTN_jde_item_strength, "IMWTYP" AS IMWTYP_warranty_type, "IMSIDS" AS IMSIDS_supplier_item, "IMUS01" AS IMUS01_users_01, "IMUS02" AS IMUS02_users_02, "IMUS03" AS IMUS03_users_03, "IMUS04" AS IMUS04_users_04, "IMUS05" AS IMUS05_users_05, "IMUS06" AS IMUS06_users_06, "IMUS07" AS IMUS07_users_07, "IMUS08" AS IMUS08_users_08, "IMUS09" AS IMUS09_users_09, "IMUS10" AS IMUS10_users_10, "IMUS11" AS IMUS11_users_11, "IMUS12" AS IMUS12_users_12, "IMUS13" AS IMUS13_users_13, "IMUS14" AS IMUS14_users_14, "IMUS15" AS IMUS15_users_15
#
# -- INTO etl.ARCPTEL_NPFIMS_<instert_friendly_name_here>
#
# FROM
#     OPENQUERY (ESYS_PROD, '
#
# 	SELECT
# 		IMACDE, CAST((IMACST)/10000.0 AS DEC(15,4)) AS IMACST, IMACHF, IMAVLC, IMADTE, IMRQTY, IMBODT, IMCLSC, IMCQTC, IMCLQT, IMDESC, IMDKYA, IMDKYB, IMHEIG, IMCSET, IMITEM, IMRSET, IMITAX, IMKITC, IMLENG, IMNDC#, CAST((IMPINF)/10000.0 AS DEC(15,4)) AS IMPINF, IMPCL1, IMWGTC, IMSIZE, IMSTRN, IMSCDE, IMVEND, IMVITM, IMWEIG, IMWIDT, IMDTYP, IMLOCT, IMCLMJ, IMCLSJ, IMCLMC, IMCLSM, IMBUYR, IMSUPL, IMRPKE, IMTXCA, IMUDEF, IMPUCD, IMENTD, IMFRTC, IMHAZC, IMADMC, IMCSTP, IMPKTP, IMINVU, IMSLEL, IMJNKM, IMSTCK, IMSLSC, IMPRCD, IMMSC1, IMMSC2, IMMSC3, IMWDSC, IMPDSC, CASE WHEN IMDCLS IS NOT NULL THEN DATE(DIGITS(DEC(IMDCLS+ 1900000,7,0))) ELSE NULL END AS IMDCLS, IMPRLF, IMWCHC, IMNHAZ, IMLCTL, IMPSLF, IMJDSC, IMLNTY, IMSNOR, IMSTAS, IMSLBT, IMNDC1, IMNDC2, IMNDC3, IMMLNK, IMELEN, IMEWID, IMEHEI, IMGIN#, IMEDES, IMIDES, IMPSPD, IMJSTN, IMWTYP, IMSIDS, IMUS01, IMUS02, IMUS03, IMUS04, IMUS05, IMUS06, IMUS07, IMUS08, IMUS09, IMUS10, IMUS11, IMUS12, IMUS13, IMUS14, IMUS15
#
# 	FROM
# 		ARCPTEL.NPFIMS
# --    WHERE
# --        <insert custom code here>
# --    ORDER BY
# --        <insert custom code here>
# ')
#
# --------------------------------------------------------------------------------
#
# -- SELECT IMACDE_accounting_code AS accounting_code, IMACST_average_unit_cost AS average_unit_cost, IMACHF_availability_change_flag AS availability_change_flag, IMAVLC_availability_check AS availability_check, IMADTE_availability_date AS availability_date, IMRQTY_reorder_quantity AS reorder_quantity, IMBODT_backorder_date AS backorder_date, IMCLSC_class_code AS class_code, IMCQTC_case_quantity_code AS case_quantity_code, IMCLQT_closing_quantity AS closing_quantity, IMDESC_description AS description, IMDKYA_description_key_a AS description_key_a, IMDKYB_description_key_b AS description_key_b, IMHEIG_height AS height, IMCSET_cash_settlement_yn AS cash_settlement_yn, IMITEM_item_number AS item_number, IMRSET_rule_set_name AS rule_set_name, IMITAX_item_tax_code AS item_tax_code, IMKITC_kit_component_lines AS kit_component_lines, IMLENG_length AS length, IMNDC#_ndc_codeprimary_supplier AS ndc_codeprimary_supplier, IMPINF_percentage_budget_change AS percentage_budget_change, IMPCL1_prob_of_close_1 AS prob_of_close_1, IMWGTC_item_shipping_method_code AS item_shipping_method_code, IMSIZE_product_size AS product_size, IMSTRN_transaction_code AS transaction_code, IMSCDE_substitution_code AS substitution_code, IMVEND_primary_last_supplier_number AS primary_last_supplier_number, IMVITM_primary_supplier_item_code AS primary_supplier_item_code, IMWEIG_weight AS weight, IMWIDT_width AS width, IMDTYP_doi_entity_type AS doi_entity_type, IMLOCT_location_type AS location_type, IMCLMJ_product_major_class AS product_major_class, IMCLSJ_product_submajor_class AS product_submajor_class, IMCLMC_claim_code AS claim_code, IMCLSM_product_subminor_class AS product_subminor_class, IMBUYR_buyer_number AS buyer_number, IMSUPL_supplier_code AS supplier_code, IMRPKE_needs_repackaging_yn AS needs_repackaging_yn, IMTXCA_tax_code_array_8_x AS tax_code_array_8_x, IMUDEF_undefined_filler_field AS undefined_filler_field, IMPUCD_archive_file_group_code AS archive_file_group_code, IMENTD_date_entered AS date_entered, IMFRTC_freight_calculated_yn AS freight_calculated_yn, IMHAZC_hazard_code AS hazard_code, IMADMC_admin_charge_code AS admin_charge_code, IMCSTP_customer_group AS customer_group, IMPKTP_print_on_pick_ticket AS print_on_pick_ticket, IMINVU_upd_inventoryservice_level AS upd_inventoryservice_level, IMSLEL_count_as_sales_lnegross_prf AS count_as_sales_lnegross_prf, IMJNKM_junk_mail AS junk_mail, IMSTCK_stocknonstock_code AS stocknonstock_code, IMSLSC_sales_plan_code AS sales_plan_code, IMPRCD_method_code AS method_code, IMMSC1_misc_flag_1 AS misc_flag_1, IMMSC2_misc_flag_2 AS misc_flag_2, IMMSC3_misc_flag_3 AS misc_flag_3, IMWDSC_warehouse_description AS warehouse_description, IMPDSC_primary_description AS primary_description, IMDCLS_date_regular_coverage_lost AS date_regular_coverage_lost, IMPRLF_product_useful_life AS product_useful_life, IMWCHC_item_watch_code AS item_watch_code, IMNHAZ_non_hazmat AS non_hazmat, IMLCTL_location_control_yn AS location_control_yn, IMPSLF_product_shelf_life AS product_shelf_life, IMJDSC_jde_item_description AS jde_item_description, IMLNTY_line_type AS line_type, IMSNOR_item_serial_required AS item_serial_required, IMSTAS_item_status AS item_status, IMSLBT_item_eshipping_label_type AS item_eshipping_label_type, IMNDC1_ndc_10_digit_edited AS ndc_10_digit_edited, IMNDC2_ndc_10_digit AS ndc_10_digit, IMNDC3_ndc_11_digit AS ndc_11_digit, IMMLNK_item_image_link AS item_image_link, IMELEN_item_ea_length AS item_ea_length, IMEWID_item_ea_width AS item_ea_width, IMEHEI_item_ea_heigth AS item_ea_heigth, IMGIN#_get_in_ AS get_in_, IMEDES_item_extended_description AS item_extended_description, IMIDES_invoice_description AS invoice_description, IMPSPD_packing_slip_prt_desc AS packing_slip_prt_desc, IMJSTN_jde_item_strength AS jde_item_strength, IMWTYP_warranty_type AS warranty_type, IMSIDS_supplier_item AS supplier_item, IMUS01_users_01 AS users_01, IMUS02_users_02 AS users_02, IMUS03_users_03 AS users_03, IMUS04_users_04 AS users_04, IMU ...

# %%
dff
# Out:
#     ORDINAL_POSITION COLUMN_NAME                                COLUMN_TEXT  \
# 0                  1      IMACDE                              ACTIVITY CODE
# 1                  2      IMACST                          Item Average Cost
# 2                  3      IMACHF                   AVAILABILITY CHANGE FLAG
# 3                  4      IMAVLC                AVAILABILITY CODE CORPORATE
# 4                  5      IMADTE                          AVAILABILITY DATE
# 5                  6      IMRQTY                        RESTRICTED QUANTITY
# 6                  7      IMBODT                            BACK-ORDER DATE
# 7                  8      IMCLSC                                 CLASS CODE
# 8                  9      IMCQTC                         CASE QUANTITY CODE
# 9                 10      IMCLQT                          CASE LOT QUANTITY
# 10                11      IMDESC                                DESCRIPTION
# 11                12      IMDKYA                          DESCRIPTION KEY A
# 12                13      IMDKYB                          DESCRIPTION KEY B
# 13                14      IMHEIG                                     HEIGHT
# 14                15      IMCSET                       ITEM FAMILY COST SET
# 15                16      IMITEM                                  ITEM CODE
# 16                17      IMRSET                     ITEM FAMILY RESALE SET
# 17                18      IMITAX                              ITEM TAX CODE
# 18                19      IMKITC  'M' = MIX/MATCH,'N' = MIX/MATCH GROUP RCD
# 19                20      IMLENG                                     LENGTH
# 20                21      IMNDC#               N.D.C. CODE-PRIMARY SUPPLIER
# 21                22      IMPINF                        PRICING INFORMATION
# 22                23      IMPCL1         PRODUCT CLASSIFICATION CODE, MAJOR
# 23                24      IMWGTC                  ITEM SHIPPING METHOD CODE
# 24                25      IMSIZE                               PRODUCT SIZE
# 25                26      IMSTRN                              ITEM STRENGTH
# 26                27      IMSCDE                          SUBSTITUTION CODE
# 27                28      IMVEND                                VENDOR CODE
# 28                29      IMVITM                 PRIMARY SUPPLIER ITEM CODE
# 29                30      IMWEIG                                     WEIGHT
# 30                31      IMWIDT                                      WIDTH
# 31                32      IMDTYP                          PRODUCT DATE TYPE
# 32                33      IMLOCT                              LOCATION TYPE
# 33                34      IMCLMJ                        PRODUCT MAJOR CLASS
# 34                35      IMCLSJ                    PRODUCT SUB-MAJOR CLASS
# 35                36      IMCLMC                        PRODUCT MINOR CLASS
# 36                37      IMCLSM                    PRODUCT SUB-MINOR CLASS
# 37                38      IMBUYR                               BUYER NUMBER
# 38                39      IMSUPL                      PRIMARY SUPPLIER CODE
# 39                40      IMRPKE                      Needs Repackaging Y/N
# 40                41      IMTXCA                         Tax Code Array 8 X
# 41                42      IMUDEF                     Undefined Filler Field
# 42                43      IMPUCD                              Purchase Code
# 43                44      IMENTD                               DATE ENTERED
# 44                45      IMFRTC                               FREIGHT CODE
# 45                46      IMHAZC                                HAZARD CODE
# 46                47      IMADMC                         ADMIN. CHARGE CODE
# 47                48      IMCSTP                    % RESALE TO USE AS COST
# 48                49      IMPKTP                       PRINT ON PICK TICKET
# ..               ...         ...                                        ...
# 51                52      IMJNKM                                  JUNK MAIL
# 52                53      IMSTCK                       STOCK,NON-STOCK CODE
# 53                54      IMSLSC                            SALES PLAN CODE
# 54                55      IMPRCD                             PRICE LOT CODE
# 55                56      IMMSC1                               MISC. FLAG 1
# 56                57      IMMSC2                               MISC. FLAG 2
# 57                58      IMMSC3                               MISC. FLAG 3
# 58                59      IMWDSC                      WAREHOUSE DESCRIPTION
# 59                60      IMPDSC                       PHONETIC DESCRIPTION
# 60                61      IMDCLS                        DATE CLASSIFICATION
# 61                62      IMPRLF                        PRODUCT USEFUL LIFE
# 62                63      IMWCHC                            ITEM WATCH CODE
# 63                64      IMNHAZ                                 NON HAZMAT
# 64                65      IMLCTL                           ITEM LOT CONTROL
# 65                66      IMPSLF                         PRODUCT SHELF LIFE
# 66                67      IMJDSC                       JDE ITEM DESCRIPTION
# 67                68      IMLNTY                              JDE LINE TYPE
# 68                69      IMSNOR                      Item Serial# Required
# 69                70      IMSTAS                                ITEM STATUS
# 70                71      IMSLBT                 ITEM E-SHIPPING LABEL TYPE
# 71                72      IMNDC1                       NDC# 10 Digit Edited
# 72                73      IMNDC2                              NDC# 10 Digit
# 73                74      IMNDC3                              NDC# 11 Digit
# 74                75      IMMLNK                            Item Image Link
# 75                76      IMELEN                             Item Ea Length
# 76                77      IMEWID                              Item Ea Width
# 77                78      IMEHEI                             Item Ea Heigth
# 78                79      IMGIN#                                   GET IN #
# 79                80      IMEDES                  Item Extended Description
# 80                81      IMIDES                        Invoice Description
# 81                82      IMPSPD                      Packing Slip Prt Desc
# 82                83      IMJSTN                          JDE Item Strength
# 83                84      IMWTYP                              Warranty Type
# 84                85      IMSIDS                             Supplier Item#
# 85                86      IMUS01                            Future Use - 01
# 86                87      IMUS02                            Future Use - 02
# 87                88      IMUS03                            Future Use - 03
# 88                89      IMUS04                            Future Use - 04
# 89                90      IMUS05                            Future Use - 05
# 90                91      IMUS06                            Future Use - 06
# 91                92      IMUS07                            Future Use - 07
# 92                93      IMUS08                            Future Use - 08
# 93                94      IMUS09                            Future Use - 09
# 94                95      IMUS10                            Future Use - 10
# 95                96      IMUS11                            Future Use - 11
# 96                97      IMUS12                            Future Use - 12
# 97                98      IMUS13                            Future Use - 13
# 98                99      IMUS14                            Future Use - 14
# 99               100      IMUS15                            Future Use - 15
#
#    DATA_TYPE  LENGTH  NUMERIC_PRECISION data_item data_item_type data_type  \
# 0       CHAR       1                NaN      ACDE              A         2
# 1    DECIMAL       9                9.0      ACST              P         9
# 2       CHAR       1                NaN      ACHF            NaN         0
# 3       CHAR       1                NaN      AVLC              A         1
# 4    DECIMAL       6                6.0      ADTE            NaN         0
# 5    DECIMAL       5                5.0      RQTY              P         9
# 6    DECIMAL       6                6.0      BODT            NaN         0
# 7       CHAR       2                NaN      CLSC            NaN         0
# 8       CHAR       1                NaN      CQTC            NaN         0
# 9    DECIMAL       4                4.0      CLQT              P         9
# 10      CHAR      25                NaN      DESC              O         2
# 11      CHAR      25                NaN      DKYA            NaN         0
# 12      CHAR      25                NaN      DKYB            NaN         0
# 13   DECIMAL       5                5.0      HEIG            NaN         0
# 14      CHAR       7                NaN      CSET              A         1
# 15      CHAR       7                NaN      ITEM              A         2
# 16      CHAR       7                NaN      RSET              A         9
# 17      CHAR       1                NaN      ITAX            NaN         0
# 18      CHAR       1                NaN      KITC              A         1
# 19   DECIMAL       5                5.0      LENG            NaN         0
# 20   DECIMAL      11               11.0      NDC#            NaN         0
# 21      CHAR      20                NaN      PINF              P         9
# 22      CHAR       3                NaN      PCL1              A         2
# 23      CHAR       3                NaN      WGTC            NaN         0
# 24      CHAR       8                NaN      SIZE            NaN         0
# 25      CHAR       7                NaN      STRN              A         2
# 26      CHAR       1                NaN      SCDE            NaN         0
# 27      CHAR       6                NaN      VEND              S         9
# 28      CHAR      12                NaN      VITM            NaN         0
# 29   DECIMAL       5                5.0      WEIG            NaN         0
# 30   DECIMAL       5                5.0      WIDT            NaN         0
# 31      CHAR       1                NaN      DTYP              A         1
# 32      CHAR       2                NaN      LOCT              A         2
# 33      CHAR       3                NaN      CLMJ            NaN         0
# 34      CHAR       2                NaN      CLSJ            NaN         0
# 35      CHAR       2                NaN      CLMC              P         9
# 36      CHAR       2                NaN      CLSM            NaN         0
# 37   DECIMAL       5                5.0      BUYR              S         9
# 38      CHAR       6                NaN      SUPL              A         2
# 39      CHAR       1                NaN      RPKE            NaN         0
# 40      CHAR       8                NaN      TXCA            NaN         0
# 41      CHAR      20                NaN      UDEF            NaN         0
# 42      CHAR       1                NaN      PUCD              A         2
# 43   DECIMAL       7                7.0      ENTD            NaN         0
# 44      CHAR       1                NaN      FRTC              A         1
# 45      CHAR       2                NaN      HAZC            NaN         0
# 46      CHAR       1                NaN      ADMC            NaN         0
# 47   DECIMAL       4                4.0      CSTP              A         2
# 48      CHAR       1                NaN      PKTP            NaN         0
# ..       ...     ...                ...       ...            ...       ...
# 51      CHAR       1                NaN      JNKM            NaN         0
# 52      CHAR       1                NaN      STCK            NaN         0
# 53      CHAR       1                NaN      SLSC            NaN         0
# 54      CHAR       1                NaN      PRCD              A         1
# 55      CHAR       1                NaN      MSC1            NaN         0
# 56      CHAR       1                NaN      MSC2            NaN         0
# 57      CHAR       1                NaN      MSC3            NaN         0
# 58      CHAR      45                NaN      WDSC            NaN         0
# 59      CHAR      45                NaN      PDSC              O         2
# 60      CHAR       1                NaN      DCLS              S        11
# 61   DECIMAL       5                5.0      PRLF            NaN         0
# 62      CHAR       3                NaN      WCHC            NaN         0
# 63      CHAR       1                NaN      NHAZ            NaN         0
# 64      CHAR       2                NaN      LCTL              A         1
# 65   DECIMAL       2                2.0      PSLF            NaN         0
# 66      CHAR      30                NaN      JDSC            NaN         0
# 67      CHAR       2                NaN      LNTY              A         2
# 68      CHAR       1                NaN      SNOR            NaN         0
# 69      CHAR       2                NaN      STAS            NaN         0
# 70      CHAR       2                NaN      SLBT            NaN         0
# 71   DECIMAL      10               10.0      NDC1            NaN         0
# 72      CHAR      12                NaN      NDC2            NaN         0
# 73      CHAR      13                NaN      NDC3            NaN         0
# 74      CHAR      60                NaN      MLNK            NaN         0
# 75   DECIMAL       6                6.0      ELEN            NaN         0
# 76   DECIMAL       6                6.0      EWID            NaN         0
# 77   DECIMAL       6                6.0      EHEI            NaN         0
# 78      CHAR      14                NaN      GIN#            NaN         0
# 79      CHAR      65                NaN      EDES            NaN         0
# 80      CHAR      65                NaN      IDES            NaN         0
# 81      CHAR      65                NaN      PSPD            NaN         0
# 82      CHAR      12                NaN      JSTN            NaN         0
# 83      CHAR       8                NaN      WTYP            NaN         0
# 84      CHAR      25                NaN      SIDS            NaN         0
# 85      CHAR       2                NaN      US01              S         9
# 86      CHAR       2                NaN      US02              S         9
# 87      CHAR       2                NaN      US03              S         9
# 88      CHAR       2                NaN      US04              S         9
# 89      CHAR       2                NaN      US05              S         9
# 90      CHAR       5                NaN      US06              S         9
# 91      CHAR       5                NaN      US07              S         9
# 92      CHAR      10                NaN      US08              S         9
# 93      CHAR      10                NaN      US09              S         9
# 94      CHAR      10                NaN      US10              S         9
# 95      CHAR      20                NaN      US11              S         9
# 96      CHAR      20                NaN      US12              S         9
# 97      CHAR      40                NaN      US13              S         9
# 98   DECIMAL      13               13.0      US14              S         9
# 99   DECIMAL      13               13.0      US15              S         9
#
#     data_item_size display_decimals                           row_description  \
# 0             12.0                0  Accounting Code. . . . . . . . . . . . .
# 1             15.0                4  Average Unit Cost. . . . . . . . . . . .
# 2              NaN                0                  AVAILABILITY CHANGE FLAG
# 3              1.0                0  Availability Check . . . . . . . . . . .
# 4              NaN                0                         AVAILABILITY DATE
# 5             15.0                0  Reorder Quantity . . . . . . . . . . . .
# 6              NaN                0                           BACK-ORDER DATE
# 7              NaN                0                                CLASS CODE
# 8              NaN                0                        CASE QUANTITY CODE
# 9             15.0                0  Closing Quantity . . . . . . . . . . . .
# 10            30.0                0  Description. . . . . . . . . . . . . . .
# 11             NaN                0                         DESCRIPTION KEY A
# 12             NaN                0                         DESCRIPTION KEY B
# 13             NaN                0                                    HEIGHT
# 14             1.0                0  Cash Settlement (Y/N). . . . . . . . . .
# 15             6.0                0  Item Number. . . . . . . . . . . . . . .
# 16            10.0                0  Rule Set Name. . . . . . . . . . . . . .
# 17             NaN                0                             ITEM TAX CODE
# 18             1.0                0  Kit Component Lines. . . . . . . . . . .
# 19             NaN                0                                    LENGTH
# 20             NaN                0              N.D.C. CODE-PRIMARY SUPPLIER
# 21             9.0                4  Percentage - Budget Change . . . . . . .
# 22             5.0                0  Prob of Close #1 . . . . . . . . . . . .
# 23             NaN                0                 ITEM SHIPPING METHOD CODE
# 24             NaN                0                              PRODUCT SIZE
# 25             3.0                0  Transaction Code . . . . . . . . . . . .
# 26             NaN                0                         SUBSTITUTION CODE
# 27             8.0                0  Primary / Last Supplier Number . . . . .
# 28             NaN                0                PRIMARY SUPPLIER ITEM CODE
# 29             NaN                0                                    WEIGHT
# 30             NaN                0                                     WIDTH
# 31             1.0                0  DOI Entity Type. . . . . . . . . . . . .
# 32             2.0                0  Location Type. . . . . . . . . . . . . .
# 33             NaN                0                       PRODUCT MAJOR CLASS
# 34             NaN                0                   PRODUCT SUB-MAJOR CLASS
# 35             2.0                0  Claim Code . . . . . . . . . . . . . . .
# 36             NaN                0                   PRODUCT SUB-MINOR CLASS
# 37             8.0                0  Buyer Number . . . . . . . . . . . . . .
# 38             6.0                0  Supplier Code  . . . . . . . . . . . . .
# 39             NaN                0                     Needs Repackaging Y/N
# 40             NaN                0                        Tax Code Array 8 X
# 41             NaN                0                    Undefined Filler Field
# 42             3.0                0  Archive File Group Code. . . . . . . . .
# 43             NaN                0                              DATE ENTERED
# 44             1.0                0  Freight Calculated (Y/N) . . . . . . . .
# 45             NaN                0                               HAZARD CODE
# 46             NaN                0                        ADMIN. CHARGE CODE
# 47             8.0                0  Customer Group . . . . . . . . . . . . .
# 48             NaN                0                      PRINT ON PICK TICKET
# ..             ...              ...                                       ...
# 51             NaN                0                                 JUNK MAIL
# 52             NaN                0                      STOCK,NON-STOCK CODE
# 53             NaN                0                           SALES PLAN CODE
# 54             1.0                0  Method Code. . . . . . . . . . . . . . .
# 55             NaN                0                              MISC. FLAG 1
# 56             NaN                0                              MISC. FLAG 2
# 57             NaN                0                              MISC. FLAG 3
# 58             NaN                0                     WAREHOUSE DESCRIPTION
# 59            60.0                0  Primary Description. . . . . . . . . . .
# 60             6.0                0  Date Regular Coverage Lost . . . . . . .
# 61             NaN                0                       PRODUCT USEFUL LIFE
# 62             NaN                0                           ITEM WATCH CODE
# 63             NaN                0                                NON HAZMAT
# 64             1.0                0  Location Control (Y/N) . . . . . . . . .
# 65             NaN                0                        PRODUCT SHELF LIFE
# 66             NaN                0                      JDE ITEM DESCRIPTION
# 67             2.0                0  Line Type. . . . . . . . . . . . . . . .
# 68             NaN                0                     Item Serial# Required
# 69             NaN                0                               ITEM STATUS
# 70             NaN                0                ITEM E-SHIPPING LABEL TYPE
# 71             NaN                0                      NDC# 10 Digit Edited
# 72             NaN                0                             NDC# 10 Digit
# 73             NaN                0                             NDC# 11 Digit
# 74             NaN                0                           Item Image Link
# 75             NaN                0                            Item Ea Length
# 76             NaN                0                             Item Ea Width
# 77             NaN                0                            Item Ea Heigth
# 78             NaN                0                                  GET IN #
# 79             NaN                0                 Item Extended Description
# 80             NaN                0                       Invoice Description
# 81             NaN                0                     Packing Slip Prt Desc
# 82             NaN                0                         JDE Item Strength
# 83             NaN                0                             Warranty Type
# 84             NaN                0                            Supplier Item#
# 85             5.0                0  Users 01 . . . . . . . . . . . . . . . .
# 86             5.0                0  Users 02 . . . . . . . . . . . . . . . .
# 87             5.0                0  Users 03 . . . . . . . . . . . . . . . .
# 88             5.0                0  Users 04 . . . . . . . . . . . . . . . .
# 89             5.0                0  Users 05 . . . . . . . . . . . . . . . .
# 90             5.0                0  Users 06 . . . . . . . . . . . . . . . .
# 91             5.0                0  Users 07 . . . . . . . . . . . . . . . .
# 92             5.0                0  Users 08 . . . . . . . . . . . . . . . .
# 93             5.0                0  Users 09 . . . . . . . . . . . . . . . .
# 94             5.0                0  Users 10 . . . . . . . . . . . . . . . .
# 95             5.0                0  Users 11 . . . . . . . . . . . . . . . .
# 96             5.0                0  Users 12 . . . . . . . . . . . . . . . .
# 97             5.0                0  Users 13 . . . . . . . . . . . . . . . .
# 98             5.0                0  Users 14 . . . . . . . . . . . . . . . .
# 99             5.0                0  Users 15 . . . . . . . . . . . . . . . .
#
#            row_description_final
# 0                accounting_code
# 1              average_unit_cost
# 2       availability_change_flag
# 3             availability_check
# 4              availability_date
# 5               reorder_quantity
# 6                 backorder_date
# 7                     class_code
# 8             case_quantity_code
# 9               closing_quantity
# 10                   description
# 11             description_key_a
# 12             description_key_b
# 13                        height
# 14            cash_settlement_yn
# 15                   item_number
# 16                 rule_set_name
# 17                 item_tax_code
# 18           kit_component_lines
# 19                        length
# 20      ndc_codeprimary_supplier
# 21      percentage_budget_change
# 22               prob_of_close_1
# 23     item_shipping_method_code
# 24                  product_size
# 25              transaction_code
# 26             substitution_code
# 27  primary_last_supplier_number
# 28    primary_supplier_item_code
# 29                        weight
# 30                         width
# 31               doi_entity_type
# 32                 location_type
# 33           product_major_class
# 34        product_submajor_class
# 35                    claim_code
# 36        product_subminor_class
# 37                  buyer_number
# 38                 supplier_code
# 39          needs_repackaging_yn
# 40            tax_code_array_8_x
# 41        undefined_filler_field
# 42       archive_file_group_code
# 43                  date_entered
# 44         freight_calculated_yn
# 45                   hazard_code
# 46             admin_charge_code
# 47                customer_group
# 48          print_on_pick_ticket
# ..                           ...
# 51                     junk_mail
# 52            stocknonstock_code
# 53               sales_plan_code
# 54                   method_code
# 55                   misc_flag_1
# 56                   misc_flag_2
# 57                   misc_flag_3
# 58         warehouse_description
# 59           primary_description
# 60    date_regular_coverage_lost
# 61           product_useful_life
# 62               item_watch_code
# 63                    non_hazmat
# 64           location_control_yn
# 65            product_shelf_life
# 66          jde_item_description
# 67                     line_type
# 68          item_serial_required
# 69                   item_status
# 70     item_eshipping_label_type
# 71           ndc_10_digit_edited
# 72                  ndc_10_digit
# 73                  ndc_11_digit
# 74               item_image_link
# 75                item_ea_length
# 76                 item_ea_width
# 77                item_ea_heigth
# 78                       get_in_
# 79     item_extended_description
# 80           invoice_description
# 81         packing_slip_prt_desc
# 82             jde_item_strength
# 83                 warranty_type
# 84                 supplier_item
# 85                      users_01
# 86                      users_02
# 87                      users_03
# 88                      users_04
# 89                      users_05
# 90                      users_06
# 91                      users_07
# 92                      users_08
# 93                      users_09
# 94                      users_10
# 95                      users_11
# 96                      users_12
# 97                      users_13
# 98                      users_14
# 99                      users_15
#
# [100 rows x 13 columns]

# %%
# %time df_table_map = pd.read_sql_query(sql_table_map, engine);
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# pymssql.pyx in pymssql.Cursor.execute()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_query()
#
# _mssql.pyx in _mssql.MSSQLConnection.execute_query()
#
# _mssql.pyx in _mssql.MSSQLConnection.get_result()
#
# _mssql.pyx in _mssql.check_cancel_and_raise()
#
# _mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (7342, b'An unexpected NULL value was returned for column "[MSDASQL].IMPINF" from OLE DB provider "MSDASQL" for linked server "ESYS_PROD". This column cannot be NULL.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# pymssql.pyx in pymssql.Cursor.execute()
#
# OperationalError: (7342, b'An unexpected NULL value was returned for column "[MSDASQL].IMPINF" from OLE DB provider "MSDASQL" for linked server "ESYS_PROD". This column cannot be NULL.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <timed exec> in <module>()
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     329     return pandas_sql.read_query(
#     330         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 331         parse_dates=parse_dates, chunksize=chunksize)
#     332
#     333
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1082         args = _convert_params(sql, params)
#    1083
# -> 1084         result = self.execute(*args)
#    1085         columns = result.keys()
#    1086
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     973     def execute(self, *args, **kwargs):
#     974         """Simple passthrough to SQLAlchemy connectable"""
# --> 975         return self.connectable.execute(*args, **kwargs)
#     976
#     977     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2062
#    2063         connection = self.contextual_connect(close_with_result=True)
# -> 2064         return connection.execute(statement, *multiparams, **params)
#    2065
#    2066     def scalar(self, statement, *multiparams, **params):
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     937         """
#     938         if isinstance(object, util.string_types[0]):
# --> 939             return self._execute_text(object, multiparams, params)
#     940         try:
#     941             meth = object._execute_on_connection
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1095             statement,
#    1096             parameters,
# -> 1097             statement, parameters
#    1098         )
#    1099         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#     472     def do_execute_no_params(self, cursor, statement, context=None):
#
# pymssql.pyx in pymssql.Cursor.execute()
#
# OperationalError: (pymssql.OperationalError) (7342, b'An unexpected NULL value was returned for column "[MSDASQL].IMPINF" from OLE DB provider "MSDASQL" for linked server "ESYS_PROD". This column cannot be NULL.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n') [SQL: '\n\n--------------------------------------------------------------------------------\n-- DROP TABLE STAGE_JDE_ARCPTEL_NPFIMS_<instert_friendly_name_here>\n--------------------------------------------------------------------------------\n\nSELECT \n\n    Top 5 \n    "IMACDE" AS IMACDE_accounting_code, "IMACST" AS IMACST_average_unit_cost, "IMACHF" AS IMACHF_availability_change_flag, "IMAVLC" AS IMAVLC_availability_check, "IMADTE" AS IMADTE_availability_date, "IMRQTY" AS IMRQTY_reorder_quantity, "IMBODT" AS IMBODT_backorder_date, "IMCLSC" AS IMCLSC_class_code, "IMCQTC" AS IMCQTC_case_quantity_code, "IMCLQT" AS IMCLQT_closing_quantity, "IMDESC" AS IMDESC_description, "IMDKYA" AS IMDKYA_description_key_a, "IMDKYB" AS IMDKYB_description_key_b, "IMHEIG" AS IMHEIG_height, "IMCSET" AS IMCSET_cash_settlement_yn, "IMITEM" AS IMITEM_item_number, "IMRSET" AS IMRSET_rule_set_name, "IMITAX" AS IMITAX_item_tax_code, "IMKITC" AS IMKITC_kit_component_lines, "IMLENG" AS IMLENG_length, "IMNDC#" AS IMNDC#_ndc_codeprimary_supplier, "IMPINF" AS IMPINF_percentage_budget_change, "IMPCL1" AS IMPCL1_prob_of_close_1, "IMWGTC" AS IMWGTC_item_shipping_method_code, "IMSIZE" AS IMSIZE_product_size, "IMSTRN" AS IMSTRN_transaction_code, "IMSCDE" AS IMSCDE_substitution_code, "IMVEND" AS IMVEND_primary_last_supplier_number, "IMVITM" AS IMVITM_primary_supplier_item_code, "IMWEIG" AS IMWEIG_weight, "IMWIDT" AS IMWIDT_width, "IMDTYP" AS IMDTYP_doi_entity_type, "IMLOCT" AS IMLOCT_location_type, "IMCLMJ" AS IMCLMJ_product_major_class, "IMCLSJ" AS IMCLSJ_product_submajor_class, "IMCLMC" AS IMCLMC_claim_code, "IMCLSM" AS IMCLSM_product_subminor_class, "IMBUYR" AS IMBUYR_buyer_number, "IMSUPL" AS IMSUPL_supplier_code, "IMRPKE" AS IMRPKE_needs_repackaging_yn, "IMTXCA" AS IMTXCA_tax_code_array_8_x, "IMUDEF" AS IMUDEF_undefined_filler_field, "IMPUCD" AS IMPUCD_archive_file_group_code, "IMENTD" AS IMENTD_date_entered, "IMFRTC" AS IMFRTC_freight_calculated_yn, "IMHAZC" AS IMHAZC_hazard_code, "IMADMC" AS IMADMC_admin_charge_code, "IMCSTP" AS IMCSTP_customer_group, "IMPKTP" AS IMPKTP_print_on_pick_ticket, "IMINVU" AS IMINVU_upd_inventoryservice_level, "IMSLEL" AS IMSLEL_count_as_sales_lnegross_prf, "IMJNKM" AS IMJNKM_junk_mail, "IMSTCK" AS IMSTCK_stocknonstock_code, "IMSLSC" AS IMSLSC_sales_plan_code, "IMPRCD" AS IMPRCD_method_code, "IMMSC1" AS IMMSC1_misc_flag_1, "IMMSC2" AS IMMSC2_misc_flag_2, "IMMSC3" AS IMMSC3_misc_flag_3, "IMWDSC" AS IMWDSC_warehouse_description, "IMPDSC" AS IMPDSC_primary_description, "IMDCLS" AS IMDCLS_date_regular_coverage_lost, "IMPRLF" AS IMPRLF_product_useful_life, "IMWCHC" AS IMWCHC_item_watch_code, "IMNHAZ" AS IMNHAZ_non_hazmat, "IMLCTL" AS IMLCTL_location_control_yn, "IMPSLF" AS IMPSLF_product_shelf_life, "IMJDSC" AS IMJDSC_jde_item_description, "IMLNTY" AS IMLNTY_line_type, "IMSNOR" AS IMSNOR_item_serial_required, "IMSTAS" AS IMSTAS_item_status, "IMSLBT" AS IMSLBT_item_eshipping_label_type, "IMNDC1" AS IMNDC1_ndc_10_digit_edited, "IMNDC2" AS IMNDC2_ndc_10_digit, "IMNDC3" AS IMNDC3_ndc_11_digit, "IMMLNK" AS IMMLNK_item_image_link, "IMELEN" AS IMELEN_item_ea_length, "IMEWID" AS IMEWID_item_ea_width, "IMEHEI" AS IMEHEI_item_ea_heigth, "IMGIN#" AS IMGIN#_get_in_, "IMEDES" AS IMEDES_item_extended_description, "IMIDES" AS IMIDES_invoice_description, "IMPSPD" AS IMPSPD_packing_slip_prt_desc, "IMJSTN" AS IMJSTN_jde_item_strength, "IMWTYP" AS IMWTYP_warranty_type, "IMSIDS" AS IMSIDS_supplier_item, "IMUS01" AS IMUS01_users_01, "IMUS02" AS IMUS02_users_02, "IMUS03" AS IMUS03_users_03, "IMUS04" AS IMUS04_users_04, "IMUS05" AS IMUS05_users_05, "IMUS06" AS IMUS06_users_06, "IMUS07" AS IMUS07_users_07, "IMUS08" AS IMUS08_users_08, "IMUS09"  ...

# %% [markdown]
# ### Next steps...
# Add SQL to SQL Tools data package

# %%
df_table_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-5ecd88d7372c> in <module>()
# ----> 1 df_table_map
#
# NameError: name 'df_table_map' is not defined
